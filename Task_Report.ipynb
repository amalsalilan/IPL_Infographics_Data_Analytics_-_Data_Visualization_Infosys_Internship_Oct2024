# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\sampa\OneDrive\Desktop\Intership_Infosys\Deliver\archive\deliveries.csv")
df
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
df.shape
# Out:
# (260920, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260920 entries, 0 to 260919
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          260920 non-null  int64
#  1   inning            260920 non-null  int64
#  2   batting_team      260920 non-null  object
#  3   bowling_team      260920 non-null  object
#  4   over              260920 non-null  int64
#  5   ball              260920 non-null  int64
#  6   batter            260920 non-null  object
#  7   bowler            260920 non-null  object
#  8   non_striker       260920 non-null  object
#  9   batsman_runs      260920 non-null  int64
#  10  extra_runs        260920 non-null  int64
#  11  total_runs        260920 non-null  int64
#  12  extras_type       14125 non-null   object
#  13  is_wicket         260920 non-null  int64
#  14  player_dismissed  12950 non-null   object
#  15  dismissal_kind    12950 non-null   object
# ...

# %%
df.isnull().sum()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# match_id             0.000000
# inning               0.000000
# batting_team         0.000000
# bowling_team         0.000000
# over                 0.000000
# ball                 0.000000
# batter               0.000000
# bowler               0.000000
# non_striker          0.000000
# batsman_runs         0.000000
# extra_runs           0.000000
# total_runs           0.000000
# extras_type         94.586463
# is_wicket            0.000000
# player_dismissed    95.036793
# dismissal_kind      95.036793
# fielder             96.414993
# dtype: float64

# %% [markdown]
# >>>

# %% [markdown]
# > # Visulizations

# %%
Top_Runs=df.groupby('batter')['total_runs'].sum().sort_values(ascending=False).head(10)
Top_Runs
# Out:
# batter
# V Kohli           8307
# S Dhawan          7119
# DA Warner         6910
# RG Sharma         6884
# SK Raina          5780
# MS Dhoni          5505
# AB de Villiers    5354
# CH Gayle          5336
# RV Uthappa        5246
# KD Karthik        5066
# Name: total_runs, dtype: int64

# %%
df['batter'].nunique()
# Out:
# 673

# %%
Top_Runs.plot(kind='bar', figsize=(10,5), x='batter', y='Top_Runs', title='Top 10 Batsmen By Score')
plt.xlabel('Batsman Name')
plt.ylabel('Total Runs')
# Out:
# Text(0, 0.5, 'Total Runs')

# %% [markdown]
# #### Insights: Top 10 Batsman accoring to the total runs each player scored
# ####    * These are the Top 10 players from the 673 Players
# ####    * The top player scored in the graph is V.Kohli, who scored 8307 runs
# ####    * The Top 10th player scored 5066 runs

# %% [markdown]
# >

# %% [markdown]
# ### 2.Top Bowlers By Wickets

# %%
Top_Bowlers=df.groupby('bowler')['is_wicket'].sum().sort_values(ascending=False).head(10)
Top_Bowlers
# Out:
# bowler
# YS Chahal     213
# DJ Bravo      207
# PP Chawla     201
# SP Narine     200
# R Ashwin      198
# B Kumar       195
# SL Malinga    188
# A Mishra      183
# JJ Bumrah     182
# RA Jadeja     169
# Name: is_wicket, dtype: int64

# %%
df['bowler'].nunique()
# Out:
# 530

# %%
Top_Bowlers.plot(kind='bar', x='bowler', y='is_wicket', title='Top 10 Bowlers By Wickets')
plt.xlabel('BowlersName')
plt.ylabel('No.of Wickets')
# Out:
# Text(0, 0.5, 'No.of Wickets')

# %% [markdown]
# #### Insights: Top 10 Bowlers according to the total Wickets each scored
# ####    * These are the Top 10 Bowlers from the 530 Players
# ####    * The top Bowlers scored in the graph is Y.S.Chahal, who scored 213 wickets
# ####    * The Top 10th Bowlers scored 169 wickets

# %% [markdown]
# ### 3.Run Distribution by over

# %%
Runs_Distribution=df.groupby(['over'])['total_runs'].sum()
Runs_Distribution
# Out:
# over
# 0     13651
# 1     16163
# 2     17895
# 3     18415
# 4     18565
# 5     18528
# 6     14839
# 7     15981
# 8     16639
# 9     16353
# 10    16779
# 11    17076
# 12    17205
# 13    17634
# 14    18149
# 15    18472
# 16    19012
# 17    19559
# 18    19076
# 19    17765
# Name: total_runs, dtype: int64

# %%
Runs_Distribution.plot(kind='line')
# Out:
# <Axes: xlabel='over'>

# %% [markdown]
# #### Insights: The Total no.of runs in the 20 overs
# ####    * Death Overs is performed from the 16th to the 17th over
# ####    * Slower balls are frequently used in death overs to counter aggressive batting.
# ####    * The score rate increased from 5.5 over
# ####    * The Score rate declined from 5th over

# %% [markdown]
# >>

# %% [markdown]
# >>

# %% [markdown]
# ### 4.Extra Breakdowns

# %%
Extra=df.groupby(['extras_type'])['extras_type'].count()
Extra
# Out:
# extras_type
# byes        673
# legbyes    4001
# noballs    1069
# penalty       2
# wides      8380
# Name: extras_type, dtype: int64

# %%
Extra.plot(kind='pie', figsize=(5,5),title='Extras Distribution',autopct='%1.1f%%',startangle=90)
# Out:
# <Axes: title={'center': 'Extras Distribution'}, ylabel='extras_type'>

# %% [markdown]
# #### Insights: The Total no.of Extra runs in the 20 overs because of different types
# ####    * There are 5 types of Extra where the batsman can score runs as shown in the graph
# ####    * From the various types of runs, wides were the most in scoring(59.3%) than the rest
# ####    * There were no penalty(0.0%) in the matches
# ####    * 7.6% of the extras were no balls
# ####    * 28.3% were legbyes
# ####    * 4.8% were byes

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# ### 5.Dismissal Types

# %%
dismissal_counts=df['dismissal_kind'].value_counts()
dismissal_counts
# Out:
# dismissal_kind
# caught                   8063
# bowled                   2212
# run out                  1114
# lbw                       800
# caught and bowled         367
# stumped                   358
# retired hurt               15
# hit wicket                 15
# obstructing the field       3
# retired out                 3
# Name: count, dtype: int64

# %%
dismissal_counts=df['dismissal_kind'].unique()
dismissal_counts
# Out:
# array([nan, 'caught', 'bowled', 'run out', 'lbw', 'retired hurt',
#        'stumped', 'caught and bowled', 'hit wicket',
#        'obstructing the field', 'retired out'], dtype=object)

# %%
df['dismissal_kind'].value_counts().plot(kind='pie', figsize=(10,10), startangle=90, title='Distribution of Dismissal Types', autopct='%1.1f%%', legend=False)
# Out:
# <Axes: title={'center': 'Distribution of Dismissal Types'}, ylabel='count'>

# %% [markdown]
# #### Insights: The Total no.of Dismissal types in the matches are 11
# ####    * Most of the dismissal are because of caught(62.3%)
# ####    * The 2nd most of the dismissal are bowled (17.1%)
# ####    * The 3rd most of the dismissal are run out (8.6%)

# %% [markdown]
# >

# %% [markdown]
# >

# %% [markdown]
# ### 6.Team Performance Comparison

# %%
df.groupby('batting_team')['total_runs'].sum().plot(kind='bar', figsize=(20, 5), color='blue', title='Total Runs Scored by Each Team', xlabel='Team', ylabel='Total Runs',rot=45)
# Out:
# <Axes: title={'center': 'Total Runs Scored by Each Team'}, xlabel='Team', ylabel='Total Runs'>

# %% [markdown]
# #### Insights: The Total no.of Dismissal types in the matches are 19
# ####    * Mumbai Indians scored the most runs out of the 19 teams
# ####    * The 2nd most scored team which scored after Mumbai Indians is Kolkata Knight Riders
# ####    * The least most scored team was Kochi Tuskers Kerala

# %% [markdown]
# >

# %% [markdown]
# >

# %%
AvgRuns_Over=df.groupby('over')['total_runs'].mean()
AvgRuns_Over
# Out:
# over
# 0     0.981663
# 1     1.173528
# 2     1.316099
# 3     1.356538
# 4     1.369100
# 5     1.373055
# 6     1.103107
# 7     1.189948
# 8     1.242087
# 9     1.224577
# 10    1.262623
# 11    1.287686
# 12    1.301240
# 13    1.343645
# 14    1.393504
# 15    1.434273
# 16    1.498778
# 17    1.587839
# 18    1.646896
# 19    1.776855
# Name: total_runs, dtype: float64

# %%
AvgRuns_Over_Graph = plt.plot(AvgRuns_Over)
plt.title('Average Runs per Over', ha='center')
plt.xlabel('Over')
plt.ylabel('Average Runs')
plt.xlim(0, 20)
plt.xticks([0, 5, 10, 15, 20])
plt.grid(True)
plt.show()

# %% [markdown]
# #### Insights: Average runs scored by a batsman in each over
# ####    * The average score in the first quarter of the match is 1.3 runs
# ####    * At half of the over the average score was 1.25 runs
# ####    * On the 20th over the average score is nearly 1.8 runs

# %% [markdown]
# >

# %%
YO = df[df['is_wicket']==1]
Wicket_PerOver= YO.groupby('over')['is_wicket'].count()
Wicket_PerOver
# Out:
# over
# 0      463
# 1      503
# 2      533
# 3      548
# 4      576
# 5      540
# 6      444
# 7      472
# 8      537
# 9      498
# 10     568
# 11     567
# 12     585
# 13     633
# 14     695
# 15     736
# 16     779
# 17     976
# 18     989
# 19    1308
# Name: is_wicket, dtype: int64

# %%
Wicket_PerOver_Graph= Wicket_PerOver.plot(kind='bar', color='brown'); plt.title('Wicket Fall Distribution by Over'); plt.xlabel('Over'); plt.ylabel('No.of Wickets');
Wicket_PerOver_Graph
# Out:
# <Axes: title={'center': 'Wicket Fall Distribution by Over'}, xlabel='Over', ylabel='No.of Wickets'>

# %% [markdown]
# >

# %% [markdown]
# >

# %%
team_performance = df.groupby('batting_team')['total_runs'].sum().reset_index().sort_values('total_runs')
team_performance
# Out:
#                    batting_team  total_runs
# 7          Kochi Tuskers Kerala        1901
# 15      Rising Pune Supergiants        2063
# 14       Rising Pune Supergiant        2470
# 17  Royal Challengers Bengaluru        2930
# 4                 Gujarat Lions        4862
# 11                Pune Warriors        6358
# 9          Lucknow Super Giants        7510
# 5                Gujarat Titans        7757
# 12                 Punjab Kings        9536
# 1               Deccan Chargers       11463
# 2                Delhi Capitals       14900
# 3              Delhi Daredevils       24296
# 18          Sunrisers Hyderabad       29071
# 6               Kings XI Punjab       30064
# 13             Rajasthan Royals       34747
# 16  Royal Challengers Bangalore       37692
# 0           Chennai Super Kings       38629
# 8         Kolkata Knight Riders       39331
# 10               Mumbai Indians       42176

# %%
team_performance .plot(kind='bar')
# Out:
# <Axes: >
