# %% [markdown]
# # Initial Exploration and Statstics

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("all_season_details.csv",)
# Out:
# C:\Users\harik\AppData\Local\Temp\ipykernel_7124\3332879461.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("all_season_details.csv",)

# %%
df.head()
# Out:
#    comment_id  season  match_id match_name home_team away_team  \
# 0         110  2023.0   1359475   GT v CSK        GT       CSK
# 1         120  2023.0   1359475   GT v CSK        GT       CSK
# 2         130  2023.0   1359475   GT v CSK        GT       CSK
# 3         140  2023.0   1359475   GT v CSK        GT       CSK
# 4         150  2023.0   1359475   GT v CSK        GT       CSK
#
#   current_innings  innings_id  over  ball  ...  wicket_id wkt_batsman_name  \
# 0             CSK           1     1     1  ...        NaN              NaN
# 1             CSK           1     1     2  ...        NaN              NaN
# 2             CSK           1     1     3  ...        NaN              NaN
# 3             CSK           1     1     4  ...        NaN              NaN
# 4             CSK           1     1     5  ...        NaN              NaN
#
#    wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  wkt_text  \
# ...

# %%
df.info()  #it gives the column information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242550 entries, 0 to 242549
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   comment_id         242550 non-null  int64
#  1   season             242067 non-null  float64
#  2   match_id           242550 non-null  int64
#  3   match_name         242550 non-null  object
#  4   home_team          242550 non-null  object
#  5   away_team          242550 non-null  object
#  6   current_innings    242550 non-null  object
#  7   innings_id         242550 non-null  int64
#  8   over               242550 non-null  int64
#  9   ball               242550 non-null  int64
#  10  runs               242550 non-null  int64
#  11  shortText          242550 non-null  object
#  12  isBoundary         242550 non-null  bool
#  13  isWide             242550 non-null  bool
#  14  isNoball           242550 non-null  bool
# ...

# %%
df.describe()
# Out:
#           comment_id         season      match_id     innings_id  \
# count  242550.000000  242067.000000  2.425500e+05  242550.000000
# mean    86415.531767    2015.588048  8.701769e+05       1.483245
# std     79516.360959       4.639506  3.530671e+05       0.499720
# min       110.000000    2008.000000  3.359820e+05       1.000000
# 25%     18040.000000    2012.000000  5.483150e+05       1.000000
# 50%     29010.000000    2015.000000  8.298190e+05       1.000000
# 75%    118060.000000    2020.000000  1.216506e+06       2.000000
# max    219080.000000    2023.000000  1.370353e+06       2.000000
#
#                 over           ball           runs   batsman1_id  \
# count  242550.000000  242550.000000  242550.000000  2.425500e+05
# mean       10.161678       3.483875       1.317901  2.503057e+05
# std         5.658053       1.707451       1.612821  2.968806e+05
# min         1.000000       1.000000       0.000000  4.292000e+03
# ...

# %%
df.nunique() # Unique value counts
# Out:
# comment_id              380
# season                   16
# match_id               1023
# match_name              159
# home_team                15
# away_team                15
# current_innings          15
# innings_id                2
# over                     20
# ball                      7
# runs                      8
# shortText             88537
# isBoundary                2
# isWide                    2
# isNoball                  2
# batsman1_id             635
# batsman1_name           637
# batsman1_runs           156
# batsman1_balls           74
# bowler1_id              503
# bowler1_name            504
# bowler1_overs            36
# bowler1_maidens           3
# bowler1_runs             70
# bowler1_wkts              7
# batsman2_id             626
# batsman2_name           627
# batsman2_runs           138
# batsman2_balls           71
# bowler2_id              496
# bowler2_name            497
# bowler2_overs            23
# bowler2_maidens           3
# ...

# %%
df.isnull().sum()  #checking missing values
# Out:
# comment_id                0
# season                  483
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# shortText                 0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# ...

# %%
df.describe(include=['object'])   # Summary statistics for categorical columns
# Out:
#        match_name home_team away_team current_innings               shortText  \
# count      242550    242550    242550          242550                  242550
# unique        159        15        15              15                   88537
# top       DC v MI       CSK        MI              DC  Sharma to Kohli, 1 run
# freq         5965     29624     30851           37007                      94
#
#        batsman1_name         bowler1_name batsman2_id   batsman2_name  \
# count         242550               242550      242550          242548
# unique           637                  504         626             627
# top      Virat Kohli  Ravichandran Ashwin       28235  Shikhar Dhawan
# freq            5726                 4325        5827            5827
#
#                bowler2_name wkt_batsman_name wkt_bowler_name  \
# count                229709            11880           11880
# unique                  497              594             437
# ...

# %%
df.groupby('home_team')['runs'].mean()    # Average runs scored by each team
# Out:
# home_team
# CSK      1.298002
# DC       1.316851
# GL       1.398185
# GT       1.427558
# KKR      1.306080
# KXIP     1.347413
# Kochi    1.227069
# LSG      1.278488
# MI       1.335122
# PBKS     1.365373
# PWI      1.174881
# RCB      1.344371
# RPS      1.313337
# RR       1.320733
# SRH      1.285950
# Name: runs, dtype: float64

# %%
df.shape
# Out:
# (242550, 45)

# %%
df.columns
# Out:
# Index(['comment_id', 'season', 'match_id', 'match_name', 'home_team',
#        'away_team', 'current_innings', 'innings_id', 'over', 'ball', 'runs',
#        'shortText', 'isBoundary', 'isWide', 'isNoball', 'batsman1_id',
#        'batsman1_name', 'batsman1_runs', 'batsman1_balls', 'bowler1_id',
#        'bowler1_name', 'bowler1_overs', 'bowler1_maidens', 'bowler1_runs',
#        'bowler1_wkts', 'batsman2_id', 'batsman2_name', 'batsman2_runs',
#        'batsman2_balls', 'bowler2_id', 'bowler2_name', 'bowler2_overs',
#        'bowler2_maidens', 'bowler2_runs', 'bowler2_wkts', 'wicket_id',
#        'wkt_batsman_name', 'wkt_bowler_name', 'wkt_batsman_runs',
#        'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt', 'text', 'preText',
#        'postText'],
#       dtype='object')

# %%
df=df.groupby('season')['runs'].agg(['sum'])
df
# Out:
#           sum
# season
# 2008.0  17875
# 2009.0  16243
# 2010.0  18726
# 2011.0  21087
# 2012.0  22357
# 2013.0  22463
# 2014.0  18827
# 2015.0  18211
# 2016.0  18798
# 2017.0  18698
# 2018.0  19781
# 2019.0  19343
# 2020.0  19244
# 2021.0  18508
# 2022.0  24184
# 2023.0  24535

# %% [markdown]
# # EDA_Visualization

# %% [markdown]
# # 1. AVERAGE RUN RATE PER OVER
#
# Task:Calculate the average run rate for each over across all matches.

# %%
average_runs_per_over = df.groupby('over')['runs'].mean()
plt.figure(figsize=(10, 6))
average_runs_per_over.plot(kind='line', marker='o', color='b')
plt.title("Average Run Rate per Over")
plt.xlabel("Over")
plt.ylabel("Average Runs")
plt.grid(True)
plt.show()

# %% [markdown]
# # 2. WICKET FALL DISTRIBUTION BY OVER
#
# Task:Analyze which overs tend to see the most wickets fall.
# The chart can reveal patterns, like whether more wickets fall in the middle overs or the "death" overs. This information can help teams decide which bowlers to use in these high-wicket overs to maximize their chances of taking wickets.

# %%
wickets_data = df[df['wicket_id'].notna()] #IDENTIFY WICKETS
wickets_per_over = wickets_data.groupby('over').size() #COUNTS WICKETS BY OVER
plt.figure(figsize=(10, 6))
wickets_per_over.plot(kind='bar', color='orange')
plt.title("Wicket Fall Distribution by Over")
plt.xlabel("Over")
plt.ylabel("Number of Wickets")
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # 3.TOP 10 PARTNERSHIPS BY TOTAL RUNS
#
# Task:Identify the top 10 batting partnerships that have scored the most runs together.
# This visualization reveals the most successful batting partnerships, which can help in understanding which player combinations have the best Energy

# %%
partnerships = df.groupby(['batsman1_name', 'batsman2_name'])['runs'].sum().reset_index()
#Sort and get the top 10 partnerships by total runs
top_10_partnerships = partnerships.nlargest(10, 'runs')
# Combine batsman names for display
top_10_partnerships['partnership'] = top_10_partnerships['batsman1_name'] + " & " + top_10_partnerships['batsman2_name']
plt.figure(figsize=(12, 6))
plt.barh(top_10_partnerships['partnership'], top_10_partnerships['runs'], color='skyblue')
plt.xlabel("Total Runs")
plt.title("Top 10 Partnerships by Total Runs")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # 4. BATSMAN VS BOWLER ANALYSIS
#
# Task: Analyze which batsmen have scored the most runs against specific bowlers.
#
# This visualization highlights which batsmen have scored the most runs against specific bowlers.

# %%
batsman_bowler_runs = df.groupby(['batsman1_name', 'bowler1_name'])['runs'].sum().reset_index()
# Get the top 10 batsman-bowler pairs by total runs scored
top_10_batsman_bowler_pairs = batsman_bowler_runs.nlargest(10, 'runs')
# Combine batsman and bowler names for display
top_10_batsman_bowler_pairs['pair'] = top_10_batsman_bowler_pairs['batsman1_name'] + " vs " + top_10_batsman_bowler_pairs['bowler1_name']
plt.figure(figsize=(12, 6))
plt.barh(top_10_batsman_bowler_pairs['pair'], top_10_batsman_bowler_pairs['runs'], color='lightcoral')
plt.xlabel("Total Runs Scored")
plt.title("Top 10 Batsman vs Bowler Pairs by Runs Scored")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # 5.WICKETS BY DISMISSAL KIND PER BOWLER
#
# Task: Analyze how different bowlers take wickets (e.g., caught, bowled, LBW).

# %%
wickets_df = df[df['wicket_id'].notna()]
# Group by bowler and dismissal kind, then count the number of occurrences
dismissal_counts = wickets_df.groupby(['bowler1_name', 'wkt_text']).size().reset_index(name='wicket_count')
# Select the top 10 combinations based on wicket count
top_dismissals = dismissal_counts.nlargest(10, 'wicket_count')
plt.figure(figsize=(12, 6))
plt.barh(top_dismissals.apply(lambda x: f"{x['bowler1_name']} ({x['wkt_text']})", axis=1), top_dismissals['wicket_count'], color='PINK')
plt.xlabel("Number of Wickets")
plt.ylabel("Bowler and Dismissal Kind")
plt.title("Top 10 Bowler and Dismissal Kind Combinations")
plt.show()

# %% [markdown]
# # 6. MATCHES PER SEASON
#
# TASK: Visualize the Total Matches per Season in IPL Data.
#
# The line plot will display the number of matches per season, helping to identify increases, or decreases in the IPL match count over time.

# %%
matches_per_season = df['season'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
sns.lineplot(x=matches_per_season.index, y=matches_per_season.values, marker='o', color='b')
plt.title('Total Matches per Season')
plt.xlabel('Season')
plt.ylabel('Number of Matches')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # 7. Maximum Scores Achieved by Each Batsman
# This plot shows the maximum scores by each batsman

# %%
max_scores = df.groupby('batsman1_name')['batsman1_runs'].max().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=max_scores.values, y=max_scores.index)
plt.xlabel('Maximum Runs in a Single Match')
plt.title('Top 10 Batsmen by Highest Individual Scores')
plt.show()

# %% [markdown]
# # 8. Total Runs Scored by Each Batsman
# It shows the top 10 batsman by total runs

# %%
total_runs = df.groupby('batsman1_name')['batsman1_runs'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=total_runs.values, y=total_runs.index,color='pink')
plt.xlabel('Total Runs Scored')
plt.title('Top 10 Batsmen by Total Runs')
plt.show()

# %% [markdown]
# # 9. Frequency of High Scores (50+ and 100+)
# This first plot shows the top 10 batsmens with 50+ scores
#
# This second plot shows the top 10 batsmens with 100+ scores

# %%
# Top 10 batsmen by number of 50+ scores
fifties = df[df['batsman1_runs'] >= 50].groupby('batsman1_name')['batsman1_runs'].count().sort_values(ascending=False).head(10)
# Top 10 batsmen by number of 100+ scores
centuries = df[df['batsman1_runs'] >= 100].groupby('batsman1_name')['batsman1_runs'].count().sort_values(ascending=False).head(10)

# Plotting 50+ scores
plt.figure(figsize=(12, 6))
sns.barplot(x=fifties.values, y=fifties.index, color="Blue")
plt.xlabel('Count of 50+ Scores')
plt.title('Top 10 Batsmen by 50+ Scores')
plt.show()

# Plotting 100+ scores
plt.figure(figsize=(12, 6))
sns.barplot(x=centuries.values, y=centuries.index, color="Green")
plt.xlabel('Count of 100+ Scores')
plt.title('Top 10 Batsmen by 100+ Scores')
plt.show()

# %% [markdown]
# # 10.Boundaries Hit by Each Batsman
# This plot is ideal to visualize the total boundaries hit by top batsmen.

# %%
boundaries_by_batsman = df[df['isBoundary'] == 1].groupby('batsman1_name')['isBoundary'].count().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=boundaries_by_batsman.values, y=boundaries_by_batsman.index, color='brown')
plt.xlabel('Total Boundaries Hit')
plt.title('Top 10 Batsmen by Boundaries')
plt.show()

# %% [markdown]
# # 11.Top Bowlers by Total Wickets Taken
# This will identify the top 10 bowlers who have taken the most wickets in total.

# %%
total_wickets = df.groupby('bowler1_name')['bowler1_wkts'].sum().sort_values(ascending=False).head(10)
plt.figure(figsize=(12, 6))
sns.barplot(x=total_wickets.values, y=total_wickets.index, color="skyblue")
plt.xlabel('Total Wickets Taken')
plt.title('Top 10 Bowlers by Total Wickets')
plt.show()

# %% [markdown]
# # Data Preprocessing:

# %%
df.isnull().sum()
# Out:
# comment_id                0
# season                  483
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# shortText                 0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# ...

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df = df.drop_duplicates()  #removes the duplicate rows

# %%
df.columns
# Out:
# Index(['comment_id', 'season', 'match_id', 'match_name', 'home_team',
#        'away_team', 'current_innings', 'innings_id', 'over', 'ball', 'runs',
#        'shortText', 'isBoundary', 'isWide', 'isNoball', 'batsman1_id',
#        'batsman1_name', 'batsman1_runs', 'batsman1_balls', 'bowler1_id',
#        'bowler1_name', 'bowler1_overs', 'bowler1_maidens', 'bowler1_runs',
#        'bowler1_wkts', 'batsman2_id', 'batsman2_name', 'batsman2_runs',
#        'batsman2_balls', 'bowler2_id', 'bowler2_name', 'bowler2_overs',
#        'bowler2_maidens', 'bowler2_runs', 'bowler2_wkts', 'wicket_id',
#        'wkt_batsman_name', 'wkt_bowler_name', 'wkt_batsman_runs',
#        'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt', 'text', 'preText',
#        'postText'],
#       dtype='object')

# %% [markdown]
# # HANDILING MISSING VALUES

# %%
df['season'] = df['season'].astype('object').fillna('Unknown')
df['batsman2_name'] = df['batsman2_name'].fillna('Unknown')

# %%
bowler2_columns = ['bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens', 'bowler2_runs', 'bowler2_wkts']
df[bowler2_columns] = df[bowler2_columns].fillna('Unknown')

# %%
wicket_columns = ['wicket_id', 'wkt_batsman_name', 'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls']
df[wicket_columns] = df[wicket_columns].fillna('No Wicket')

# %%
df = df.drop(columns=['preText', 'postText','wkt_text','text'])

# %%
df.isnull().sum()
# Out:
# comment_id           0
# season               0
# match_id             0
# match_name           0
# home_team            0
# away_team            0
# current_innings      0
# innings_id           0
# over                 0
# ball                 0
# runs                 0
# shortText            0
# isBoundary           0
# isWide               0
# isNoball             0
# batsman1_id          0
# batsman1_name        0
# batsman1_runs        0
# batsman1_balls       0
# bowler1_id           0
# bowler1_name         0
# bowler1_overs        0
# bowler1_maidens      0
# bowler1_runs         0
# bowler1_wkts         0
# batsman2_id          0
# batsman2_name        0
# batsman2_runs        0
# batsman2_balls       0
# bowler2_id           0
# bowler2_name         0
# bowler2_overs        0
# bowler2_maidens      0
# bowler2_runs         0
# bowler2_wkts         0
# wicket_id            0
# wkt_batsman_name     0
# wkt_bowler_name      0
# wkt_batsman_runs     0
# wkt_batsman_balls    0
# ...

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Tracks the total score i.e; cumulative runs for each team within each inning.

# %%
df['cumulative_score'] = df.groupby(['match_id', 'current_innings'])['runs'].cumsum()

# %%
df.cumulative_score
# Out:
# 0           0
# 1           1
# 2           1
# 3           2
# 4           2
#          ...
# 242545    157
# 242546    158
# 242547    159
# 242548    161
# 242549    163
# Name: cumulative_score, Length: 242550, dtype: int64

# %% [markdown]
# # Outlier Removal

# %% [markdown]
# Removing outliers using IQR for 'runs'

# %%
Q1_runs = df['runs'].quantile(0.25)
Q3_runs = df['runs'].quantile(0.75)
IQR_runs = Q3_runs - Q1_runs
df = df[(df['runs'] >= (Q1_runs - 1.5 * IQR_runs)) & (df['runs'] <= (Q3_runs + 1.5 * IQR_runs))]

# %% [markdown]
# Removing outliers using IQR for 'bowler1_overs'

# %%
Q1_overs = df['bowler1_overs'].quantile(0.25)
Q3_overs = df['bowler1_overs'].quantile(0.75)
IQR_overs = Q3_overs - Q1_overs
df = df[(df['bowler1_overs'] >= (Q1_overs - 1.5 * IQR_overs)) & (df['bowler1_overs'] <= (Q3_overs + 1.5 * IQR_overs))]

# %%
df.select_dtypes(include=['number'])
# Out:
#         comment_id  match_id  innings_id  over  ball  runs  batsman1_id  \
# 0              110   1359475           1     1     1     0       379140
# 1              120   1359475           1     1     2     1       379140
# 2              130   1359475           1     1     3     0      1060380
# 3              140   1359475           1     1     4     1      1060380
# 4              150   1359475           1     1     5     0       379140
# ...            ...       ...         ...   ...   ...   ...          ...
# 242545      219020    336040           2    20     2     0         8166
# 242546      219030    336040           2    20     3     1         8166
# 242547      219050    336040           2    20     4     1         8166
# 242548      219040    336040           2    20     4     2        43265
# 242549      219060    336040           2    20     5     2        43265
#
#         batsman1_runs  batsman1_balls  bowler1_id  bowler1_overs  \
# ...

# %% [markdown]
# # Standardization

# %% [markdown]
# Specify the numeric columns to standardize then Initialize the scaler and then Standardize the numeric columns

# %%
from sklearn.preprocessing import StandardScaler
numeric_cols = ['runs', 'bowler1_overs', 'bowler1_runs', 'batsman1_runs']
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# %%
df.head()
# Out:
#    comment_id  season  match_id match_name home_team away_team  \
# 0         110  2023.0   1359475   GT v CSK        GT       CSK
# 1         120  2023.0   1359475   GT v CSK        GT       CSK
# 2         130  2023.0   1359475   GT v CSK        GT       CSK
# 3         140  2023.0   1359475   GT v CSK        GT       CSK
# 4         150  2023.0   1359475   GT v CSK        GT       CSK
#
#   current_innings  innings_id  over  ball  ...  bowler2_maidens bowler2_runs  \
# 0             CSK           1     1     1  ...          Unknown      Unknown
# 1             CSK           1     1     2  ...          Unknown      Unknown
# 2             CSK           1     1     3  ...          Unknown      Unknown
# 3             CSK           1     1     4  ...          Unknown      Unknown
# 4             CSK           1     1     5  ...          Unknown      Unknown
#
#    bowler2_wkts  wicket_id  wkt_batsman_name  wkt_bowler_name  \
# ...

# %%
print(df)
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  ...  bowler2_maidens  \
# 0                  CSK           1     1     1  ...          Unknown
# ...

# %%
df.dtypes
# Out:
# comment_id             int64
# season                object
# match_id               int64
# match_name            object
# home_team             object
# away_team             object
# current_innings       object
# innings_id             int64
# over                   int64
# ball                   int64
# runs                 float64
# shortText             object
# isBoundary              bool
# isWide                  bool
# isNoball                bool
# batsman1_id            int64
# batsman1_name         object
# batsman1_runs        float64
# batsman1_balls         int64
# bowler1_id             int64
# bowler1_name          object
# bowler1_overs        float64
# bowler1_maidens        int64
# bowler1_runs         float64
# bowler1_wkts           int64
# batsman2_id           object
# batsman2_name         object
# batsman2_runs          int64
# batsman2_balls         int64
# bowler2_id            object
# bowler2_name          object
# bowler2_overs         object
# ...

# %%
df.to_csv('preprocessed_dataset.csv', index=False)

# %% [markdown]
# # Base_Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error, r2_score

# %%
df=pd.read_csv('preprocessed_dataset.csv',low_memory=False)

# %%
df.head()
# Out:
#    comment_id  season  match_id match_name home_team away_team  \
# 0         110  2023.0   1359475   GT v CSK        GT       CSK
# 1         120  2023.0   1359475   GT v CSK        GT       CSK
# 2         130  2023.0   1359475   GT v CSK        GT       CSK
# 3         140  2023.0   1359475   GT v CSK        GT       CSK
# 4         150  2023.0   1359475   GT v CSK        GT       CSK
#
#   current_innings  innings_id  over  ball  ...  bowler2_maidens bowler2_runs  \
# 0             CSK           1     1     1  ...          Unknown      Unknown
# 1             CSK           1     1     2  ...          Unknown      Unknown
# 2             CSK           1     1     3  ...          Unknown      Unknown
# 3             CSK           1     1     4  ...          Unknown      Unknown
# 4             CSK           1     1     5  ...          Unknown      Unknown
#
#    bowler2_wkts  wicket_id  wkt_batsman_name  wkt_bowler_name  \
# ...

# %% [markdown]
# # Defining features and target

# %%
X = df[[
    'over', 'ball', 'runs', 'isBoundary', 'isWide', 'isNoball',
    'batsman1_runs', 'batsman1_balls', 'bowler1_overs', 'bowler1_runs'
]]
Y = df['cumulative_score']

# %%
X
# Out:
#         over  ball      runs  isBoundary  isWide  isNoball  batsman1_runs  \
# 0          1     1 -1.064710       False   False     False      -0.946154
# 1          1     2  0.549373       False   False     False      -0.946154
# 2          1     3 -1.064710       False   False     False      -0.946154
# 3          1     4  0.549373       False   False     False      -0.889917
# 4          1     5 -1.064710       False   False     False      -0.946154
# ...      ...   ...       ...         ...     ...       ...            ...
# 201636    20     2 -1.064710       False   False     False      -0.552493
# 201637    20     3  0.549373       False   False     False      -0.496256
# 201638    20     4  0.549373       False   False     False      -0.440018
# 201639    20     4  2.163455       False    True     False      -0.608730
# 201640    20     5  2.163455       False   False     False      -0.496256
#
#         batsman1_balls  bowler1_overs  bowler1_runs
# ...

# %%
Y
# Out:
# 0           0
# 1           1
# 2           1
# 3           2
# 4           2
#          ...
# 201636    157
# 201637    158
# 201638    159
# 201639    161
# 201640    163
# Name: cumulative_score, Length: 201641, dtype: int64

# %% [markdown]
# # Train-Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train
# Out:
#         over  ball      runs  isBoundary  isWide  isNoball  batsman1_runs  \
# 55319      5     4  0.549373       False   False     False      -0.608730
# 142337    15     3 -1.064710       False   False     False      -0.664968
# 187150    20     1 -1.064710       False   False     False      -0.833679
# 59684     12     2  2.163455       False   False     False      -0.777442
# 136921    14     3 -1.064710       False   False     False       1.696999
# ...      ...   ...       ...         ...     ...       ...            ...
# 119879     3     1  0.549373       False    True     False      -0.946154
# 103694    16     5  0.549373       False   False     False      -0.327544
# 131932    18     1 -1.064710       False   False     False       1.247100
# 146867    12     6  0.549373       False   False     False       0.009880
# 121958     4     2 -1.064710       False   False     False      -0.721205
#
#         batsman1_balls  bowler1_overs  bowler1_runs
# ...

# %%
X_test
# Out:
#         over  ball      runs  isBoundary  isWide  isNoball  batsman1_runs  \
# 184506     4     1  0.549373       False   False     False      -0.833679
# 156706    12     3  0.549373       False   False     False      -0.440018
# 69144     12     4  0.549373       False   False     False       1.696999
# 38198      8     1  2.163455       False   False     False       0.516016
# 183537     7     6  0.549373       False   False     False       0.740965
# ...      ...   ...       ...         ...     ...       ...            ...
# 123998     8     3  0.549373       False   False     False       0.009880
# 166104     2     4 -1.064710       False   False     False      -0.946154
# 153082     7     6 -1.064710       False   False     False      -0.889917
# 192618    17     3  0.549373       False   False     False      -0.496256
# 67415     20     1  0.549373       False   False     False      -0.777442
#
#         batsman1_balls  bowler1_overs  bowler1_runs
# ...

# %% [markdown]
# # Train the Random Forest model

# %%
rf_model = RandomForestRegressor(random_state=42)
rf_model.fit(X_train, Y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
Y_pred_rf = rf_model.predict(X_test)

# %% [markdown]
# # Calculate MSE and R² score

# %%
mse_rf = mean_squared_error(Y_test, Y_pred_rf)
r2_rf = r2_score(Y_test, Y_pred_rf)

# %%
 mse_rf,r2_rf
# Out:
# (335.5923028691785, 0.8591402032959097)

# %% [markdown]
# # Train the Linear Regression model

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred_linear = linear_model.predict(X_test)

# %% [markdown]
# # Calculate MSE and R² score

# %%
mse_linear = mean_squared_error(Y_test, Y_pred_linear)
r2_linear = r2_score(Y_test, Y_pred_linear)

# %%
 mse_linear,r2_linear
# Out:
# (301.12247776105266, 0.8736083913790222)

# %% [markdown]
# # Train the GradientBoosting model

# %%
gbr_model = GradientBoostingRegressor(random_state=42)
gbr_model.fit(X_train, Y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
Y_pred_gbr = gbr_model.predict(X_test)

# %% [markdown]
# # Calculate MSE and R² score

# %%
mse_gbr = mean_squared_error(Y_test, Y_pred_gbr)
r2_gbr = r2_score(Y_test, Y_pred_gbr)

# %%
 mse_gbr,r2_gbr
# Out:
# (305.84081106199017, 0.8716279422928248)

# %% [markdown]
# # Train the XGBoost model

# %%
xgb_model = XGBRegressor(random_state=42)
xgb_model.fit(X_train, Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
Y_pred_xgb = xgb_model.predict(X_test)

# %% [markdown]
# # Calculate MSE and R² score

# %%
mse_xgb = mean_squared_error(Y_test, Y_pred_rf)
r2_xgb = r2_score(Y_test, Y_pred_rf)

# %%
 mse_xgb,r2_xgb
# Out:
# (335.5923028691785, 0.8591402032959097)

# %%
print(pd.DataFrame({"Model": ["Random Forest", "Linear Regression","Gradien Boosting","XGBoost"], "MSE": [mse_rf, mse_linear,mse_gbr,mse_xgb], "R² Score": [r2_rf, r2_linear,r2_gbr,r2_xgb]}))
# Out:
#                Model         MSE  R² Score
# 0      Random Forest  335.592303  0.859140
# 1  Linear Regression  301.122478  0.873608
# 2   Gradien Boosting  305.840811  0.871628
# 3            XGBoost  335.592303  0.859140

# %% [markdown]
# # Hyper parameter tuning

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Define the column transformer for categorical encoding
trf = ColumnTransformer([
    ('onehot', OneHotEncoder(drop='first'), ['isBoundary', 'isWide', 'isNoball'])
], remainder='passthrough')

# %%
# Define the models and their hyperparameter grids
models = {
    'Gradient Boosting': (GradientBoostingRegressor(), {
        'model__n_estimators': [100, 200, 300],
        'model__learning_rate': [0.01, 0.1, 0.05],
        'model__max_depth': [3, 5, 7, 10],
        'model__subsample': [0.8, 0.9, 1.0]
    }),
}

# %%
# Dictionary to store results
result = {}

# %%
for model_name, (model, param_grid) in models.items():
    print(f"Tuning hyperparameters for {model_name}...")

    # Define the pipeline with encoding step and model
    pipe = Pipeline([
        ('transform', trf),
        ('model', model)
    ])

    # Check if hyperparameters need tuning
    if param_grid:
        search = RandomizedSearchCV(pipe, param_grid, scoring='r2', n_iter=10, cv=5, random_state=42)
        search.fit(X_train, Y_train)
        best_model = search.best_estimator_
    else:
        best_model = pipe
        best_model.fit(X_train, Y_train)

    Y_pred = best_model.predict(X_test)

    mse = mean_squared_error(Y_test, Y_pred)
    r2 = r2_score(Y_test, Y_pred)

    result[model_name] = {'MSE': mse, 'R2 Score': r2}
# Out:
# Tuning hyperparameters for Gradient Boosting...

# %%
pipe
# Out:
# Pipeline(steps=[('transform',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehot',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['isBoundary', 'isWide',
#                                                    'isNoball'])])),
#                 ('model', GradientBoostingRegressor())])

# %%
result
# Out:
# {'Gradient Boosting': {'MSE': 291.1624570877968,
#   'R2 Score': 0.8777889595124645}}

# %% [markdown]
# NOTE: After hyperparameter tuning, the Gradient Boosting model achieved improved performance with an MSE of 291.16 and an R² score of 0.878, indicating strong predictive accuracy.

# %% [markdown]
# # Classification

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report

# %%
# Create and train the Gradient Boosting Classifier
model = GradientBoostingClassifier(n_estimators=100, max_depth=3, learning_rate=0.1)
model.fit(X_train, Y_train)

# Make predictions on the test set
Y_pred = model.predict(X_test)

# Calculate accuracy and classification report
accuracy = accuracy_score(Y_test, Y_pred)
report = classification_report(Y_test, Y_pred)

print(f"Accuracy: {accuracy}")
print(f"Classification Report:\n{report}")
# Out:
# Accuracy: 0.9989337697438567
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96       551
#            1       1.00      1.00      1.00     39778
#
#     accuracy                           1.00     40329
#    macro avg       0.98      0.98      0.98     40329
# weighted avg       1.00      1.00      1.00     40329

# %% [markdown]
#   NOTE:
# The model achieved a 99.89% accuracy with exceptional performance in predicting wins and losses.
# The precision, recall, and F1-scores for both classes indicate a highly effective model, particularly in correctly identifying wins.
#
# class1 :wins
#
# class0 :losses
