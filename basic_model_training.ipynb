# %% [markdown]
# <a href="https://colab.research.google.com/github/amalsalilan/IPL_Infographics_Data_Analytics_-_Data_Visualization_Infosys_Internship_Oct2024/blob/D_Aasritha_Reddy/basic_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('sample_dataset.csv')
data
# Out:
#         Unnamed: 0  season  match_id home_team away_team current_innings  \
# 0                0  2023.0   1359475        GT       CSK             CSK
# 1                1  2023.0   1359475        GT       CSK             CSK
# 2                2  2023.0   1359475        GT       CSK             CSK
# 3                3  2023.0   1359475        GT       CSK             CSK
# 4                4  2023.0   1359475        GT       CSK             CSK
# ...            ...     ...       ...       ...       ...             ...
# 242545      242545  2008.0    336040       CSK        RR              RR
# 242546      242546  2008.0    336040       CSK        RR              RR
# 242547      242547  2008.0    336040       CSK        RR              RR
# 242548      242548  2008.0    336040       CSK        RR              RR
# 242549      242549  2008.0    336040       CSK        RR              RR
#
#         over  ball  wkt_batsman_runs  isRetiredHurt  cumulative_runs  \
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0            0
# season              483
# match_id              0
# home_team             0
# away_team             0
# current_innings       0
# over                  0
# ball                  0
# wkt_batsman_runs      0
# isRetiredHurt         0
# cumulative_runs       0
# wickets_lost          0
# overs_bowled          0
# run_rate              0
# powerplay             0
# dtype: int64

# %%
new = data.filter(['overs_bowled', 'wickets_lost', 'run_rate', 'powerplay','cumulative_runs'], axis=1)

# %%
new
# Out:
#         overs_bowled  wickets_lost  run_rate  powerplay  cumulative_runs
# 0           1.166667             0  0.000000       True              0.0
# 1           1.333333             0  0.000000       True              0.0
# 2           1.500000             0  0.000000       True              0.0
# 3           1.666667             0  0.000000       True              0.0
# 4           1.833333             0  0.000000       True              0.0
# ...              ...           ...       ...        ...              ...
# 242545     20.333333             2  3.786885      False             77.0
# 242546     20.500000             3  3.756098      False             77.0
# 242547     20.666667             3  3.725806      False             77.0
# 242548     20.666667             3  3.725806      False             77.0
# 242549     20.833333             3  3.696000      False             77.0
#
# [242550 rows x 5 columns]

# %%
# Select split size
ratio = 0.8
total_rows = new.shape[0]
train_size = int(total_rows*ratio)

# %%
train = new[0:train_size]
test = new[train_size:]

# %%
train
# Out:
#         overs_bowled  wickets_lost  run_rate  powerplay  cumulative_runs
# 0           1.166667             0  0.000000       True              0.0
# 1           1.333333             0  0.000000       True              0.0
# 2           1.500000             0  0.000000       True              0.0
# 3           1.666667             0  0.000000       True              0.0
# 4           1.833333             0  0.000000       True              0.0
# ...              ...           ...       ...        ...              ...
# 194035     18.833333             6  5.734513      False            108.0
# 194036     19.000000             6  5.684211      False            108.0
# 194037     19.166667             6  5.634783      False            108.0
# 194038     19.333333             6  5.586207      False            108.0
# 194039     19.500000             6  5.743590      False            112.0
#
# [194040 rows x 5 columns]

# %%
test
# Out:
#         overs_bowled  wickets_lost  run_rate  powerplay  cumulative_runs
# 194040     19.666667             6  6.711864      False            132.0
# 194041     19.833333             6  6.655462      False            132.0
# 194042     20.000000             6  6.600000      False            132.0
# 194043     20.166667             6  6.545455      False            132.0
# 194044     20.333333             6  6.491803      False            132.0
# ...              ...           ...       ...        ...              ...
# 242545     20.333333             2  3.786885      False             77.0
# 242546     20.500000             3  3.756098      False             77.0
# 242547     20.666667             3  3.725806      False             77.0
# 242548     20.666667             3  3.725806      False             77.0
# 242549     20.833333             3  3.696000      False             77.0
#
# [48510 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor

# %%
y=new['cumulative_runs']
x=new.drop(columns=['cumulative_runs'])

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42)

# %%
x_train
# Out:
#         overs_bowled  wickets_lost  run_rate  powerplay
# 75297       1.166667             1  0.000000       True
# 188346      7.666667             4  2.086957      False
# 135421     18.333333             4  5.618182      False
# 108174     18.000000             2  1.722222      False
# 100799     10.333333             1  2.612903      False
# ...              ...           ...       ...        ...
# 119879     10.833333             2  6.369231      False
# 103694     12.500000             2  0.480000      False
# 131932      6.000000             3  6.000000       True
# 146867     18.833333             2  4.725664      False
# 121958     10.833333             2  1.938462      False
#
# [181912 rows x 4 columns]

# %%
x_test
# Out:
#         overs_bowled  wickets_lost  run_rate  powerplay
# 122566     10.666667             0  2.437500      False
# 147656      5.166667             1  0.000000       True
# 27099      20.833333             6  7.104000      False
# 42493       2.666667             0  0.000000       True
# 154359     19.000000             2  4.789474      False
# ...              ...           ...       ...        ...
# 92333       4.333333             3  6.000000       True
# 74059      16.500000             3  2.363636      False
# 111812     13.000000             3  2.692308      False
# 119204     18.500000             4  5.513514      False
# 115299     10.833333             1  2.123077      False
#
# [60638 rows x 4 columns]

# %%
y_train
# Out:
# 75297       0.0
# 188346     16.0
# 135421    103.0
# 108174     31.0
# 100799     27.0
#           ...
# 119879     69.0
# 103694      6.0
# 131932     36.0
# 146867     89.0
# 121958     21.0
# Name: cumulative_runs, Length: 181912, dtype: float64

# %%
y_test
# Out:
# 122566     26.0
# 147656      0.0
# 27099     148.0
# 42493       0.0
# 154359     91.0
#           ...
# 92333      26.0
# 74059      39.0
# 111812     35.0
# 119204    102.0
# 115299     23.0
# Name: cumulative_runs, Length: 60638, dtype: float64

# %%
rf_model=RandomForestRegressor(n_estimators=200, max_depth=None, random_state=42,min_samples_leaf=1,min_samples_split=2)

# %%
rf_model
# Out:
# RandomForestRegressor(n_estimators=200, random_state=42)

# %%
rf_model.fit(x_train,y_train)
pred=rf_model.predict(x_test)

# %%
mse=mean_squared_error(y_test,pred)
rf_r2=r2_score(y_test,pred)

# %%
mse
# Out:
# 0.15277755120551473

# %%
rf_r2
# Out:
# 0.9999087152586794
