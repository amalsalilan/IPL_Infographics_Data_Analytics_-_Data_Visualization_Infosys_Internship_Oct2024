# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('all_season_details.csv')
df
# Out:
# C:\Users\govinda prasad\AppData\Local\Temp\ipykernel_29496\3647924527.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('all_season_details.csv')
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  ...  wicket_id  \
# 0                  CSK           1     1     1  ...        NaN
# 1                  CSK           1     1     2  ...        NaN
# 2                  CSK           1     1     3  ...        NaN
# 3                  CSK           1     1     4  ...        NaN
# 4                  CSK           1     1     5  ...        NaN
# ...                ...         ...   ...   ...  ...        ...
# 242545              RR           2    20     2  ...        NaN
# 242546              RR           2    20     3  ...        NaN
# 242547              RR           2    20     4  ...        NaN
# 242548              RR           2    20     4  ...        NaN
# 242549              RR           2    20     5  ...        NaN
#
#        wkt_batsman_name  wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 0                   NaN              NaN               NaN                NaN
# 1                   NaN              NaN               NaN                NaN
# 2                   NaN              NaN               NaN                NaN
# 3                   NaN              NaN               NaN                NaN
# 4                   NaN              NaN               NaN                NaN
# ...                 ...              ...               ...                ...
# 242545              NaN              NaN               NaN                NaN
# 242546              NaN              NaN               NaN                NaN
# 242547              NaN              NaN               NaN                NaN
# 242548              NaN              NaN               NaN                NaN
# 242549              NaN              NaN               NaN                NaN
#
#         wkt_text isRetiredHurt  \
# 0            NaN         False
# 1            NaN         False
# 2            NaN         False
# 3            NaN         False
# 4            NaN         False
# ...          ...           ...
# 242545       NaN         False
# 242546       NaN         False
# 242547       NaN         False
# 242548       NaN         False
# 242549       NaN         False
#
#                                                      text  \
# 0       nice and full, angling and perhaps swinging in...
# 1       Conway shuffles across off, and shimmies out a...
# 2       good length, angling in at off and then straig...
# 3       shorter and slanting into middle and leg, Gaik...
# 4       Shami hits a heavy length and brings this back...
# ...                                                   ...
# 242545  lovely! Balaji's bowled a yorker outside off s...
# 242546  Warne steps down the track and throws his bat ...
# 242547  Warne reaches out for a full ball and squeezes...
# 242548  what has he done! Balaji has bowled a wide out...
# 242549  Balaji bowls a full toss angling into the left...
#
#                                                   preText  \
# 0       <p><strong>7.30pm</strong> Gaikwad and Conway ...
# 1                                                     NaN
# 2                                                     NaN
# 3       <p>Rummy: "Fast bowling options for CSK defini...
# 4       <p>LG: "Watching out for Hangargekar. He was i...
# ...                                                   ...
# 242545                                                NaN
# 242546                                                NaN
# 242547                                                NaN
# 242548  <p>Rajasthan need two runs a ball. Balaji from...
# 242549                                                NaN
#
#                                              postText
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 242545                                            NaN
# 242546                          <p>6 off 3 balls.</p>
# 242547             <p>Three to win off two balls.</p>
# 242548                                            NaN
# 242549  <p>Rajasthan need one off the final ball.</p>
#
# [242550 rows x 45 columns]

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  runs  \
# 0                  CSK           1     1     1     0
# 1                  CSK           1     1     2     1
# 2                  CSK           1     1     3     0
# 3                  CSK           1     1     4     1
# 4                  CSK           1     1     5     0
# ...                ...         ...   ...   ...   ...
# 242545              RR           2    20     2     0
# 242546              RR           2    20     3     1
# 242547              RR           2    20     4     1
# 242548              RR           2    20     4     2
# 242549              RR           2    20     5     2
#
#                                   shortText  isBoundary  isWide  isNoball  \
# 0          Mohammed Shami to Conway, no run       False   False     False
# 1       Mohammed Shami to Conway, 1 leg bye       False   False     False
# 2         Mohammed Shami to Gaikwad, no run       False   False     False
# 3          Mohammed Shami to Gaikwad, 1 run       False   False     False
# 4          Mohammed Shami to Conway, no run       False   False     False
# ...                                     ...         ...     ...       ...
# 242545              Balaji to Warne, no run       False   False     False
# 242546               Balaji to Warne, 1 run       False   False     False
# 242547               Balaji to Warne, 1 run       False   False     False
# 242548     Balaji to Sohail Tanvir, 2 wides       False    True     False
# 242549      Balaji to Sohail Tanvir, 2 runs       False   False     False
#
#         batsman1_id    batsman1_name  batsman1_runs  batsman1_balls  \
# 0            379140     Devon Conway              0               1
# 1            379140     Devon Conway              0               2
# 2           1060380  Ruturaj Gaikwad              0               1
# 3           1060380  Ruturaj Gaikwad              1               2
# 4            379140     Devon Conway              0               3
# ...             ...              ...            ...             ...
# 242545         8166      Shane Warne              7               7
# 242546         8166      Shane Warne              8               8
# 242547         8166      Shane Warne              9               9
# 242548        43265    Sohail Tanvir              6               5
# 242549        43265    Sohail Tanvir              8               6
#
#         bowler1_id         bowler1_name  bowler1_overs  bowler1_maidens  \
# 0           481896       Mohammed Shami            0.1                0
# 1           481896       Mohammed Shami            0.2                0
# 2           481896       Mohammed Shami            0.3                0
# 3           481896       Mohammed Shami            0.4                0
# 4           481896       Mohammed Shami            0.5                0
# ...            ...                  ...            ...              ...
# 242545       26829  Lakshmipathy Balaji            3.2                0
# 242546       26829  Lakshmipathy Balaji            3.3                0
# 242547       26829  Lakshmipathy Balaji            3.4                0
# 242548       26829  Lakshmipathy Balaji            3.3                0
# 242549       26829  Lakshmipathy Balaji            3.5                0
#
#         bowler1_runs  bowler1_wkts batsman2_id    batsman2_name  \
# 0                  0             0     1060380  Ruturaj Gaikwad
# 1                  0             0     1060380  Ruturaj Gaikwad
# 2                  0             0      379140     Devon Conway
# 3                  1             0      379140     Devon Conway
# 4                  1             0     1060380  Ruturaj Gaikwad
# ...              ...           ...         ...              ...
# 242545            35             0       43265    Sohail Tanvir
# 242546            36             0       43265    Sohail Tanvir
# 242547            39             0       43265    Sohail Tanvir
# 242548            38             0        8166      Shane Warne
# 242549            41             0        8166      Shane Warne
#
#         batsman2_runs  batsman2_balls  bowler2_id   bowler2_name  \
# 0                   0               0         NaN            NaN
# 1                   0               0         NaN            NaN
# 2                   0               2         NaN            NaN
# 3                   0               2         NaN            NaN
# 4                   1               2         NaN            NaN
# ...               ...             ...         ...            ...
# 242545              6               5     46592.0  Makhaya Ntini
# 242546              6               5     46592.0  Makhaya Ntini
# 242547              6               5     46592.0  Makhaya Ntini
# 242548              8               8     46592.0  Makhaya Ntini
# 242549              9               9     46592.0  Makhaya Ntini
#
#         bowler2_overs  bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 0                 NaN              NaN           NaN           NaN        NaN
# 1                 NaN              NaN           NaN           NaN        NaN
# 2                 NaN              NaN           NaN           NaN        NaN
# 3                 NaN              NaN           NaN           NaN        NaN
# 4                 NaN              NaN           NaN           NaN        NaN
# ...               ...              ...           ...           ...        ...
# 242545            4.0              1.0          21.0           0.0        NaN
# 242546            4.0              1.0          21.0           0.0        NaN
# 242547            4.0              1.0          21.0           0.0        NaN
# 242548            4.0              1.0          21.0           0.0        NaN
# 242549            4.0              1.0          21.0           0.0        NaN
#
#        wkt_batsman_name wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 0                   NaN             NaN               NaN                NaN
# 1                   NaN             NaN               NaN                NaN
# 2                   NaN             NaN               NaN                NaN
# 3                   NaN             NaN               NaN                NaN
# 4                   NaN             NaN               NaN                NaN
# ...                 ...             ...               ...                ...
# 242545              NaN             NaN               NaN                NaN
# 242546              NaN             NaN               NaN                NaN
# 242547              NaN             NaN               NaN                NaN
# 242548              NaN             NaN               NaN                NaN
# 242549              NaN             NaN               NaN                NaN
#
#        wkt_text  isRetiredHurt  \
# 0           NaN          False
# 1           NaN          False
# 2           NaN          False
# 3           NaN          False
# 4           NaN          False
# ...         ...            ...
# 242545      NaN          False
# 242546      NaN          False
# 242547      NaN          False
# 242548      NaN          False
# 242549      NaN          False
#
#                                                      text  \
# 0       nice and full, angling and perhaps swinging in...
# 1       Conway shuffles across off, and shimmies out a...
# 2       good length, angling in at off and then straig...
# 3       shorter and slanting into middle and leg, Gaik...
# 4       Shami hits a heavy length and brings this back...
# ...                                                   ...
# 242545  lovely! Balaji's bowled a yorker outside off s...
# 242546  Warne steps down the track and throws his bat ...
# 242547  Warne reaches out for a full ball and squeezes...
# 242548  what has he done! Balaji has bowled a wide out...
# 242549  Balaji bowls a full toss angling into the left...
#
#                                                   preText  \
# 0       <p><strong>7.30pm</strong> Gaikwad and Conway ...
# 1                                                     NaN
# 2                                                     NaN
# 3       <p>Rummy: "Fast bowling options for CSK defini...
# 4       <p>LG: "Watching out for Hangargekar. He was i...
# ...                                                   ...
# 242545                                                NaN
# 242546                                                NaN
# 242547                                                NaN
# 242548  <p>Rajasthan need two runs a ball. Balaji from...
# 242549                                                NaN
#
#                                              postText
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 242545                                            NaN
# 242546                          <p>6 off 3 balls.</p>
# 242547             <p>Three to win off two balls.</p>
# 242548                                            NaN
# 242549  <p>Rajasthan need one off the final ball.</p>
#
# [242550 rows x 45 columns]

# %%
df.shape
# Out:
# (242550, 45)

# %%
df.columns
# Out:
# Index(['comment_id', 'season', 'match_id', 'match_name', 'home_team',
#        'away_team', 'current_innings', 'innings_id', 'over', 'ball', 'runs',
#        'shortText', 'isBoundary', 'isWide', 'isNoball', 'batsman1_id',
#        'batsman1_name', 'batsman1_runs', 'batsman1_balls', 'bowler1_id',
#        'bowler1_name', 'bowler1_overs', 'bowler1_maidens', 'bowler1_runs',
#        'bowler1_wkts', 'batsman2_id', 'batsman2_name', 'batsman2_runs',
#        'batsman2_balls', 'bowler2_id', 'bowler2_name', 'bowler2_overs',
#        'bowler2_maidens', 'bowler2_runs', 'bowler2_wkts', 'wicket_id',
#        'wkt_batsman_name', 'wkt_bowler_name', 'wkt_batsman_runs',
#        'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt', 'text', 'preText',
#        'postText'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242550 entries, 0 to 242549
# Data columns (total 45 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   comment_id         242550 non-null  int64
#  1   season             242067 non-null  float64
#  2   match_id           242550 non-null  int64
#  3   match_name         242550 non-null  object
#  4   home_team          242550 non-null  object
#  5   away_team          242550 non-null  object
#  6   current_innings    242550 non-null  object
#  7   innings_id         242550 non-null  int64
#  8   over               242550 non-null  int64
#  9   ball               242550 non-null  int64
#  10  runs               242550 non-null  int64
#  11  shortText          242550 non-null  object
#  12  isBoundary         242550 non-null  bool
#  13  isWide             242550 non-null  bool
#  14  isNoball           242550 non-null  bool
#  15  batsman1_id        242550 non-null  int64
#  16  batsman1_name      242550 non-null  object
#  17  batsman1_runs      242550 non-null  int64
#  18  batsman1_balls     242550 non-null  int64
#  19  bowler1_id         242550 non-null  int64
#  20  bowler1_name       242550 non-null  object
#  21  bowler1_overs      242550 non-null  float64
#  22  bowler1_maidens    242550 non-null  int64
#  23  bowler1_runs       242550 non-null  int64
#  24  bowler1_wkts       242550 non-null  int64
#  25  batsman2_id        242550 non-null  object
#  26  batsman2_name      242548 non-null  object
#  27  batsman2_runs      242550 non-null  int64
#  28  batsman2_balls     242550 non-null  int64
#  29  bowler2_id         229709 non-null  float64
#  30  bowler2_name       229709 non-null  object
#  31  bowler2_overs      229709 non-null  float64
#  32  bowler2_maidens    229709 non-null  float64
#  33  bowler2_runs       229709 non-null  float64
#  34  bowler2_wkts       229709 non-null  float64
#  35  wicket_id          11880 non-null   float64
#  36  wkt_batsman_name   11880 non-null   object
#  37  wkt_bowler_name    11880 non-null   object
#  38  wkt_batsman_runs   11880 non-null   float64
#  39  wkt_batsman_balls  11880 non-null   float64
#  40  wkt_text           11880 non-null   object
#  41  isRetiredHurt      242550 non-null  bool
#  42  text               241178 non-null  object
#  43  preText            46275 non-null   object
#  44  postText           19694 non-null   object
# dtypes: bool(4), float64(10), int64(15), object(16)
# memory usage: 76.8+ MB

# %%
df.drop(['comment_id','shortText','text','preText','postText'],axis=1,inplace=True)
df
# Out:
#         season  match_id match_name home_team away_team current_innings  \
# 0       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4       2023.0   1359475   GT v CSK        GT       CSK             CSK
# ...        ...       ...        ...       ...       ...             ...
# 242545  2008.0    336040   CSK v RR       CSK        RR              RR
# 242546  2008.0    336040   CSK v RR       CSK        RR              RR
# 242547  2008.0    336040   CSK v RR       CSK        RR              RR
# 242548  2008.0    336040   CSK v RR       CSK        RR              RR
# 242549  2008.0    336040   CSK v RR       CSK        RR              RR
#
#         innings_id  over  ball  runs  isBoundary  isWide  isNoball  \
# 0                1     1     1     0       False   False     False
# 1                1     1     2     1       False   False     False
# 2                1     1     3     0       False   False     False
# 3                1     1     4     1       False   False     False
# 4                1     1     5     0       False   False     False
# ...            ...   ...   ...   ...         ...     ...       ...
# 242545           2    20     2     0       False   False     False
# 242546           2    20     3     1       False   False     False
# 242547           2    20     4     1       False   False     False
# 242548           2    20     4     2       False    True     False
# 242549           2    20     5     2       False   False     False
#
#         batsman1_id    batsman1_name  batsman1_runs  batsman1_balls  \
# 0            379140     Devon Conway              0               1
# 1            379140     Devon Conway              0               2
# 2           1060380  Ruturaj Gaikwad              0               1
# 3           1060380  Ruturaj Gaikwad              1               2
# 4            379140     Devon Conway              0               3
# ...             ...              ...            ...             ...
# 242545         8166      Shane Warne              7               7
# 242546         8166      Shane Warne              8               8
# 242547         8166      Shane Warne              9               9
# 242548        43265    Sohail Tanvir              6               5
# 242549        43265    Sohail Tanvir              8               6
#
#         bowler1_id         bowler1_name  bowler1_overs  bowler1_maidens  \
# 0           481896       Mohammed Shami            0.1                0
# 1           481896       Mohammed Shami            0.2                0
# 2           481896       Mohammed Shami            0.3                0
# 3           481896       Mohammed Shami            0.4                0
# 4           481896       Mohammed Shami            0.5                0
# ...            ...                  ...            ...              ...
# 242545       26829  Lakshmipathy Balaji            3.2                0
# 242546       26829  Lakshmipathy Balaji            3.3                0
# 242547       26829  Lakshmipathy Balaji            3.4                0
# 242548       26829  Lakshmipathy Balaji            3.3                0
# 242549       26829  Lakshmipathy Balaji            3.5                0
#
#         bowler1_runs  bowler1_wkts batsman2_id    batsman2_name  \
# 0                  0             0     1060380  Ruturaj Gaikwad
# 1                  0             0     1060380  Ruturaj Gaikwad
# 2                  0             0      379140     Devon Conway
# 3                  1             0      379140     Devon Conway
# 4                  1             0     1060380  Ruturaj Gaikwad
# ...              ...           ...         ...              ...
# 242545            35             0       43265    Sohail Tanvir
# 242546            36             0       43265    Sohail Tanvir
# 242547            39             0       43265    Sohail Tanvir
# 242548            38             0        8166      Shane Warne
# 242549            41             0        8166      Shane Warne
#
#         batsman2_runs  batsman2_balls  bowler2_id   bowler2_name  \
# 0                   0               0         NaN            NaN
# 1                   0               0         NaN            NaN
# 2                   0               2         NaN            NaN
# 3                   0               2         NaN            NaN
# 4                   1               2         NaN            NaN
# ...               ...             ...         ...            ...
# 242545              6               5     46592.0  Makhaya Ntini
# 242546              6               5     46592.0  Makhaya Ntini
# 242547              6               5     46592.0  Makhaya Ntini
# 242548              8               8     46592.0  Makhaya Ntini
# 242549              9               9     46592.0  Makhaya Ntini
#
#         bowler2_overs  bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 0                 NaN              NaN           NaN           NaN        NaN
# 1                 NaN              NaN           NaN           NaN        NaN
# 2                 NaN              NaN           NaN           NaN        NaN
# 3                 NaN              NaN           NaN           NaN        NaN
# 4                 NaN              NaN           NaN           NaN        NaN
# ...               ...              ...           ...           ...        ...
# 242545            4.0              1.0          21.0           0.0        NaN
# 242546            4.0              1.0          21.0           0.0        NaN
# 242547            4.0              1.0          21.0           0.0        NaN
# 242548            4.0              1.0          21.0           0.0        NaN
# 242549            4.0              1.0          21.0           0.0        NaN
#
#        wkt_batsman_name wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 0                   NaN             NaN               NaN                NaN
# 1                   NaN             NaN               NaN                NaN
# 2                   NaN             NaN               NaN                NaN
# 3                   NaN             NaN               NaN                NaN
# 4                   NaN             NaN               NaN                NaN
# ...                 ...             ...               ...                ...
# 242545              NaN             NaN               NaN                NaN
# 242546              NaN             NaN               NaN                NaN
# 242547              NaN             NaN               NaN                NaN
# 242548              NaN             NaN               NaN                NaN
# 242549              NaN             NaN               NaN                NaN
#
#        wkt_text  isRetiredHurt
# 0           NaN          False
# 1           NaN          False
# 2           NaN          False
# 3           NaN          False
# 4           NaN          False
# ...         ...            ...
# 242545      NaN          False
# 242546      NaN          False
# 242547      NaN          False
# 242548      NaN          False
# 242549      NaN          False
#
# [242550 rows x 40 columns]

# %%
df.head(10)
# Out:
#    season  match_id match_name home_team away_team current_innings  \
# 0  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 5  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 6  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 7  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 8  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 9  2023.0   1359475   GT v CSK        GT       CSK             CSK
#
#    innings_id  over  ball  runs  isBoundary  isWide  isNoball  batsman1_id  \
# 0           1     1     1     0       False   False     False       379140
# 1           1     1     2     1       False   False     False       379140
# 2           1     1     3     0       False   False     False      1060380
# 3           1     1     4     1       False   False     False      1060380
# 4           1     1     5     0       False   False     False       379140
# 5           1     1     6     0       False   False     False       379140
# 6           1     2     1     4        True   False     False      1060380
# 7           1     2     2     0       False   False     False      1060380
# 8           1     2     3     4        True   False     False      1060380
# 9           1     2     4     1       False   False     False      1060380
#
#      batsman1_name  batsman1_runs  batsman1_balls  bowler1_id    bowler1_name  \
# 0     Devon Conway              0               1      481896  Mohammed Shami
# 1     Devon Conway              0               2      481896  Mohammed Shami
# 2  Ruturaj Gaikwad              0               1      481896  Mohammed Shami
# 3  Ruturaj Gaikwad              1               2      481896  Mohammed Shami
# 4     Devon Conway              0               3      481896  Mohammed Shami
# 5     Devon Conway              0               4      481896  Mohammed Shami
# 6  Ruturaj Gaikwad              5               3      625371   Hardik Pandya
# 7  Ruturaj Gaikwad              5               4      625371   Hardik Pandya
# 8  Ruturaj Gaikwad              9               5      625371   Hardik Pandya
# 9  Ruturaj Gaikwad             10               6      625371   Hardik Pandya
#
#    bowler1_overs  bowler1_maidens  bowler1_runs  bowler1_wkts batsman2_id  \
# 0            0.1                0             0             0     1060380
# 1            0.2                0             0             0     1060380
# 2            0.3                0             0             0      379140
# 3            0.4                0             1             0      379140
# 4            0.5                0             1             0     1060380
# 5            1.0                0             1             0     1060380
# 6            0.1                0             4             0      379140
# 7            0.2                0             4             0      379140
# 8            0.3                0             8             0      379140
# 9            0.4                0             9             0      379140
#
#      batsman2_name  batsman2_runs  batsman2_balls  bowler2_id    bowler2_name  \
# 0  Ruturaj Gaikwad              0               0         NaN             NaN
# 1  Ruturaj Gaikwad              0               0         NaN             NaN
# 2     Devon Conway              0               2         NaN             NaN
# 3     Devon Conway              0               2         NaN             NaN
# 4  Ruturaj Gaikwad              1               2         NaN             NaN
# 5  Ruturaj Gaikwad              1               2         NaN             NaN
# 6     Devon Conway              0               4    481896.0  Mohammed Shami
# 7     Devon Conway              0               4    481896.0  Mohammed Shami
# 8     Devon Conway              0               4    481896.0  Mohammed Shami
# 9     Devon Conway              0               4    481896.0  Mohammed Shami
#
#    bowler2_overs  bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 0            NaN              NaN           NaN           NaN        NaN
# 1            NaN              NaN           NaN           NaN        NaN
# 2            NaN              NaN           NaN           NaN        NaN
# 3            NaN              NaN           NaN           NaN        NaN
# 4            NaN              NaN           NaN           NaN        NaN
# 5            NaN              NaN           NaN           NaN        NaN
# 6            1.0              0.0           1.0           0.0        NaN
# 7            1.0              0.0           1.0           0.0        NaN
# 8            1.0              0.0           1.0           0.0        NaN
# 9            1.0              0.0           1.0           0.0        NaN
#
#   wkt_batsman_name wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 0              NaN             NaN               NaN                NaN
# 1              NaN             NaN               NaN                NaN
# 2              NaN             NaN               NaN                NaN
# 3              NaN             NaN               NaN                NaN
# 4              NaN             NaN               NaN                NaN
# 5              NaN             NaN               NaN                NaN
# 6              NaN             NaN               NaN                NaN
# 7              NaN             NaN               NaN                NaN
# 8              NaN             NaN               NaN                NaN
# 9              NaN             NaN               NaN                NaN
#
#   wkt_text  isRetiredHurt
# 0      NaN          False
# 1      NaN          False
# 2      NaN          False
# 3      NaN          False
# 4      NaN          False
# 5      NaN          False
# 6      NaN          False
# 7      NaN          False
# 8      NaN          False
# 9      NaN          False

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'isBoundary',
#        'isWide', 'isNoball', 'batsman1_id', 'batsman1_name', 'batsman1_runs',
#        'batsman1_balls', 'bowler1_id', 'bowler1_name', 'bowler1_overs',
#        'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts', 'batsman2_id',
#        'batsman2_name', 'batsman2_runs', 'batsman2_balls', 'bowler2_id',
#        'bowler2_name', 'bowler2_overs', 'bowler2_maidens', 'bowler2_runs',
#        'bowler2_wkts', 'wicket_id', 'wkt_batsman_name', 'wkt_bowler_name',
#        'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# season                  483
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# bowler2_runs          12841
# bowler2_wkts          12841
# wicket_id            230670
# wkt_batsman_name     230670
# wkt_bowler_name      230670
# wkt_batsman_runs     230670
# wkt_batsman_balls    230670
# wkt_text             230670
# isRetiredHurt             0
# dtype: int64

# %%
df[df['season'].isnull()]
# Out:
#        season  match_id match_name home_team away_team current_innings  \
# 5080      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5081      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5082      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5083      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5084      NaN   1359496   MI v KKR       KKR        MI             KKR
# ...       ...       ...        ...       ...       ...             ...
# 15196     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15197     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15198     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15199     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15200     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
#
#        innings_id  over  ball  runs  isBoundary  isWide  isNoball  \
# 5080            1     1     1     0       False   False     False
# 5081            1     1     2     2       False   False     False
# 5082            1     1     3     1       False   False     False
# 5083            1     1     4     1       False   False     False
# 5084            1     1     5     0       False   False     False
# ...           ...   ...   ...   ...         ...     ...       ...
# 15196           2    20     3     4        True   False     False
# 15197           2    20     4     0       False   False     False
# 15198           2    20     4     7        True   False      True
# 15199           2    20     5     0       False   False     False
# 15200           2    20     6     0       False   False     False
#
#        batsman1_id       batsman1_name  batsman1_runs  batsman1_balls  \
# 5080        974087  Rahmanullah Gurbaz              0               1
# 5081        974087  Rahmanullah Gurbaz              2               2
# 5082        974087  Rahmanullah Gurbaz              3               3
# 5083       1048813  Narayan Jagadeesan              0               1
# 5084        974087  Rahmanullah Gurbaz              3               4
# ...            ...                 ...            ...             ...
# 15196       403902    Liam Livingstone             88              44
# 15197       403902    Liam Livingstone             94              46
# 15198       403902    Liam Livingstone             94              45
# 15199       403902    Liam Livingstone             94              47
# 15200       403902    Liam Livingstone             94              48
#
#        bowler1_id     bowler1_name  bowler1_overs  bowler1_maidens  \
# 5080      1148776  Arjun Tendulkar            0.1                0
# 5081      1148776  Arjun Tendulkar            0.2                0
# 5082      1148776  Arjun Tendulkar            0.3                0
# 5083      1148776  Arjun Tendulkar            0.4                0
# 5084      1148776  Arjun Tendulkar            0.5                0
# ...           ...              ...            ...              ...
# 15196      236779    Ishant Sharma            2.3                0
# 15197      236779    Ishant Sharma            2.4                0
# 15198      236779    Ishant Sharma            2.3                0
# 15199      236779    Ishant Sharma            2.5                0
# 15200      236779    Ishant Sharma            3.0                0
#
#        bowler1_runs  bowler1_wkts batsman2_id       batsman2_name  \
# 5080              0             0     1048813  Narayan Jagadeesan
# 5081              2             0     1048813  Narayan Jagadeesan
# 5082              3             0     1048813  Narayan Jagadeesan
# 5083              3             0      974087  Rahmanullah Gurbaz
# 5084              3             0     1048813  Narayan Jagadeesan
# ...             ...           ...         ...                 ...
# 15196            29             1     1064812        Rahul Chahar
# 15197            36             1     1064812        Rahul Chahar
# 15198            36             1     1064812        Rahul Chahar
# 15199            36             1     1064812        Rahul Chahar
# 15200            36             2     1064812        Rahul Chahar
#
#        batsman2_runs  batsman2_balls  bowler2_id   bowler2_name  \
# 5080               0               0         NaN            NaN
# 5081               0               0         NaN            NaN
# 5082               0               0         NaN            NaN
# 5083               3               3         NaN            NaN
# 5084               0               1         NaN            NaN
# ...              ...             ...         ...            ...
# 15196              0               0    481979.0  Anrich Nortje
# 15197              0               0    481979.0  Anrich Nortje
# 15198              0               0    481979.0  Anrich Nortje
# 15199              0               0    481979.0  Anrich Nortje
# 15200              0               0    481979.0  Anrich Nortje
#
#        bowler2_overs  bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 5080             NaN              NaN           NaN           NaN        NaN
# 5081             NaN              NaN           NaN           NaN        NaN
# 5082             NaN              NaN           NaN           NaN        NaN
# 5083             NaN              NaN           NaN           NaN        NaN
# 5084             NaN              NaN           NaN           NaN        NaN
# ...              ...              ...           ...           ...        ...
# 15196            4.0              0.0          36.0           2.0        NaN
# 15197            4.0              0.0          36.0           2.0        NaN
# 15198            4.0              0.0          36.0           2.0        NaN
# 15199            4.0              0.0          36.0           2.0        NaN
# 15200            4.0              0.0          36.0           2.0   403902.0
#
#        wkt_batsman_name wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 5080                NaN             NaN               NaN                NaN
# 5081                NaN             NaN               NaN                NaN
# 5082                NaN             NaN               NaN                NaN
# 5083                NaN             NaN               NaN                NaN
# 5084                NaN             NaN               NaN                NaN
# ...                 ...             ...               ...                ...
# 15196               NaN             NaN               NaN                NaN
# 15197               NaN             NaN               NaN                NaN
# 15198               NaN             NaN               NaN                NaN
# 15199               NaN             NaN               NaN                NaN
# 15200  Liam Livingstone   Ishant Sharma              94.0               48.0
#
#                                                 wkt_text  isRetiredHurt
# 5080                                                 NaN          False
# 5081                                                 NaN          False
# 5082                                                 NaN          False
# 5083                                                 NaN          False
# 5084                                                 NaN          False
# ...                                                  ...            ...
# 15196                                                NaN          False
# 15197                                                NaN          False
# 15198                                                NaN          False
# 15199                                                NaN          False
# 15200  LS Livingstone c Patel b Sharma 94 (69m 48b 5x...          False
#
# [483 rows x 40 columns]

# %%
df.loc[(df['match_id'].isin([1359496,1359538])) & (df['season'].isnull()), 'season'] = 2023

# %%
df.isnull().sum()
# Out:
# season                    0
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# bowler2_runs          12841
# bowler2_wkts          12841
# wicket_id            230670
# wkt_batsman_name     230670
# wkt_bowler_name      230670
# wkt_batsman_runs     230670
# wkt_batsman_balls    230670
# wkt_text             230670
# isRetiredHurt             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#        season  match_id match_name home_team away_team current_innings  \
# 13082  2023.0   1359530   KKR v RR       KKR        RR             KKR
#
#        innings_id  over  ball  runs  isBoundary  isWide  isNoball  \
# 13082           1     1     1     2       False   False     False
#
#        batsman1_id batsman1_name  batsman1_runs  batsman1_balls  bowler1_id  \
# 13082       298438     Jason Roy              2               1      277912
#
#       bowler1_name  bowler1_overs  bowler1_maidens  bowler1_runs  \
# 13082  Trent Boult            0.1                0             2
#
#        bowler1_wkts batsman2_id       batsman2_name  batsman2_runs  \
# 13082             0      974087  Rahmanullah Gurbaz              0
#
#        batsman2_balls  bowler2_id bowler2_name  bowler2_overs  \
# 13082               0         NaN          NaN            NaN
#
#        bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 13082              NaN           NaN           NaN        NaN
#
#       wkt_batsman_name wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 13082              NaN             NaN               NaN                NaN
#
#       wkt_text  isRetiredHurt
# 13082      NaN          False

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.to_csv('all_season_details_data.csv', index=False)
