# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('all_season_details.csv')
df
# Out:
# C:\Users\govinda prasad\AppData\Local\Temp\ipykernel_19444\3647924527.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('all_season_details.csv')
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  runs  \
# 0                  CSK           1     1     1     0
# 1                  CSK           1     1     2     1
# 2                  CSK           1     1     3     0
# 3                  CSK           1     1     4     1
# 4                  CSK           1     1     5     0
# ...                ...         ...   ...   ...   ...
# 242545              RR           2    20     2     0
# 242546              RR           2    20     3     1
# 242547              RR           2    20     4     1
# 242548              RR           2    20     4     2
# 242549              RR           2    20     5     2
#
#                                   shortText  isBoundary  isWide  isNoball  \
# 0          Mohammed Shami to Conway, no run       False   False     False
# 1       Mohammed Shami to Conway, 1 leg bye       False   False     False
# 2         Mohammed Shami to Gaikwad, no run       False   False     False
# 3          Mohammed Shami to Gaikwad, 1 run       False   False     False
# 4          Mohammed Shami to Conway, no run       False   False     False
# ...                                     ...         ...     ...       ...
# 242545              Balaji to Warne, no run       False   False     False
# 242546               Balaji to Warne, 1 run       False   False     False
# 242547               Balaji to Warne, 1 run       False   False     False
# 242548     Balaji to Sohail Tanvir, 2 wides       False    True     False
# 242549      Balaji to Sohail Tanvir, 2 runs       False   False     False
#
#         batsman1_id    batsman1_name  batsman1_runs  batsman1_balls  \
# 0            379140     Devon Conway              0               1
# 1            379140     Devon Conway              0               2
# 2           1060380  Ruturaj Gaikwad              0               1
# 3           1060380  Ruturaj Gaikwad              1               2
# 4            379140     Devon Conway              0               3
# ...             ...              ...            ...             ...
# 242545         8166      Shane Warne              7               7
# 242546         8166      Shane Warne              8               8
# 242547         8166      Shane Warne              9               9
# 242548        43265    Sohail Tanvir              6               5
# 242549        43265    Sohail Tanvir              8               6
#
#         bowler1_id         bowler1_name  bowler1_overs  bowler1_maidens  \
# 0           481896       Mohammed Shami            0.1                0
# 1           481896       Mohammed Shami            0.2                0
# 2           481896       Mohammed Shami            0.3                0
# 3           481896       Mohammed Shami            0.4                0
# 4           481896       Mohammed Shami            0.5                0
# ...            ...                  ...            ...              ...
# 242545       26829  Lakshmipathy Balaji            3.2                0
# 242546       26829  Lakshmipathy Balaji            3.3                0
# 242547       26829  Lakshmipathy Balaji            3.4                0
# 242548       26829  Lakshmipathy Balaji            3.3                0
# 242549       26829  Lakshmipathy Balaji            3.5                0
#
#         bowler1_runs  bowler1_wkts batsman2_id    batsman2_name  \
# 0                  0             0     1060380  Ruturaj Gaikwad
# 1                  0             0     1060380  Ruturaj Gaikwad
# 2                  0             0      379140     Devon Conway
# 3                  1             0      379140     Devon Conway
# 4                  1             0     1060380  Ruturaj Gaikwad
# ...              ...           ...         ...              ...
# 242545            35             0       43265    Sohail Tanvir
# 242546            36             0       43265    Sohail Tanvir
# 242547            39             0       43265    Sohail Tanvir
# 242548            38             0        8166      Shane Warne
# 242549            41             0        8166      Shane Warne
#
#         batsman2_runs  batsman2_balls  bowler2_id   bowler2_name  \
# 0                   0               0         NaN            NaN
# 1                   0               0         NaN            NaN
# 2                   0               2         NaN            NaN
# 3                   0               2         NaN            NaN
# 4                   1               2         NaN            NaN
# ...               ...             ...         ...            ...
# 242545              6               5     46592.0  Makhaya Ntini
# 242546              6               5     46592.0  Makhaya Ntini
# 242547              6               5     46592.0  Makhaya Ntini
# 242548              8               8     46592.0  Makhaya Ntini
# 242549              9               9     46592.0  Makhaya Ntini
#
#         bowler2_overs  bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 0                 NaN              NaN           NaN           NaN        NaN
# 1                 NaN              NaN           NaN           NaN        NaN
# 2                 NaN              NaN           NaN           NaN        NaN
# 3                 NaN              NaN           NaN           NaN        NaN
# 4                 NaN              NaN           NaN           NaN        NaN
# ...               ...              ...           ...           ...        ...
# 242545            4.0              1.0          21.0           0.0        NaN
# 242546            4.0              1.0          21.0           0.0        NaN
# 242547            4.0              1.0          21.0           0.0        NaN
# 242548            4.0              1.0          21.0           0.0        NaN
# 242549            4.0              1.0          21.0           0.0        NaN
#
#        wkt_batsman_name wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 0                   NaN             NaN               NaN                NaN
# 1                   NaN             NaN               NaN                NaN
# 2                   NaN             NaN               NaN                NaN
# 3                   NaN             NaN               NaN                NaN
# 4                   NaN             NaN               NaN                NaN
# ...                 ...             ...               ...                ...
# 242545              NaN             NaN               NaN                NaN
# 242546              NaN             NaN               NaN                NaN
# 242547              NaN             NaN               NaN                NaN
# 242548              NaN             NaN               NaN                NaN
# 242549              NaN             NaN               NaN                NaN
#
#        wkt_text  isRetiredHurt  \
# 0           NaN          False
# 1           NaN          False
# 2           NaN          False
# 3           NaN          False
# 4           NaN          False
# ...         ...            ...
# 242545      NaN          False
# 242546      NaN          False
# 242547      NaN          False
# 242548      NaN          False
# 242549      NaN          False
#
#                                                      text  \
# 0       nice and full, angling and perhaps swinging in...
# 1       Conway shuffles across off, and shimmies out a...
# 2       good length, angling in at off and then straig...
# 3       shorter and slanting into middle and leg, Gaik...
# 4       Shami hits a heavy length and brings this back...
# ...                                                   ...
# 242545  lovely! Balaji's bowled a yorker outside off s...
# 242546  Warne steps down the track and throws his bat ...
# 242547  Warne reaches out for a full ball and squeezes...
# 242548  what has he done! Balaji has bowled a wide out...
# 242549  Balaji bowls a full toss angling into the left...
#
#                                                   preText  \
# 0       <p><strong>7.30pm</strong> Gaikwad and Conway ...
# 1                                                     NaN
# 2                                                     NaN
# 3       <p>Rummy: "Fast bowling options for CSK defini...
# 4       <p>LG: "Watching out for Hangargekar. He was i...
# ...                                                   ...
# 242545                                                NaN
# 242546                                                NaN
# 242547                                                NaN
# 242548  <p>Rajasthan need two runs a ball. Balaji from...
# 242549                                                NaN
#
#                                              postText
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 242545                                            NaN
# 242546                          <p>6 off 3 balls.</p>
# 242547             <p>Three to win off two balls.</p>
# 242548                                            NaN
# 242549  <p>Rajasthan need one off the final ball.</p>
#
# [242550 rows x 45 columns]

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  runs  \
# 0                  CSK           1     1     1     0
# 1                  CSK           1     1     2     1
# 2                  CSK           1     1     3     0
# 3                  CSK           1     1     4     1
# 4                  CSK           1     1     5     0
# ...                ...         ...   ...   ...   ...
# 242545              RR           2    20     2     0
# 242546              RR           2    20     3     1
# 242547              RR           2    20     4     1
# 242548              RR           2    20     4     2
# 242549              RR           2    20     5     2
#
#                                   shortText  isBoundary  isWide  isNoball  \
# 0          Mohammed Shami to Conway, no run       False   False     False
# 1       Mohammed Shami to Conway, 1 leg bye       False   False     False
# 2         Mohammed Shami to Gaikwad, no run       False   False     False
# 3          Mohammed Shami to Gaikwad, 1 run       False   False     False
# 4          Mohammed Shami to Conway, no run       False   False     False
# ...                                     ...         ...     ...       ...
# 242545              Balaji to Warne, no run       False   False     False
# 242546               Balaji to Warne, 1 run       False   False     False
# 242547               Balaji to Warne, 1 run       False   False     False
# 242548     Balaji to Sohail Tanvir, 2 wides       False    True     False
# 242549      Balaji to Sohail Tanvir, 2 runs       False   False     False
#
#         batsman1_id    batsman1_name  batsman1_runs  batsman1_balls  \
# 0            379140     Devon Conway              0               1
# 1            379140     Devon Conway              0               2
# 2           1060380  Ruturaj Gaikwad              0               1
# 3           1060380  Ruturaj Gaikwad              1               2
# 4            379140     Devon Conway              0               3
# ...             ...              ...            ...             ...
# 242545         8166      Shane Warne              7               7
# 242546         8166      Shane Warne              8               8
# 242547         8166      Shane Warne              9               9
# 242548        43265    Sohail Tanvir              6               5
# 242549        43265    Sohail Tanvir              8               6
#
#         bowler1_id         bowler1_name  bowler1_overs  bowler1_maidens  \
# 0           481896       Mohammed Shami            0.1                0
# 1           481896       Mohammed Shami            0.2                0
# 2           481896       Mohammed Shami            0.3                0
# 3           481896       Mohammed Shami            0.4                0
# 4           481896       Mohammed Shami            0.5                0
# ...            ...                  ...            ...              ...
# 242545       26829  Lakshmipathy Balaji            3.2                0
# 242546       26829  Lakshmipathy Balaji            3.3                0
# 242547       26829  Lakshmipathy Balaji            3.4                0
# 242548       26829  Lakshmipathy Balaji            3.3                0
# 242549       26829  Lakshmipathy Balaji            3.5                0
#
#         bowler1_runs  bowler1_wkts batsman2_id    batsman2_name  \
# 0                  0             0     1060380  Ruturaj Gaikwad
# 1                  0             0     1060380  Ruturaj Gaikwad
# 2                  0             0      379140     Devon Conway
# 3                  1             0      379140     Devon Conway
# 4                  1             0     1060380  Ruturaj Gaikwad
# ...              ...           ...         ...              ...
# 242545            35             0       43265    Sohail Tanvir
# 242546            36             0       43265    Sohail Tanvir
# 242547            39             0       43265    Sohail Tanvir
# 242548            38             0        8166      Shane Warne
# 242549            41             0        8166      Shane Warne
#
#         batsman2_runs  batsman2_balls  bowler2_id   bowler2_name  \
# 0                   0               0         NaN            NaN
# 1                   0               0         NaN            NaN
# 2                   0               2         NaN            NaN
# 3                   0               2         NaN            NaN
# 4                   1               2         NaN            NaN
# ...               ...             ...         ...            ...
# 242545              6               5     46592.0  Makhaya Ntini
# 242546              6               5     46592.0  Makhaya Ntini
# 242547              6               5     46592.0  Makhaya Ntini
# 242548              8               8     46592.0  Makhaya Ntini
# 242549              9               9     46592.0  Makhaya Ntini
#
#         bowler2_overs  bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 0                 NaN              NaN           NaN           NaN        NaN
# 1                 NaN              NaN           NaN           NaN        NaN
# 2                 NaN              NaN           NaN           NaN        NaN
# 3                 NaN              NaN           NaN           NaN        NaN
# 4                 NaN              NaN           NaN           NaN        NaN
# ...               ...              ...           ...           ...        ...
# 242545            4.0              1.0          21.0           0.0        NaN
# 242546            4.0              1.0          21.0           0.0        NaN
# 242547            4.0              1.0          21.0           0.0        NaN
# 242548            4.0              1.0          21.0           0.0        NaN
# 242549            4.0              1.0          21.0           0.0        NaN
#
#        wkt_batsman_name wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls  \
# 0                   NaN             NaN               NaN                NaN
# 1                   NaN             NaN               NaN                NaN
# 2                   NaN             NaN               NaN                NaN
# 3                   NaN             NaN               NaN                NaN
# 4                   NaN             NaN               NaN                NaN
# ...                 ...             ...               ...                ...
# 242545              NaN             NaN               NaN                NaN
# 242546              NaN             NaN               NaN                NaN
# 242547              NaN             NaN               NaN                NaN
# 242548              NaN             NaN               NaN                NaN
# 242549              NaN             NaN               NaN                NaN
#
#        wkt_text  isRetiredHurt  \
# 0           NaN          False
# 1           NaN          False
# 2           NaN          False
# 3           NaN          False
# 4           NaN          False
# ...         ...            ...
# 242545      NaN          False
# 242546      NaN          False
# 242547      NaN          False
# 242548      NaN          False
# 242549      NaN          False
#
#                                                      text  \
# 0       nice and full, angling and perhaps swinging in...
# 1       Conway shuffles across off, and shimmies out a...
# 2       good length, angling in at off and then straig...
# 3       shorter and slanting into middle and leg, Gaik...
# 4       Shami hits a heavy length and brings this back...
# ...                                                   ...
# 242545  lovely! Balaji's bowled a yorker outside off s...
# 242546  Warne steps down the track and throws his bat ...
# 242547  Warne reaches out for a full ball and squeezes...
# 242548  what has he done! Balaji has bowled a wide out...
# 242549  Balaji bowls a full toss angling into the left...
#
#                                                   preText  \
# 0       <p><strong>7.30pm</strong> Gaikwad and Conway ...
# 1                                                     NaN
# 2                                                     NaN
# 3       <p>Rummy: "Fast bowling options for CSK defini...
# 4       <p>LG: "Watching out for Hangargekar. He was i...
# ...                                                   ...
# 242545                                                NaN
# 242546                                                NaN
# 242547                                                NaN
# 242548  <p>Rajasthan need two runs a ball. Balaji from...
# 242549                                                NaN
#
#                                              postText
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ...                                               ...
# 242545                                            NaN
# 242546                          <p>6 off 3 balls.</p>
# 242547             <p>Three to win off two balls.</p>
# 242548                                            NaN
# 242549  <p>Rajasthan need one off the final ball.</p>
#
# [242550 rows x 45 columns]

# %%
df.shape
# Out:
# (242550, 45)

# %%
df.columns
# Out:
# Index(['comment_id', 'season', 'match_id', 'match_name', 'home_team',
#        'away_team', 'current_innings', 'innings_id', 'over', 'ball', 'runs',
#        'shortText', 'isBoundary', 'isWide', 'isNoball', 'batsman1_id',
#        'batsman1_name', 'batsman1_runs', 'batsman1_balls', 'bowler1_id',
#        'bowler1_name', 'bowler1_overs', 'bowler1_maidens', 'bowler1_runs',
#        'bowler1_wkts', 'batsman2_id', 'batsman2_name', 'batsman2_runs',
#        'batsman2_balls', 'bowler2_id', 'bowler2_name', 'bowler2_overs',
#        'bowler2_maidens', 'bowler2_runs', 'bowler2_wkts', 'wicket_id',
#        'wkt_batsman_name', 'wkt_bowler_name', 'wkt_batsman_runs',
#        'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt', 'text', 'preText',
#        'postText'],
#       dtype='object')

# %%
df.drop(['comment_id','text','preText','postText'],axis=1,inplace=True)
df
# Out:
#         season  match_id match_name home_team away_team current_innings  \
# 0       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4       2023.0   1359475   GT v CSK        GT       CSK             CSK
# ...        ...       ...        ...       ...       ...             ...
# 242545  2008.0    336040   CSK v RR       CSK        RR              RR
# 242546  2008.0    336040   CSK v RR       CSK        RR              RR
# 242547  2008.0    336040   CSK v RR       CSK        RR              RR
# 242548  2008.0    336040   CSK v RR       CSK        RR              RR
# 242549  2008.0    336040   CSK v RR       CSK        RR              RR
#
#         innings_id  over  ball  runs                            shortText  \
# 0                1     1     1     0     Mohammed Shami to Conway, no run
# 1                1     1     2     1  Mohammed Shami to Conway, 1 leg bye
# 2                1     1     3     0    Mohammed Shami to Gaikwad, no run
# 3                1     1     4     1     Mohammed Shami to Gaikwad, 1 run
# 4                1     1     5     0     Mohammed Shami to Conway, no run
# ...            ...   ...   ...   ...                                  ...
# 242545           2    20     2     0              Balaji to Warne, no run
# 242546           2    20     3     1               Balaji to Warne, 1 run
# 242547           2    20     4     1               Balaji to Warne, 1 run
# 242548           2    20     4     2     Balaji to Sohail Tanvir, 2 wides
# 242549           2    20     5     2      Balaji to Sohail Tanvir, 2 runs
#
#         isBoundary  isWide  isNoball  batsman1_id    batsman1_name  \
# 0            False   False     False       379140     Devon Conway
# 1            False   False     False       379140     Devon Conway
# 2            False   False     False      1060380  Ruturaj Gaikwad
# 3            False   False     False      1060380  Ruturaj Gaikwad
# 4            False   False     False       379140     Devon Conway
# ...            ...     ...       ...          ...              ...
# 242545       False   False     False         8166      Shane Warne
# 242546       False   False     False         8166      Shane Warne
# 242547       False   False     False         8166      Shane Warne
# 242548       False    True     False        43265    Sohail Tanvir
# 242549       False   False     False        43265    Sohail Tanvir
#
#         batsman1_runs  batsman1_balls  bowler1_id         bowler1_name  \
# 0                   0               1      481896       Mohammed Shami
# 1                   0               2      481896       Mohammed Shami
# 2                   0               1      481896       Mohammed Shami
# 3                   1               2      481896       Mohammed Shami
# 4                   0               3      481896       Mohammed Shami
# ...               ...             ...         ...                  ...
# 242545              7               7       26829  Lakshmipathy Balaji
# 242546              8               8       26829  Lakshmipathy Balaji
# 242547              9               9       26829  Lakshmipathy Balaji
# 242548              6               5       26829  Lakshmipathy Balaji
# 242549              8               6       26829  Lakshmipathy Balaji
#
#         bowler1_overs  bowler1_maidens  bowler1_runs  bowler1_wkts  \
# 0                 0.1                0             0             0
# 1                 0.2                0             0             0
# 2                 0.3                0             0             0
# 3                 0.4                0             1             0
# 4                 0.5                0             1             0
# ...               ...              ...           ...           ...
# 242545            3.2                0            35             0
# 242546            3.3                0            36             0
# 242547            3.4                0            39             0
# 242548            3.3                0            38             0
# 242549            3.5                0            41             0
#
#        batsman2_id    batsman2_name  batsman2_runs  batsman2_balls  \
# 0          1060380  Ruturaj Gaikwad              0               0
# 1          1060380  Ruturaj Gaikwad              0               0
# 2           379140     Devon Conway              0               2
# 3           379140     Devon Conway              0               2
# 4          1060380  Ruturaj Gaikwad              1               2
# ...            ...              ...            ...             ...
# 242545       43265    Sohail Tanvir              6               5
# 242546       43265    Sohail Tanvir              6               5
# 242547       43265    Sohail Tanvir              6               5
# 242548        8166      Shane Warne              8               8
# 242549        8166      Shane Warne              9               9
#
#         bowler2_id   bowler2_name  bowler2_overs  bowler2_maidens  \
# 0              NaN            NaN            NaN              NaN
# 1              NaN            NaN            NaN              NaN
# 2              NaN            NaN            NaN              NaN
# 3              NaN            NaN            NaN              NaN
# 4              NaN            NaN            NaN              NaN
# ...            ...            ...            ...              ...
# 242545     46592.0  Makhaya Ntini            4.0              1.0
# 242546     46592.0  Makhaya Ntini            4.0              1.0
# 242547     46592.0  Makhaya Ntini            4.0              1.0
# 242548     46592.0  Makhaya Ntini            4.0              1.0
# 242549     46592.0  Makhaya Ntini            4.0              1.0
#
#         bowler2_runs  bowler2_wkts  wicket_id wkt_batsman_name  \
# 0                NaN           NaN        NaN              NaN
# 1                NaN           NaN        NaN              NaN
# 2                NaN           NaN        NaN              NaN
# 3                NaN           NaN        NaN              NaN
# 4                NaN           NaN        NaN              NaN
# ...              ...           ...        ...              ...
# 242545          21.0           0.0        NaN              NaN
# 242546          21.0           0.0        NaN              NaN
# 242547          21.0           0.0        NaN              NaN
# 242548          21.0           0.0        NaN              NaN
# 242549          21.0           0.0        NaN              NaN
#
#        wkt_bowler_name  wkt_batsman_runs  wkt_batsman_balls wkt_text  \
# 0                  NaN               NaN                NaN      NaN
# 1                  NaN               NaN                NaN      NaN
# 2                  NaN               NaN                NaN      NaN
# 3                  NaN               NaN                NaN      NaN
# 4                  NaN               NaN                NaN      NaN
# ...                ...               ...                ...      ...
# 242545             NaN               NaN                NaN      NaN
# 242546             NaN               NaN                NaN      NaN
# 242547             NaN               NaN                NaN      NaN
# 242548             NaN               NaN                NaN      NaN
# 242549             NaN               NaN                NaN      NaN
#
#         isRetiredHurt
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ...               ...
# 242545          False
# 242546          False
# 242547          False
# 242548          False
# 242549          False
#
# [242550 rows x 41 columns]

# %%
df.head(10)
# Out:
#    season  match_id match_name home_team away_team current_innings  \
# 0  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 5  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 6  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 7  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 8  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 9  2023.0   1359475   GT v CSK        GT       CSK             CSK
#
#    innings_id  over  ball  runs                            shortText  \
# 0           1     1     1     0     Mohammed Shami to Conway, no run
# 1           1     1     2     1  Mohammed Shami to Conway, 1 leg bye
# 2           1     1     3     0    Mohammed Shami to Gaikwad, no run
# 3           1     1     4     1     Mohammed Shami to Gaikwad, 1 run
# 4           1     1     5     0     Mohammed Shami to Conway, no run
# 5           1     1     6     0     Mohammed Shami to Conway, no run
# 6           1     2     1     4              Pandya to Gaikwad, FOUR
# 7           1     2     2     0            Pandya to Gaikwad, no run
# 8           1     2     3     4              Pandya to Gaikwad, FOUR
# 9           1     2     4     1             Pandya to Gaikwad, 1 run
#
#    isBoundary  isWide  isNoball  batsman1_id    batsman1_name  batsman1_runs  \
# 0       False   False     False       379140     Devon Conway              0
# 1       False   False     False       379140     Devon Conway              0
# 2       False   False     False      1060380  Ruturaj Gaikwad              0
# 3       False   False     False      1060380  Ruturaj Gaikwad              1
# 4       False   False     False       379140     Devon Conway              0
# 5       False   False     False       379140     Devon Conway              0
# 6        True   False     False      1060380  Ruturaj Gaikwad              5
# 7       False   False     False      1060380  Ruturaj Gaikwad              5
# 8        True   False     False      1060380  Ruturaj Gaikwad              9
# 9       False   False     False      1060380  Ruturaj Gaikwad             10
#
#    batsman1_balls  bowler1_id    bowler1_name  bowler1_overs  bowler1_maidens  \
# 0               1      481896  Mohammed Shami            0.1                0
# 1               2      481896  Mohammed Shami            0.2                0
# 2               1      481896  Mohammed Shami            0.3                0
# 3               2      481896  Mohammed Shami            0.4                0
# 4               3      481896  Mohammed Shami            0.5                0
# 5               4      481896  Mohammed Shami            1.0                0
# 6               3      625371   Hardik Pandya            0.1                0
# 7               4      625371   Hardik Pandya            0.2                0
# 8               5      625371   Hardik Pandya            0.3                0
# 9               6      625371   Hardik Pandya            0.4                0
#
#    bowler1_runs  bowler1_wkts batsman2_id    batsman2_name  batsman2_runs  \
# 0             0             0     1060380  Ruturaj Gaikwad              0
# 1             0             0     1060380  Ruturaj Gaikwad              0
# 2             0             0      379140     Devon Conway              0
# 3             1             0      379140     Devon Conway              0
# 4             1             0     1060380  Ruturaj Gaikwad              1
# 5             1             0     1060380  Ruturaj Gaikwad              1
# 6             4             0      379140     Devon Conway              0
# 7             4             0      379140     Devon Conway              0
# 8             8             0      379140     Devon Conway              0
# 9             9             0      379140     Devon Conway              0
#
#    batsman2_balls  bowler2_id    bowler2_name  bowler2_overs  bowler2_maidens  \
# 0               0         NaN             NaN            NaN              NaN
# 1               0         NaN             NaN            NaN              NaN
# 2               2         NaN             NaN            NaN              NaN
# 3               2         NaN             NaN            NaN              NaN
# 4               2         NaN             NaN            NaN              NaN
# 5               2         NaN             NaN            NaN              NaN
# 6               4    481896.0  Mohammed Shami            1.0              0.0
# 7               4    481896.0  Mohammed Shami            1.0              0.0
# 8               4    481896.0  Mohammed Shami            1.0              0.0
# 9               4    481896.0  Mohammed Shami            1.0              0.0
#
#    bowler2_runs  bowler2_wkts  wicket_id wkt_batsman_name wkt_bowler_name  \
# 0           NaN           NaN        NaN              NaN             NaN
# 1           NaN           NaN        NaN              NaN             NaN
# 2           NaN           NaN        NaN              NaN             NaN
# 3           NaN           NaN        NaN              NaN             NaN
# 4           NaN           NaN        NaN              NaN             NaN
# 5           NaN           NaN        NaN              NaN             NaN
# 6           1.0           0.0        NaN              NaN             NaN
# 7           1.0           0.0        NaN              NaN             NaN
# 8           1.0           0.0        NaN              NaN             NaN
# 9           1.0           0.0        NaN              NaN             NaN
#
#    wkt_batsman_runs  wkt_batsman_balls wkt_text  isRetiredHurt
# 0               NaN                NaN      NaN          False
# 1               NaN                NaN      NaN          False
# 2               NaN                NaN      NaN          False
# 3               NaN                NaN      NaN          False
# 4               NaN                NaN      NaN          False
# 5               NaN                NaN      NaN          False
# 6               NaN                NaN      NaN          False
# 7               NaN                NaN      NaN          False
# 8               NaN                NaN      NaN          False
# 9               NaN                NaN      NaN          False

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242550 entries, 0 to 242549
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   season             242067 non-null  float64
#  1   match_id           242550 non-null  int64
#  2   match_name         242550 non-null  object
#  3   home_team          242550 non-null  object
#  4   away_team          242550 non-null  object
#  5   current_innings    242550 non-null  object
#  6   innings_id         242550 non-null  int64
#  7   over               242550 non-null  int64
#  8   ball               242550 non-null  int64
#  9   runs               242550 non-null  int64
#  10  shortText          242550 non-null  object
#  11  isBoundary         242550 non-null  bool
#  12  isWide             242550 non-null  bool
#  13  isNoball           242550 non-null  bool
#  14  batsman1_id        242550 non-null  int64
#  15  batsman1_name      242550 non-null  object
#  16  batsman1_runs      242550 non-null  int64
#  17  batsman1_balls     242550 non-null  int64
#  18  bowler1_id         242550 non-null  int64
#  19  bowler1_name       242550 non-null  object
#  20  bowler1_overs      242550 non-null  float64
#  21  bowler1_maidens    242550 non-null  int64
#  22  bowler1_runs       242550 non-null  int64
#  23  bowler1_wkts       242550 non-null  int64
#  24  batsman2_id        242550 non-null  object
#  25  batsman2_name      242548 non-null  object
#  26  batsman2_runs      242550 non-null  int64
#  27  batsman2_balls     242550 non-null  int64
#  28  bowler2_id         229709 non-null  float64
#  29  bowler2_name       229709 non-null  object
#  30  bowler2_overs      229709 non-null  float64
#  31  bowler2_maidens    229709 non-null  float64
#  32  bowler2_runs       229709 non-null  float64
#  33  bowler2_wkts       229709 non-null  float64
#  34  wicket_id          11880 non-null   float64
#  35  wkt_batsman_name   11880 non-null   object
#  36  wkt_bowler_name    11880 non-null   object
#  37  wkt_batsman_runs   11880 non-null   float64
#  38  wkt_batsman_balls  11880 non-null   float64
#  39  wkt_text           11880 non-null   object
#  40  isRetiredHurt      242550 non-null  bool
# dtypes: bool(4), float64(10), int64(14), object(13)
# memory usage: 69.4+ MB

# %%
df.isnull().sum()
# Out:
# season                  483
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# shortText                 0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# bowler2_runs          12841
# bowler2_wkts          12841
# wicket_id            230670
# wkt_batsman_name     230670
# wkt_bowler_name      230670
# wkt_batsman_runs     230670
# wkt_batsman_balls    230670
# wkt_text             230670
# isRetiredHurt             0
# dtype: int64

# %%
df[df['season'].isnull()]
# Out:
#        season  match_id match_name home_team away_team current_innings  \
# 5080      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5081      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5082      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5083      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5084      NaN   1359496   MI v KKR       KKR        MI             KKR
# ...       ...       ...        ...       ...       ...             ...
# 15196     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15197     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15198     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15199     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15200     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
#
#        innings_id  over  ball  runs                                shortText  \
# 5080            1     1     1     0  Tendulkar to Rahmanullah Gurbaz, no run
# 5081            1     1     2     2  Tendulkar to Rahmanullah Gurbaz, 2 runs
# 5082            1     1     3     1   Tendulkar to Rahmanullah Gurbaz, 1 run
# 5083            1     1     4     1       Tendulkar to Jagadeesan, 1 leg bye
# 5084            1     1     5     0  Tendulkar to Rahmanullah Gurbaz, no run
# ...           ...   ...   ...   ...                                      ...
# 15196           2    20     3     4              Sharma to Livingstone, FOUR
# 15197           2    20     4     0            Sharma to Livingstone, no run
# 15198           2    20     4     7     Sharma to Livingstone, (no ball) SIX
# 15199           2    20     5     0            Sharma to Livingstone, no run
# 15200           2    20     6     0               Sharma to Livingstone, OUT
#
#        isBoundary  isWide  isNoball  batsman1_id       batsman1_name  \
# 5080        False   False     False       974087  Rahmanullah Gurbaz
# 5081        False   False     False       974087  Rahmanullah Gurbaz
# 5082        False   False     False       974087  Rahmanullah Gurbaz
# 5083        False   False     False      1048813  Narayan Jagadeesan
# 5084        False   False     False       974087  Rahmanullah Gurbaz
# ...           ...     ...       ...          ...                 ...
# 15196        True   False     False       403902    Liam Livingstone
# 15197       False   False     False       403902    Liam Livingstone
# 15198        True   False      True       403902    Liam Livingstone
# 15199       False   False     False       403902    Liam Livingstone
# 15200       False   False     False       403902    Liam Livingstone
#
#        batsman1_runs  batsman1_balls  bowler1_id     bowler1_name  \
# 5080               0               1     1148776  Arjun Tendulkar
# 5081               2               2     1148776  Arjun Tendulkar
# 5082               3               3     1148776  Arjun Tendulkar
# 5083               0               1     1148776  Arjun Tendulkar
# 5084               3               4     1148776  Arjun Tendulkar
# ...              ...             ...         ...              ...
# 15196             88              44      236779    Ishant Sharma
# 15197             94              46      236779    Ishant Sharma
# 15198             94              45      236779    Ishant Sharma
# 15199             94              47      236779    Ishant Sharma
# 15200             94              48      236779    Ishant Sharma
#
#        bowler1_overs  bowler1_maidens  bowler1_runs  bowler1_wkts batsman2_id  \
# 5080             0.1                0             0             0     1048813
# 5081             0.2                0             2             0     1048813
# 5082             0.3                0             3             0     1048813
# 5083             0.4                0             3             0      974087
# 5084             0.5                0             3             0     1048813
# ...              ...              ...           ...           ...         ...
# 15196            2.3                0            29             1     1064812
# 15197            2.4                0            36             1     1064812
# 15198            2.3                0            36             1     1064812
# 15199            2.5                0            36             1     1064812
# 15200            3.0                0            36             2     1064812
#
#             batsman2_name  batsman2_runs  batsman2_balls  bowler2_id  \
# 5080   Narayan Jagadeesan              0               0         NaN
# 5081   Narayan Jagadeesan              0               0         NaN
# 5082   Narayan Jagadeesan              0               0         NaN
# 5083   Rahmanullah Gurbaz              3               3         NaN
# 5084   Narayan Jagadeesan              0               1         NaN
# ...                   ...            ...             ...         ...
# 15196        Rahul Chahar              0               0    481979.0
# 15197        Rahul Chahar              0               0    481979.0
# 15198        Rahul Chahar              0               0    481979.0
# 15199        Rahul Chahar              0               0    481979.0
# 15200        Rahul Chahar              0               0    481979.0
#
#         bowler2_name  bowler2_overs  bowler2_maidens  bowler2_runs  \
# 5080             NaN            NaN              NaN           NaN
# 5081             NaN            NaN              NaN           NaN
# 5082             NaN            NaN              NaN           NaN
# 5083             NaN            NaN              NaN           NaN
# 5084             NaN            NaN              NaN           NaN
# ...              ...            ...              ...           ...
# 15196  Anrich Nortje            4.0              0.0          36.0
# 15197  Anrich Nortje            4.0              0.0          36.0
# 15198  Anrich Nortje            4.0              0.0          36.0
# 15199  Anrich Nortje            4.0              0.0          36.0
# 15200  Anrich Nortje            4.0              0.0          36.0
#
#        bowler2_wkts  wicket_id  wkt_batsman_name wkt_bowler_name  \
# 5080            NaN        NaN               NaN             NaN
# 5081            NaN        NaN               NaN             NaN
# 5082            NaN        NaN               NaN             NaN
# 5083            NaN        NaN               NaN             NaN
# 5084            NaN        NaN               NaN             NaN
# ...             ...        ...               ...             ...
# 15196           2.0        NaN               NaN             NaN
# 15197           2.0        NaN               NaN             NaN
# 15198           2.0        NaN               NaN             NaN
# 15199           2.0        NaN               NaN             NaN
# 15200           2.0   403902.0  Liam Livingstone   Ishant Sharma
#
#        wkt_batsman_runs  wkt_batsman_balls  \
# 5080                NaN                NaN
# 5081                NaN                NaN
# 5082                NaN                NaN
# 5083                NaN                NaN
# 5084                NaN                NaN
# ...                 ...                ...
# 15196               NaN                NaN
# 15197               NaN                NaN
# 15198               NaN                NaN
# 15199               NaN                NaN
# 15200              94.0               48.0
#
#                                                 wkt_text  isRetiredHurt
# 5080                                                 NaN          False
# 5081                                                 NaN          False
# 5082                                                 NaN          False
# 5083                                                 NaN          False
# 5084                                                 NaN          False
# ...                                                  ...            ...
# 15196                                                NaN          False
# 15197                                                NaN          False
# 15198                                                NaN          False
# 15199                                                NaN          False
# 15200  LS Livingstone c Patel b Sharma 94 (69m 48b 5x...          False
#
# [483 rows x 41 columns]

# %%
df.loc[(df['match_id'].isin([1359496,1359538])) & (df['season'].isnull()), 'season'] = 2023

# %%
df.isnull().sum()
# Out:
# season                    0
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# shortText                 0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# bowler2_runs          12841
# bowler2_wkts          12841
# wicket_id            230670
# wkt_batsman_name     230670
# wkt_bowler_name      230670
# wkt_batsman_runs     230670
# wkt_batsman_balls    230670
# wkt_text             230670
# isRetiredHurt             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#        season  match_id match_name home_team away_team current_innings  \
# 13082  2023.0   1359530   KKR v RR       KKR        RR             KKR
#
#        innings_id  over  ball  runs                shortText  isBoundary  \
# 13082           1     1     1     2  Boult to JJ Roy, 2 runs       False
#
#        isWide  isNoball  batsman1_id batsman1_name  batsman1_runs  \
# 13082   False     False       298438     Jason Roy              2
#
#        batsman1_balls  bowler1_id bowler1_name  bowler1_overs  \
# 13082               1      277912  Trent Boult            0.1
#
#        bowler1_maidens  bowler1_runs  bowler1_wkts batsman2_id  \
# 13082                0             2             0      974087
#
#             batsman2_name  batsman2_runs  batsman2_balls  bowler2_id  \
# 13082  Rahmanullah Gurbaz              0               0         NaN
#
#       bowler2_name  bowler2_overs  bowler2_maidens  bowler2_runs  \
# 13082          NaN            NaN              NaN           NaN
#
#        bowler2_wkts  wicket_id wkt_batsman_name wkt_bowler_name  \
# 13082           NaN        NaN              NaN             NaN
#
#        wkt_batsman_runs  wkt_batsman_balls wkt_text  isRetiredHurt
# 13082               NaN                NaN      NaN          False

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby(['season'])['match_id'].nunique().sum()
# Out:
# np.int64(1023)

# %%
print(plt.style.available)
plt.style.use('fivethirtyeight')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import warnings
warnings.filterwarnings('ignore')

matches_per_season = df.groupby(['season'])['match_id'].nunique().sort_values(ascending=False).reset_index()
plt.figure(figsize=(10, 6))
palette=sns.color_palette('viridis',n_colors=len(matches_per_season))

bargraph=sns.barplot(x='season', y='match_id', data=matches_per_season, palette=palette,order=matches_per_season['season'])

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom' ,
        fontsize= 9
    )


plt.title('Number of Matches Played in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Number of Matches', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

total_runs_per_season = df.groupby(['season'])['runs'].sum().sort_values(ascending=False).reset_index()

print(total_runs_per_season)

plt.figure(figsize=(10, 6))

palette = sns.color_palette('viridis', n_colors=len(total_runs_per_season))
bargraph = sns.barplot(x='season', y='runs', data=total_runs_per_season,  order=total_runs_per_season['season'],palette=palette)

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Runs Scored in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Runs', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
#     season   runs
# 0   2023.0  25310
# 1   2022.0  24184
# 2   2013.0  22463
# 3   2012.0  22357
# 4   2011.0  21087
# 5   2018.0  19781
# 6   2019.0  19343
# 7   2020.0  19244
# 8   2014.0  18827
# 9   2016.0  18798
# 10  2010.0  18726
# 11  2017.0  18698
# 12  2021.0  18508
# 13  2015.0  18211
# 14  2008.0  17875
# 15  2009.0  16243

# %%
wickets_per_season = df.groupby(['season'])['wicket_id'].count().sort_values(ascending=False).reset_index()
print(wickets_per_season)
print()
plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='wicket_id', data=wickets_per_season, 
                        order=wickets_per_season['season'], palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Wickets Taken in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Wickets', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
#     season  wicket_id
# 0   2013.0        903
# 1   2023.0        890
# 2   2022.0        887
# 3   2012.0        850
# 4   2011.0        804
# 5   2018.0        715
# 6   2021.0        708
# 7   2010.0        708
# 8   2017.0        705
# 9   2009.0        687
# 10  2008.0        683
# 11  2015.0        677
# 12  2019.0        675
# 13  2014.0        664
# 14  2016.0        663
# 15  2020.0        661

# %%
boundaries_per_season = df.groupby(['season'])['isBoundary'].sum().sort_values(ascending=False).reset_index()

print(boundaries_per_season)
plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='isBoundary', data=boundaries_per_season, 
                        order=boundaries_per_season['season'], palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Boundaries Hit in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Boundaries', fontsize=10)

plt.xticks(rotation=45
plt.tight_layout()
plt.show()
# Out:
#     season  isBoundary
# 0   2023.0        3260
# 1   2022.0        3053
# 2   2013.0        2714
# 3   2012.0        2628
# 4   2011.0        2547
# 5   2018.0        2505
# 6   2019.0        2429
# 7   2008.0        2320
# 8   2020.0        2308
# 9   2017.0        2305
# 10  2015.0        2285
# 11  2010.0        2272
# 12  2014.0        2264
# 13  2016.0        2261
# 14  2021.0        2219
# 15  2009.0        1816

# %%
noballs_per_season = df.groupby(['season'])['isNoball'].sum().sort_values(ascending=False).reset_index()

print(noballs_per_season)

plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='isNoball', data=noballs_per_season, 
                        order=noballs_per_season['season'], palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total No-Balls Bowled in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total No-Balls', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
#     season  isNoball
# 0   2023.0        97
# 1   2011.0        83
# 2   2008.0        82
# 3   2021.0        76
# 4   2009.0        73
# 5   2022.0        71
# 6   2012.0        61
# 7   2010.0        60
# 8   2013.0        59
# 9   2019.0        59
# 10  2014.0        54
# 11  2020.0        52
# 12  2015.0        49
# 13  2016.0        48
# 14  2018.0        39
# 15  2017.0        38

# %%
wides_per_season = df.groupby(['season'])['isWide'].sum().sort_values(ascending=False).reset_index()

print(wides_per_season)

plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='isWide', data=wides_per_season, 
                        order=wides_per_season['season'], palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Wides Bowled in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Wides', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()
# Out:
#     season  isWide
# 0   2022.0     696
# 1   2023.0     615
# 2   2011.0     501
# 3   2012.0     497
# 4   2010.0     495
# 5   2013.0     476
# 6   2021.0     460
# 7   2008.0     457
# 8   2015.0     447
# 9   2020.0     446
# 10  2018.0     436
# 11  2009.0     434
# 12  2016.0     429
# 13  2017.0     418
# 14  2014.0     399
# 15  2019.0     395

# %%
total_unique_matches = df.groupby(['season'])['match_id'].nunique().sum()
print(total_unique_matches)
# Out:
# 1023

# %%
unique_teams_per_season = df.groupby(['season'])[['home_team', 'away_team']].nunique()
unique_teams_per_season
# Out:
#         home_team  away_team
# season
# 2008.0          8          8
# 2009.0          7          8
# 2010.0          8          8
# 2011.0         10         10
# 2012.0          9          9
# 2013.0          9          9
# 2014.0          8          8
# 2015.0          8          8
# 2016.0          8          8
# 2017.0          8          8
# 2018.0          8          8
# 2019.0          8          8
# 2020.0          8          8
# 2021.0          8          8
# 2022.0         10         10
# 2023.0         10         10

# %%
combined_teams = pd.concat([df[['season', 'home_team']].rename(columns={'home_team': 'team'}),
                            df[['season', 'away_team']].rename(columns={'away_team': 'team'})])


team_count_per_season = combined_teams.groupby('season')['team'].nunique().reset_index()
team_count_per_season
# Out:
#     season  team
# 0   2008.0     8
# 1   2009.0     8
# 2   2010.0     8
# 3   2011.0    10
# 4   2012.0     9
# 5   2013.0     9
# 6   2014.0     8
# 7   2015.0     8
# 8   2016.0     8
# 9   2017.0     8
# 10  2018.0     8
# 11  2019.0     8
# 12  2020.0     8
# 13  2021.0     8
# 14  2022.0    10
# 15  2023.0    10

# %%
df['home_team'][df['season']==2009].unique()
# Out:
# array(['CSK', 'RCB', 'DC', 'SRH', 'KXIP', 'KKR', 'MI'], dtype=object)

# %%
df['away_team'][df['season']==2009].unique()
# Out:
# array(['MI', 'RR', 'KXIP', 'KKR', 'CSK', 'SRH', 'DC', 'RCB'], dtype=object)

# %%
top_home_teams = df.groupby('home_team')['runs'].sum().sort_values(ascending=False).reset_index()

# Plotting the graph
plt.figure(figsize=(10, 6))
bargraph = sns.barplot(x='runs', y='home_team', data=top_home_teams, palette='viridis')

# Annotating the bars with values
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Home Teams by Total Runs Scored', fontsize=16)
plt.xlabel('Total Runs', fontsize=14)
plt.ylabel('Home Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
top_away_teams = df.groupby('away_team')['runs'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
bargraph = sns.barplot(x='runs', y='away_team', data=top_away_teams, palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Top 10 Away Teams by Total Runs Scored', fontsize=16)
plt.xlabel('Total Runs', fontsize=14)
plt.ylabel('Away Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_runs = df.groupby('home_team')['runs'].sum()
away_team_runs = df.groupby('away_team')['runs'].sum()

total_team_runs = home_team_runs.add(away_team_runs)

total_team_runs = total_team_runs.sort_values(ascending=False).reset_index()
total_team_runs.columns = ['Team', 'Total Runs']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Runs', y='Team', data=total_team_runs, palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Runs Scored by Each Team (Combined)', fontsize=16)
plt.xlabel('Total Runs', fontsize=14)
plt.ylabel('Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_wickets = df.groupby('home_team')['wicket_id'].count().sort_values(ascending=False).reset_index()
home_team_wickets.columns = ['Home Team', 'Total Wickets']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Wickets', y='Home Team', data=home_team_wickets, palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Wickets Taken by Each Home Team', fontsize=16)
plt.xlabel('Total Wickets', fontsize=14)
plt.ylabel('Home Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
away_team_wickets = df.groupby('away_team')['wicket_id'].count().sort_values(ascending=False).reset_index()
away_team_wickets.columns = ['Away Team', 'Total Wickets']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Wickets', y='Away Team', data=away_team_wickets, palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Wickets Taken by Each Away Team', fontsize=16)
plt.xlabel('Total Wickets', fontsize=14)
plt.ylabel('Away Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_wicks = df.groupby('home_team')['wicket_id'].count()

away_team_wicks = df.groupby('away_team')['wicket_id'].count()

total_team_wicks = home_team_wicks.add(away_team_wicks)

total_team_wicks = total_team_wicks.sort_values(ascending=False).reset_index()
total_team_wicks.columns = ['Team', 'Total Wickets']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Wickets', y='Team', data=total_team_wicks, palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Wickets Taken by Each Team (Home and Away)', fontsize=16)
plt.xlabel('Total Wickets', fontsize=14)
plt.ylabel('Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_boundaries = df.groupby('home_team')['isBoundary'].sum()

total_boundaries_home = home_team_boundaries.sort_values(ascending=False).reset_index()
total_boundaries_home.columns = ['Home Team', 'Total Boundaries']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Boundaries', y='Home Team', data=total_boundaries_home, palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Boundaries Scored by Each Home Team', fontsize=16)
plt.xlabel('Total Boundaries', fontsize=14)
plt.ylabel('Home Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
away_team_boundaries = df.groupby('away_team')['isBoundary'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=away_team_boundaries.values, y=away_team_boundaries.index, palette='viridis')

for index, value in enumerate(away_team_boundaries.values):
    barplot.annotate(
        f'{value}', 
        (value, index), 
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Boundaries Scored by Away Teams', fontsize=16)
plt.xlabel('Total Boundaries', fontsize=14)
plt.ylabel('Away Team', fontsize=14)

plt.tight_layout()
plt.show()

# %%
home_team_boundary = df.groupby('home_team')['isBoundary'].sum()
away_team_boundary = df.groupby('away_team')['isBoundary'].sum()

total_team_boundary = home_team_boundary.add(away_team_boundary).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=total_team_boundary.values, y=total_team_boundary.index, palette='viridis')

for index, value in enumerate(total_team_boundary.values):
    barplot.annotate(
        f'{value}', 
        (value, index), 
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Boundaries Scored by Each Team', fontsize=16)
plt.xlabel('Total Boundaries', fontsize=14)
plt.ylabel('Team', fontsize=14)

plt.tight_layout()
plt.show()

# %%
df.groupby('home_team')[['isWide', 'isNoball']].sum().sort_values(['isWide', 'isNoball'],ascending=False)
# Out:
#            isWide  isNoball
# home_team
# RCB           979       117
# MI            967       115
# CSK           915       142
# DC            902       118
# SRH           811       135
# KKR           787        96
# RR            737       107
# KXIP          658        69
# PBKS          177        25
# LSG           139        11
# PWI           137        26
# GT            134        19
# RPS           106         4
# GL            103         7
# Kochi          49        10

# %%
df.groupby('away_team')[['isWide', 'isNoball']].sum().sort_values(['isWide', 'isNoball'],ascending=False)
# Out:
#            isWide  isNoball
# away_team
# MI           1016       133
# KKR           917       135
# RR            851       113
# SRH           846        97
# RCB           837       132
# DC            793       114
# CSK           768        67
# KXIP          724        97
# PBKS          196        29
# LSG           132        19
# PWI           128        23
# RPS           120         9
# GT            112        10
# GL             98        15
# Kochi          63         8

# %%
home_team_extra =df.groupby('home_team')[['isWide', 'isNoball']].sum()
away_team_extra = df.groupby('away_team')[['isWide', 'isNoball']].sum()

total_team_extra = home_team_extra.add(away_team_extra)

total_team_extra = total_team_extra.sort_values('isWide',ascending=False)
total_team_extra
# Out:
#            isWide  isNoball
# home_team
# MI           1983       248
# RCB          1816       249
# KKR          1704       231
# DC           1695       232
# CSK          1683       209
# SRH          1657       232
# RR           1588       220
# KXIP         1382       166
# PBKS          373        54
# LSG           271        30
# PWI           265        49
# GT            246        29
# RPS           226        13
# GL            201        22
# Kochi         112        18

# %%
df.groupby('home_team')['match_id'].nunique().sort_values(ascending=False)
# Out:
# home_team
# CSK      123
# DC       123
# SRH      122
# RCB      122
# MI       118
# KKR      114
# RR        96
# KXIP      93
# PWI       23
# PBKS      20
# GT        18
# LSG       15
# GL        15
# RPS       14
# Kochi      7
# Name: match_id, dtype: int64

# %%
df.groupby('away_team')['match_id'].nunique().sort_values(ascending=False)
# Out:
# away_team
# MI       129
# KKR      123
# SRH      119
# RCB      118
# DC       115
# RR       110
# CSK      100
# KXIP      97
# PWI       23
# PBKS      22
# RPS       16
# GL        15
# GT        15
# LSG       14
# Kochi      7
# Name: match_id, dtype: int64

# %%
home_matches = df.groupby('home_team')['match_id'].nunique()
away_matches = df.groupby('away_team')['match_id'].nunique()

total_matches = home_matches.add(away_matches, fill_value=0)

total_matches = total_matches.sort_values(ascending=False)

print(total_matches)
# Out:
# home_team
# MI       247
# SRH      241
# RCB      240
# DC       238
# KKR      237
# CSK      223
# RR       206
# KXIP     190
# PWI       46
# PBKS      42
# GT        33
# RPS       30
# GL        30
# LSG       29
# Kochi     14
# Name: match_id, dtype: int64

# %%
df.groupby('batsman1_name')['runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Virat Kohli       7513
# Shikhar Dhawan    6948
# David Warner      6722
# Rohit Sharma      6414
# Suresh Raina      5762
# AB de Villiers    5312
# Chris Gayle       5296
# MS Dhoni          5245
# Robin Uthappa     5237
# Dinesh Karthik    4692
# Name: runs, dtype: int64

# %%
df.groupby('batsman1_name')['isBoundary'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Shikhar Dhawan    896
# Virat Kohli       876
# David Warner      872
# Rohit Sharma      808
# Chris Gayle       760
# Suresh Raina      708
# Robin Uthappa     662
# AB de Villiers    661
# MS Dhoni          575
# Dinesh Karthik    575
# Name: isBoundary, dtype: int64

# %%
df.groupby('batsman1_name')['ball'].count().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Virat Kohli       5726
# Shikhar Dhawan    5353
# Rohit Sharma      4880
# David Warner      4713
# Suresh Raina      4170
# Robin Uthappa     3921
# MS Dhoni          3829
# Ajinkya Rahane    3653
# Gautam Gambhir    3524
# Chris Gayle       3498
# Name: ball, dtype: int64

# %%
df.groupby('batsman1_name')['isRetiredHurt'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Sachin Tendulkar    2
# Shikhar Dhawan      2
# Krunal Pandya       1
# Aaron Finch         1
# Kevin Pietersen     1
# Dominic Thornely    1
# Harbhajan Singh     1
# Liam Livingstone    1
# Jaskaran Singh      1
# Ambati Rayudu       1
# Name: isRetiredHurt, dtype: int64

# %%
h=df[['match_id','innings_id','batsman1_name','batsman1_runs']][df['batsman1_runs']>= 100]
h
# Out:
#         match_id  innings_id     batsman1_name  batsman1_runs
# 4459     1359493           1       Harry Brook            100
# 5184     1359496           1    Venkatesh Iyer            100
# 5187     1359496           1    Venkatesh Iyer            104
# 5188     1359496           1    Venkatesh Iyer            104
# 10080    1359516           1  Yashasvi Jaiswal            100
# ...          ...         ...               ...            ...
# 241732    336019           1       Shaun Marsh            110
# 241733    336019           1       Shaun Marsh            111
# 241735    336019           1       Shaun Marsh            115
# 241736    336019           1       Shaun Marsh            115
# 241737    336019           1       Shaun Marsh            115
#
# [479 rows x 4 columns]

# %%
h.groupby(['match_id','innings_id','batsman1_name'])['batsman1_runs'].max()
# Out:
# match_id  innings_id  batsman1_name
# 335982    1           Brendon McCullum     158
# 335983    1           Michael Hussey       116
# 335990    1           Andrew Symonds       117
# 335994    2           Adam Gilchrist       109
# 336018    2           Sanath Jayasuriya    114
#                                           ...
# 1359539   2           Virat Kohli          100
# 1359543   2           Cameron Green        100
# 1359544   1           Virat Kohli          101
#           2           Shubman Gill         104
# 1370352   1           Shubman Gill         129
# Name: batsman1_runs, Length: 85, dtype: int64

# %%
a=h.groupby(['match_id','batsman1_name',])['batsman1_runs'].max().sort_values(ascending=False).reset_index()
a
# Out:
#     match_id     batsman1_name  batsman1_runs
# 0     598027       Chris Gayle            174
# 1     335982  Brendon McCullum            158
# 2    1304112   Quinton de Kock            140
# 3     829795    AB de Villiers            133
# 4    1216510          KL Rahul            132
# ..       ...               ...            ...
# 80   1178410       Virat Kohli            100
# 81   1304055       Jos Buttler            100
# 82   1359493       Harry Brook            100
# 83   1359539       Virat Kohli            100
# 84   1359543     Cameron Green            100
#
# [85 rows x 3 columns]

# %%
a['batsman1_name'].value_counts()
# Out:
# batsman1_name
# Virat Kohli           7
# Chris Gayle           6
# Jos Buttler           5
# David Warner          4
# Shane Watson          4
# KL Rahul              4
# Shubman Gill          3
# Sanju Samson          3
# AB de Villiers        3
# Quinton de Kock       2
# Virender Sehwag       2
# Adam Gilchrist        2
# Ajinkya Rahane        2
# Shikhar Dhawan        2
# Murali Vijay          2
# Ben Stokes            2
# Hashim Amla           2
# Brendon McCullum      1
# Rishabh Pant          1
# Andrew Symonds        1
# Paul Valthaty         1
# Wriddhiman Saha       1
# Michael Hussey        1
# Manish Pandey         1
# Sanath Jayasuriya     1
# Jonny Bairstow        1
# Shaun Marsh           1
# Rohit Sharma          1
# Mahela Jayawardene    1
# Rajat Patidar         1
# Yashasvi Jaiswal      1
# Mayank Agarwal        1
# Venkatesh Iyer        1
# Heinrich Klaasen      1
# Kevin Pietersen       1
# Suryakumar Yadav      1
# Prabhsimran Singh     1
# Steven Smith          1
# David Miller          1
# Devdutt Padikkal      1
# Ruturaj Gaikwad       1
# Yusuf Pathan          1
# Suresh Raina          1
# Lendl Simmons         1
# Ambati Rayudu         1
# Harry Brook           1
# Cameron Green         1
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby('bowler1_name')['wicket_id'].count().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Dwayne Bravo           200
# Yuzvendra Chahal       194
# Piyush Chawla          188
# Ravichandran Ashwin    188
# Lasith Malinga         186
# Amit Mishra            182
# Bhuvneshwar Kumar      182
# Sunil Narine           182
# Harbhajan Singh        161
# Ravindra Jadeja        160
# Name: wicket_id, dtype: int64

# %%
df.groupby('bowler1_name')['isNoball'].sum().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Jasprit Bumrah     27
# Umesh Yadav        24
# Sreesanth          23
# Ishant Sharma      22
# Amit Mishra        21
# Lasith Malinga     18
# Prasidh Krishna    17
# Ashok Dinda        14
# Harshal Patel      14
# Brett Lee          13
# Name: isNoball, dtype: int64

# %%
df.groupby('bowler1_name')['isWide'].sum().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Dwayne Bravo           166
# Ravichandran Ashwin    134
# Lasith Malinga         127
# Bhuvneshwar Kumar      123
# Praveen Kumar          111
# Umesh Yadav            106
# Shardul Thakur          98
# Shane Watson            95
# Dale Steyn              93
# Mohammed Siraj          89
# Name: isWide, dtype: int64

# %%
df.groupby('bowler1_name')['isBoundary'].sum().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Umesh Yadav            581
# Bhuvneshwar Kumar      570
# Piyush Chawla          562
# Dwayne Bravo           494
# Mohammed Shami         484
# Ravichandran Ashwin    472
# Ravindra Jadeja        461
# Sandeep Sharma         452
# Praveen Kumar          441
# Harbhajan Singh        441
# Name: isBoundary, dtype: int64

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby('batsman1_name')['isBoundary'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Shikhar Dhawan    896
# Virat Kohli       876
# David Warner      872
# Rohit Sharma      808
# Chris Gayle       760
# Suresh Raina      708
# Robin Uthappa     662
# AB de Villiers    661
# MS Dhoni          575
# Dinesh Karthik    575
# Name: isBoundary, dtype: int64

# %%
df.groupby('bowler1_name')['isNoball'].sum().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Jasprit Bumrah     27
# Umesh Yadav        24
# Sreesanth          23
# Ishant Sharma      22
# Amit Mishra        21
# Lasith Malinga     18
# Prasidh Krishna    17
# Ashok Dinda        14
# Harshal Patel      14
# Brett Lee          13
# Name: isNoball, dtype: int64

# %%
df[['match_id','bowler1_name','bowler1_maidens']].sort_values('bowler1_maidens',ascending=False).head(20)
# Out:
#        match_id    bowler1_name  bowler1_maidens
# 18938   1304052   Harshal Patel                2
# 18939   1304052   Harshal Patel                2
# 18940   1304052   Harshal Patel                2
# 18941   1304052   Harshal Patel                2
# 59031   1216494  Mohammed Siraj                2
# 59120   1216494  Mohammed Siraj                2
# 59121   1216494  Mohammed Siraj                2
# 59116   1216494  Mohammed Siraj                2
# 59117   1216494  Mohammed Siraj                2
# 59041   1216494  Mohammed Siraj                2
# 59042   1216494  Mohammed Siraj                2
# 18926   1304052   Harshal Patel                2
# 18927   1304052   Harshal Patel                2
# 18928   1304052   Harshal Patel                2
# 18929   1304052   Harshal Patel                2
# 18917   1304052   Harshal Patel                2
# 59043   1216494  Mohammed Siraj                2
# 59038   1216494  Mohammed Siraj                2
# 59039   1216494  Mohammed Siraj                2
# 59040   1216494  Mohammed Siraj                2

# %%
a=df[df['bowler1_maidens'] != 0]
a.head(20)
# Out:
#       season  match_id match_name home_team away_team current_innings  \
# 842   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 849   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 850   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 851   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 852   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 853   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 854   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 861   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 862   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 863   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 864   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 865   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 866   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 950   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 951   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 952   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 953   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 954   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 955   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 1953  2023.0   1359483  KKR v RCB       KKR       RCB             KKR
#
#       innings_id  over  ball  runs                     shortText  isBoundary  \
# 842            2     1     6     0        Boult to Brook, no run       False
# 849            2     3     1     0      Boult to Agarwal, no run       False
# 850            2     3     2     0      Boult to Agarwal, no run       False
# 851            2     3     3     4        Boult to Agarwal, FOUR        True
# 852            2     3     4     1       Boult to Agarwal, 1 run       False
# 853            2     3     5     0        Boult to Brook, no run       False
# 854            2     3     6     0        Boult to Brook, no run       False
# 861            2     5     1     1       Boult to Agarwal, 1 run       False
# 862            2     5     2     0        Boult to Brook, no run       False
# 863            2     5     3     0        Boult to Brook, no run       False
# 864            2     5     4     0        Boult to Brook, no run       False
# 865            2     5     5     1         Boult to Brook, 1 run       False
# 866            2     5     6     1       Boult to Agarwal, 1 run       False
# 950            2    19     1     1   Boult to Abdul Samad, 1 run       False
# 951            2    19     2     0  Boult to Umran Malik, no run       False
# 952            2    19     3     0  Boult to Umran Malik, no run       False
# 953            2    19     4     4    Boult to Umran Malik, FOUR        True
# 954            2    19     5     6     Boult to Umran Malik, SIX        True
# 955            2    19     6     2  Boult to Umran Malik, 2 runs       False
# 1953           1     4     6     0        Willey to Rana, no run       False
#
#       isWide  isNoball  batsman1_id   batsman1_name  batsman1_runs  \
# 842    False     False       911707     Harry Brook              0
# 849    False     False       398438  Mayank Agarwal              3
# 850    False     False       398438  Mayank Agarwal              3
# 851    False     False       398438  Mayank Agarwal              7
# 852    False     False       398438  Mayank Agarwal              8
# 853    False     False       911707     Harry Brook              4
# 854    False     False       911707     Harry Brook              4
# 861    False     False       398438  Mayank Agarwal             14
# 862    False     False       911707     Harry Brook              4
# 863    False     False       911707     Harry Brook              4
# 864    False     False       911707     Harry Brook              4
# 865    False     False       911707     Harry Brook              5
# 866    False     False       398438  Mayank Agarwal             15
# 950    False     False      1175485     Abdul Samad             17
# 951    False     False      1246528     Umran Malik              0
# 952    False     False      1246528     Umran Malik              0
# 953    False     False      1246528     Umran Malik              4
# 954    False     False      1246528     Umran Malik             10
# 955    False     False      1246528     Umran Malik             12
# 1953   False     False       604527     Nitish Rana              0
#
#       batsman1_balls  bowler1_id  bowler1_name  bowler1_overs  \
# 842                1      277912   Trent Boult            1.0
# 849                3      277912   Trent Boult            1.1
# 850                4      277912   Trent Boult            1.2
# 851                5      277912   Trent Boult            1.3
# 852                6      277912   Trent Boult            1.4
# 853                6      277912   Trent Boult            1.5
# 854                7      277912   Trent Boult            2.0
# 861               11      277912   Trent Boult            2.1
# 862               10      277912   Trent Boult            2.2
# 863               11      277912   Trent Boult            2.3
# 864               12      277912   Trent Boult            2.4
# 865               13      277912   Trent Boult            2.5
# 866               12      277912   Trent Boult            3.0
# 950               27      277912   Trent Boult            3.1
# 951                2      277912   Trent Boult            3.2
# 952                3      277912   Trent Boult            3.3
# 953                4      277912   Trent Boult            3.4
# 954                5      277912   Trent Boult            3.5
# 955                6      277912   Trent Boult            4.0
# 1953               3      308251  David Willey            2.0
#
#       bowler1_maidens  bowler1_runs  bowler1_wkts batsman2_id  \
# 842                 1             0             2      398438
# 849                 1             0             2      911707
# 850                 1             0             2      911707
# 851                 1             4             2      911707
# 852                 1             5             2      911707
# 853                 1             5             2      398438
# 854                 1             5             2      398438
# 861                 1             6             2      911707
# 862                 1             6             2      398438
# 863                 1             6             2      398438
# 864                 1             6             2      398438
# 865                 1             7             2      398438
# 866                 1             8             2      911707
# 950                 1             9             2     1246528
# 951                 1             9             2     1175485
# 952                 1             9             2     1175485
# 953                 1            13             2     1175485
# 954                 1            19             2     1175485
# 955                 1            21             2     1175485
# 1953                1             3             2      974087
#
#            batsman2_name  batsman2_runs  batsman2_balls  bowler2_id  \
# 842       Mayank Agarwal              0               0         NaN
# 849          Harry Brook              4               5   1083030.0
# 850          Harry Brook              4               5   1083030.0
# 851          Harry Brook              4               5   1083030.0
# 852          Harry Brook              4               5   1083030.0
# 853       Mayank Agarwal              8               6   1083030.0
# 854       Mayank Agarwal              8               6   1083030.0
# 861          Harry Brook              4               9    391485.0
# 862       Mayank Agarwal             14              11    391485.0
# 863       Mayank Agarwal             14              11    391485.0
# 864       Mayank Agarwal             14              11    391485.0
# 865       Mayank Agarwal             14              11    391485.0
# 866          Harry Brook              5              13    391485.0
# 950          Umran Malik              0               1    430246.0
# 951          Abdul Samad             17              27    430246.0
# 952          Abdul Samad             17              27    430246.0
# 953          Abdul Samad             17              27    430246.0
# 954          Abdul Samad             17              27    430246.0
# 955          Abdul Samad             17              27    430246.0
# 1953  Rahmanullah Gurbaz             13              13    940973.0
#
#           bowler2_name  bowler2_overs  bowler2_maidens  bowler2_runs  \
# 842                NaN            NaN              NaN           NaN
# 849            KM Asif            1.0              0.0           7.0
# 850            KM Asif            1.0              0.0           7.0
# 851            KM Asif            1.0              0.0           7.0
# 852            KM Asif            1.0              0.0           7.0
# 853            KM Asif            1.0              0.0           7.0
# 854            KM Asif            1.0              0.0           7.0
# 861       Jason Holder            1.0              0.0           5.0
# 862       Jason Holder            1.0              0.0           5.0
# 863       Jason Holder            1.0              0.0           5.0
# 864       Jason Holder            1.0              0.0           5.0
# 865       Jason Holder            1.0              0.0           5.0
# 866       Jason Holder            1.0              0.0           5.0
# 950   Yuzvendra Chahal            4.0              0.0          17.0
# 951   Yuzvendra Chahal            4.0              0.0          17.0
# 952   Yuzvendra Chahal            4.0              0.0          17.0
# 953   Yuzvendra Chahal            4.0              0.0          17.0
# 954   Yuzvendra Chahal            4.0              0.0          17.0
# 955   Yuzvendra Chahal            4.0              0.0          17.0
# 1953    Mohammed Siraj            2.0              0.0          19.0
#
#       bowler2_wkts  wicket_id wkt_batsman_name wkt_bowler_name  \
# 842            NaN        NaN              NaN             NaN
# 849            0.0        NaN              NaN             NaN
# 850            0.0        NaN              NaN             NaN
# 851            0.0        NaN              NaN             NaN
# 852            0.0        NaN              NaN             NaN
# 853            0.0        NaN              NaN             NaN
# 854            0.0        NaN              NaN             NaN
# 861            0.0        NaN              NaN             NaN
# 862            0.0        NaN              NaN             NaN
# 863            0.0        NaN              NaN             NaN
# 864            0.0        NaN              NaN             NaN
# 865            0.0        NaN              NaN             NaN
# 866            0.0        NaN              NaN             NaN
# 950            4.0        NaN              NaN             NaN
# 951            4.0        NaN              NaN             NaN
# 952            4.0        NaN              NaN             NaN
# 953            4.0        NaN              NaN             NaN
# 954            4.0        NaN              NaN             NaN
# 955            4.0        NaN              NaN             NaN
# 1953           0.0        NaN              NaN             NaN
#
#       wkt_batsman_runs  wkt_batsman_balls wkt_text  isRetiredHurt
# 842                NaN                NaN      NaN          False
# 849                NaN                NaN      NaN          False
# 850                NaN                NaN      NaN          False
# 851                NaN                NaN      NaN          False
# 852                NaN                NaN      NaN          False
# 853                NaN                NaN      NaN          False
# 854                NaN                NaN      NaN          False
# 861                NaN                NaN      NaN          False
# 862                NaN                NaN      NaN          False
# 863                NaN                NaN      NaN          False
# 864                NaN                NaN      NaN          False
# 865                NaN                NaN      NaN          False
# 866                NaN                NaN      NaN          False
# 950                NaN                NaN      NaN          False
# 951                NaN                NaN      NaN          False
# 952                NaN                NaN      NaN          False
# 953                NaN                NaN      NaN          False
# 954                NaN                NaN      NaN          False
# 955                NaN                NaN      NaN          False
# 1953               NaN                NaN      NaN          False

# %%
a.groupby(['match_id','bowler1_name'])['bowler1_maidens'].sum().sort_values(ascending=False).head(10)
# Out:
# match_id  bowler1_name
# 1304052   Harshal Patel          32
# 1216494   Mohammed Siraj         32
# 392237    Ryan Harris            21
# 1304088   Mohsin Khan            21
# 419165    Ravichandran Ashwin    21
# 1216523   Arshdeep Singh         21
# 548336    Kevon Cooper           21
# 1178401   Ishant Sharma          21
# 598065    James Faulkner         21
# 548372    Umesh Yadav            21
# Name: bowler1_maidens, dtype: int64

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby(['season'])['match_id'].nunique()
# Out:
# season
# 2008.0    58
# 2009.0    57
# 2010.0    60
# 2011.0    73
# 2012.0    74
# 2013.0    76
# 2014.0    60
# 2015.0    59
# 2016.0    60
# 2017.0    59
# 2018.0    60
# 2019.0    60
# 2020.0    60
# 2021.0    60
# 2022.0    74
# 2023.0    73
# Name: match_id, dtype: int64

# %%
# Out:
# Python 3.12.4
