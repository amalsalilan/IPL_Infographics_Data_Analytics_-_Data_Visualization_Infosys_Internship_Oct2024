# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import warnings

# %%
df= pd.read_csv('all_season_details_data.csv')
df
# Out:
# C:\Users\govinda prasad\AppData\Local\Temp\ipykernel_32824\1911132140.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('all_season_details_data.csv')
#         season  match_id match_name home_team away_team current_innings  \
# 0       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4       2023.0   1359475   GT v CSK        GT       CSK             CSK
# ...        ...       ...        ...       ...       ...             ...
# 242544  2008.0    336040   CSK v RR       CSK        RR              RR
# 242545  2008.0    336040   CSK v RR       CSK        RR              RR
# 242546  2008.0    336040   CSK v RR       CSK        RR              RR
# ...

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#         season  match_id match_name home_team away_team current_innings  \
# 0       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4       2023.0   1359475   GT v CSK        GT       CSK             CSK
# ...        ...       ...        ...       ...       ...             ...
# 242544  2008.0    336040   CSK v RR       CSK        RR              RR
# 242545  2008.0    336040   CSK v RR       CSK        RR              RR
# 242546  2008.0    336040   CSK v RR       CSK        RR              RR
# 242547  2008.0    336040   CSK v RR       CSK        RR              RR
# 242548  2008.0    336040   CSK v RR       CSK        RR              RR
#
#         innings_id  over  ball  runs  isBoundary  isWide  isNoball  \
# ...

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'isBoundary',
#        'isWide', 'isNoball', 'batsman1_id', 'batsman1_name', 'batsman1_runs',
#        'batsman1_balls', 'bowler1_id', 'bowler1_name', 'bowler1_overs',
#        'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts', 'batsman2_id',
#        'batsman2_name', 'batsman2_runs', 'batsman2_balls', 'bowler2_id',
#        'bowler2_name', 'bowler2_overs', 'bowler2_maidens', 'bowler2_runs',
#        'bowler2_wkts', 'wicket_id', 'wkt_batsman_name', 'wkt_bowler_name',
#        'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby(['season'])['match_id'].nunique().sum()
# Out:
# np.int64(1023)

# %%
print(plt.style.available)
plt.style.use('fivethirtyeight')
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
import warnings
warnings.filterwarnings('ignore')

matches_per_season = df.groupby(['season'])['match_id'].nunique().sort_values(ascending=False).reset_index()
plt.figure(figsize=(10, 6))
palette=sns.color_palette('viridis',n_colors=len(matches_per_season))

bargraph=sns.barplot(x='season', y='match_id', data=matches_per_season, palette=palette,order=matches_per_season['season'])

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom' ,
        fontsize= 9
    )


plt.title('Number of Matches Played in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Number of Matches', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

total_runs_per_season = df.groupby(['season'])['runs'].sum().sort_values(ascending=False).reset_index()

print(total_runs_per_season)

plt.figure(figsize=(10, 6))

palette = sns.color_palette('viridis', n_colors=len(total_runs_per_season))
bargraph = sns.barplot(x='season', y='runs', data=total_runs_per_season,  order=total_runs_per_season['season'],palette=palette)

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Runs Scored in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Runs', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
#     season   runs
# 0   2023.0  25310
# 1   2022.0  24184
# 2   2013.0  22463
# 3   2012.0  22357
# 4   2011.0  21087
# 5   2018.0  19781
# 6   2019.0  19343
# 7   2020.0  19244
# 8   2014.0  18827
# 9   2016.0  18798
# 10  2010.0  18726
# 11  2017.0  18698
# 12  2021.0  18508
# 13  2015.0  18211
# 14  2008.0  17875
# 15  2009.0  16243

# %%
wickets_per_season = df.groupby(['season'])['wicket_id'].count().sort_values(ascending=False).reset_index()
print(wickets_per_season)
print()
plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='wicket_id', data=wickets_per_season, 
                        order=wickets_per_season['season'], palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Wickets Taken in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Wickets', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
#     season  wicket_id
# 0   2013.0        903
# 1   2023.0        890
# 2   2022.0        887
# 3   2012.0        850
# 4   2011.0        804
# 5   2018.0        715
# 6   2021.0        708
# 7   2010.0        708
# 8   2017.0        705
# 9   2009.0        687
# 10  2008.0        683
# 11  2015.0        677
# 12  2019.0        675
# 13  2014.0        664
# 14  2016.0        663
# 15  2020.0        661

# %%
boundaries_per_season = df.groupby(['season'])['isBoundary'].sum().sort_values(ascending=False).reset_index()

print(boundaries_per_season)
plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='isBoundary', data=boundaries_per_season, 
                        order=boundaries_per_season['season'], palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Boundaries Hit in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Boundaries', fontsize=10)

plt.xticks(rotation=45
plt.tight_layout()
plt.show()
# Out:
#   Cell In[23], line 22
#     plt.xticks(rotation=45
#               ^
# SyntaxError: '(' was never closed

# %%
noballs_per_season = df.groupby(['season'])['isNoball'].sum().sort_values(ascending=False).reset_index()

print(noballs_per_season)

plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='isNoball', data=noballs_per_season, 
                        order=noballs_per_season['season'], palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total No-Balls Bowled in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total No-Balls', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
#     season  isNoball
# 0   2023.0        97
# 1   2011.0        83
# 2   2008.0        82
# 3   2021.0        76
# 4   2009.0        73
# 5   2022.0        71
# 6   2012.0        61
# 7   2010.0        60
# 8   2013.0        59
# 9   2019.0        59
# 10  2014.0        54
# 11  2020.0        52
# 12  2015.0        49
# 13  2016.0        48
# 14  2018.0        39
# 15  2017.0        38

# %%
wides_per_season = df.groupby(['season'])['isWide'].sum().sort_values(ascending=False).reset_index()

print(wides_per_season)

plt.figure(figsize=(10, 6))

bargraph = sns.barplot(x='season', y='isWide', data=wides_per_season, 
                        order=wides_per_season['season'], palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

plt.title('Total Wides Bowled in Each IPL Season', fontsize=16)
plt.xlabel('Season', fontsize=10)
plt.ylabel('Total Wides', fontsize=10)

plt.xticks(rotation=45)

plt.tight_layout()

plt.show()
# Out:
#     season  isWide
# 0   2022.0     696
# 1   2023.0     615
# 2   2011.0     501
# 3   2012.0     497
# 4   2010.0     495
# 5   2013.0     476
# 6   2021.0     460
# 7   2008.0     457
# 8   2015.0     447
# 9   2020.0     446
# 10  2018.0     436
# 11  2009.0     434
# 12  2016.0     429
# 13  2017.0     418
# 14  2014.0     399
# 15  2019.0     395

# %%
total_unique_matches = df.groupby(['season'])['match_id'].nunique().sum()
print(total_unique_matches)
# Out:
# 1023

# %%
unique_teams_per_season = df.groupby(['season'])[['home_team', 'away_team']].nunique()
unique_teams_per_season
# Out:
#         home_team  away_team
# season
# 2008.0          8          8
# 2009.0          7          8
# 2010.0          8          8
# 2011.0         10         10
# 2012.0          9          9
# 2013.0          9          9
# 2014.0          8          8
# 2015.0          8          8
# 2016.0          8          8
# 2017.0          8          8
# 2018.0          8          8
# 2019.0          8          8
# 2020.0          8          8
# 2021.0          8          8
# 2022.0         10         10
# 2023.0         10         10

# %%
combined_teams = pd.concat([df[['season', 'home_team']].rename(columns={'home_team': 'team'}),
                            df[['season', 'away_team']].rename(columns={'away_team': 'team'})])


team_count_per_season = combined_teams.groupby('season')['team'].nunique().reset_index()
team_count_per_season
# Out:
#     season  team
# 0   2008.0     8
# 1   2009.0     8
# 2   2010.0     8
# 3   2011.0    10
# 4   2012.0     9
# 5   2013.0     9
# 6   2014.0     8
# 7   2015.0     8
# 8   2016.0     8
# 9   2017.0     8
# 10  2018.0     8
# 11  2019.0     8
# 12  2020.0     8
# 13  2021.0     8
# 14  2022.0    10
# 15  2023.0    10

# %%
df['home_team'][df['season']==2009].unique()
# Out:
# array(['CSK', 'RCB', 'DC', 'SRH', 'KXIP', 'KKR', 'MI'], dtype=object)

# %%
df['away_team'][df['season']==2009].unique()
# Out:
# array(['MI', 'RR', 'KXIP', 'KKR', 'CSK', 'SRH', 'DC', 'RCB'], dtype=object)

# %%
top_home_teams = df.groupby('home_team')['runs'].sum().sort_values(ascending=False).reset_index()

# Plotting the graph
plt.figure(figsize=(10, 6))
bargraph = sns.barplot(x='runs', y='home_team', data=top_home_teams, palette='viridis')

# Annotating the bars with values
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Home Teams by Total Runs Scored', fontsize=16)
plt.xlabel('Total Runs', fontsize=14)
plt.ylabel('Home Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
top_away_teams = df.groupby('away_team')['runs'].sum().sort_values(ascending=False).reset_index()

plt.figure(figsize=(10, 6))
bargraph = sns.barplot(x='runs', y='away_team', data=top_away_teams, palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Top 10 Away Teams by Total Runs Scored', fontsize=16)
plt.xlabel('Total Runs', fontsize=14)
plt.ylabel('Away Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_runs = df.groupby('home_team')['runs'].sum()
away_team_runs = df.groupby('away_team')['runs'].sum()

total_team_runs = home_team_runs.add(away_team_runs)

total_team_runs = total_team_runs.sort_values(ascending=False).reset_index()
total_team_runs.columns = ['Team', 'Total Runs']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Runs', y='Team', data=total_team_runs, palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Runs Scored by Each Team (Combined)', fontsize=16)
plt.xlabel('Total Runs', fontsize=14)
plt.ylabel('Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_wickets = df.groupby('home_team')['wicket_id'].count().sort_values(ascending=False).reset_index()
home_team_wickets.columns = ['Home Team', 'Total Wickets']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Wickets', y='Home Team', data=home_team_wickets, palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Wickets Taken by Each Home Team', fontsize=16)
plt.xlabel('Total Wickets', fontsize=14)
plt.ylabel('Home Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
away_team_wickets = df.groupby('away_team')['wicket_id'].count().sort_values(ascending=False).reset_index()
away_team_wickets.columns = ['Away Team', 'Total Wickets']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Wickets', y='Away Team', data=away_team_wickets, palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Wickets Taken by Each Away Team', fontsize=16)
plt.xlabel('Total Wickets', fontsize=14)
plt.ylabel('Away Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_wicks = df.groupby('home_team')['wicket_id'].count()

away_team_wicks = df.groupby('away_team')['wicket_id'].count()

total_team_wicks = home_team_wicks.add(away_team_wicks)

total_team_wicks = total_team_wicks.sort_values(ascending=False).reset_index()
total_team_wicks.columns = ['Team', 'Total Wickets']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Wickets', y='Team', data=total_team_wicks, palette='viridis')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Wickets Taken by Each Team (Home and Away)', fontsize=16)
plt.xlabel('Total Wickets', fontsize=14)
plt.ylabel('Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
home_team_boundaries = df.groupby('home_team')['isBoundary'].sum()

total_boundaries_home = home_team_boundaries.sort_values(ascending=False).reset_index()
total_boundaries_home.columns = ['Home Team', 'Total Boundaries']

plt.figure(figsize=(12, 8))
bargraph = sns.barplot(x='Total Boundaries', y='Home Team', data=total_boundaries_home, palette='plasma')

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_width()), 
        (bar.get_width(), bar.get_y() + bar.get_height() / 2),  
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Boundaries Scored by Each Home Team', fontsize=16)
plt.xlabel('Total Boundaries', fontsize=14)
plt.ylabel('Home Team', fontsize=14)
plt.tight_layout()
plt.show()

# %%
away_team_boundaries = df.groupby('away_team')['isBoundary'].sum().sort_values(ascending=False)

plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=away_team_boundaries.values, y=away_team_boundaries.index, palette='viridis')

for index, value in enumerate(away_team_boundaries.values):
    barplot.annotate(
        f'{value}', 
        (value, index), 
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Boundaries Scored by Away Teams', fontsize=16)
plt.xlabel('Total Boundaries', fontsize=14)
plt.ylabel('Away Team', fontsize=14)

plt.tight_layout()
plt.show()

# %%
home_team_boundary = df.groupby('home_team')['isBoundary'].sum()
away_team_boundary = df.groupby('away_team')['isBoundary'].sum()

total_team_boundary = home_team_boundary.add(away_team_boundary).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=total_team_boundary.values, y=total_team_boundary.index, palette='viridis')

for index, value in enumerate(total_team_boundary.values):
    barplot.annotate(
        f'{value}', 
        (value, index), 
        ha='left', 
        va='center', 
        fontsize=9
    )

plt.title('Total Boundaries Scored by Each Team', fontsize=16)
plt.xlabel('Total Boundaries', fontsize=14)
plt.ylabel('Team', fontsize=14)

plt.tight_layout()
plt.show()

# %%
df.groupby('home_team')[['isWide', 'isNoball']].sum().sort_values(['isWide', 'isNoball'],ascending=False)
# Out:
#            isWide  isNoball
# home_team
# RCB           979       117
# MI            967       115
# CSK           915       142
# DC            902       118
# SRH           811       135
# KKR           787        96
# RR            737       107
# KXIP          658        69
# PBKS          177        25
# LSG           139        11
# PWI           137        26
# GT            134        19
# RPS           106         4
# GL            103         7
# Kochi          49        10

# %%
df.groupby('away_team')[['isWide', 'isNoball']].sum().sort_values(['isWide', 'isNoball'],ascending=False)
# Out:
#            isWide  isNoball
# away_team
# MI           1016       133
# KKR           917       135
# RR            851       113
# SRH           846        97
# RCB           837       132
# DC            793       114
# CSK           768        67
# KXIP          724        97
# PBKS          196        29
# LSG           132        19
# PWI           128        23
# RPS           120         9
# GT            112        10
# GL             98        15
# Kochi          63         8

# %%
home_team_extra =df.groupby('home_team')[['isWide', 'isNoball']].sum()
away_team_extra = df.groupby('away_team')[['isWide', 'isNoball']].sum()

total_team_extra = home_team_extra.add(away_team_extra)

total_team_extra = total_team_extra.sort_values('isWide',ascending=False)
total_team_extra
# Out:
#            isWide  isNoball
# home_team
# MI           1983       248
# RCB          1816       249
# KKR          1704       231
# DC           1695       232
# CSK          1683       209
# SRH          1657       232
# RR           1588       220
# KXIP         1382       166
# PBKS          373        54
# LSG           271        30
# PWI           265        49
# GT            246        29
# RPS           226        13
# GL            201        22
# Kochi         112        18

# %%
# df.groupby('home_team')['match_id'].nunique().sort_values(ascending=False)
warnings.filterwarnings('ignore')

home_team_matches = df.groupby('home_team')['match_id'].nunique().sort_values(ascending=False).reset_index()

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(home_team_matches))

# Create bar plot
bargraph = sns.barplot(x='home_team', y='match_id', data=home_team_matches, palette=palette)

for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Number of Matches Played by Each Team in Home', fontsize=16)
plt.xlabel('Home Team', fontsize=12)
plt.ylabel('Number of Matches', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

# Calculate the number of matches for each away team
away_team_matches = df.groupby('away_team')['match_id'].nunique().sort_values(ascending=False).reset_index()

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(away_team_matches))

# Create bar plot with hue and no legend to avoid the warning
bargraph = sns.barplot(x='away_team', y='match_id', data=away_team_matches, palette=palette, hue='away_team', dodge=False)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Number of Matches Played by Each Away Team', fontsize=16)
plt.xlabel('Away Team', fontsize=12)
plt.ylabel('Number of Matches', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

# Calculate the total matches each team has played
home_matches = df.groupby('home_team')['match_id'].nunique()
away_matches = df.groupby('away_team')['match_id'].nunique()
total_matches = home_matches.add(away_matches, fill_value=0).sort_values(ascending=False).reset_index()
total_matches.columns = ['team', 'total_matches']

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(total_matches))

# Create bar plot
bargraph = sns.barplot(x='team', y='total_matches', data=total_matches, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Total Number of Matches Played by Each Team (Home + Away)', fontsize=16)
plt.xlabel('Team', fontsize=12)
plt.ylabel('Total Matches', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

# Calculate the total runs scored by each batsman and select the top 10
top_batsmen = df.groupby('batsman1_name')['runs'].sum().sort_values(ascending=False).head(10).reset_index()
top_batsmen.columns = ['batsman', 'total_runs']

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(top_batsmen))

# Create bar plot
bargraph = sns.barplot(x='batsman', y='total_runs', data=top_batsmen, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Top 10 Batsmen by Total Runs Scored', fontsize=16)
plt.xlabel('Batsman', fontsize=12)
plt.ylabel('Total Runs', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

# Calculate the total boundaries hit by each batsman and select the top 10
top_boundary_hitters = df.groupby('batsman1_name')['isBoundary'].sum().sort_values(ascending=False).head(10).reset_index()
top_boundary_hitters.columns = ['batsman', 'total_boundaries']

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(top_boundary_hitters))

# Create bar plot
bargraph = sns.barplot(x='batsman', y='total_boundaries', data=top_boundary_hitters, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Top 10 Batsmen by Boundaries Hit', fontsize=16)
plt.xlabel('Batsman', fontsize=12)
plt.ylabel('Total Boundaries', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

# Calculate the total balls faced by each batsman and select the top 10
top_balls_faced = df.groupby('batsman1_name')['ball'].count().sort_values(ascending=False).head(10).reset_index()
top_balls_faced.columns = ['batsman', 'total_balls_faced']

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(top_balls_faced))

# Create bar plot
bargraph = sns.barplot(x='batsman', y='total_balls_faced', data=top_balls_faced, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Top 10 Batsmen by Balls Faced', fontsize=16)
plt.xlabel('Batsman', fontsize=12)
plt.ylabel('Total Balls Faced', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
warnings.filterwarnings('ignore')

# Calculate the total retired hurt instances for each batsman and select the top 10
top_retired_hurt = df.groupby('batsman1_name')['isRetiredHurt'].sum().sort_values(ascending=False).head(10).reset_index()
top_retired_hurt.columns = ['batsman', 'total_retired_hurt']

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(top_retired_hurt))

# Create bar plot
bargraph = sns.barplot(x='batsman', y='total_retired_hurt', data=top_retired_hurt, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Top 10 Batsmen by Retired Hurt Instances', fontsize=16)
plt.xlabel('Batsman', fontsize=12)
plt.ylabel('Total Retired Hurt Instances', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
h=df[['match_id','innings_id','batsman1_name','batsman1_runs']][df['batsman1_runs']>= 100]
h
# Out:
#         match_id  innings_id     batsman1_name  batsman1_runs
# 4459     1359493           1       Harry Brook            100
# 5184     1359496           1    Venkatesh Iyer            100
# 5187     1359496           1    Venkatesh Iyer            104
# 5188     1359496           1    Venkatesh Iyer            104
# 10080    1359516           1  Yashasvi Jaiswal            100
# ...          ...         ...               ...            ...
# 241731    336019           1       Shaun Marsh            110
# 241732    336019           1       Shaun Marsh            111
# 241734    336019           1       Shaun Marsh            115
# 241735    336019           1       Shaun Marsh            115
# 241736    336019           1       Shaun Marsh            115
#
# [479 rows x 4 columns]

# %%
h.groupby(['match_id','innings_id','batsman1_name'])['batsman1_runs'].max()
# Out:
# match_id  innings_id  batsman1_name
# 335982    1           Brendon McCullum     158
# 335983    1           Michael Hussey       116
# 335990    1           Andrew Symonds       117
# 335994    2           Adam Gilchrist       109
# 336018    2           Sanath Jayasuriya    114
#                                           ...
# 1359539   2           Virat Kohli          100
# 1359543   2           Cameron Green        100
# 1359544   1           Virat Kohli          101
#           2           Shubman Gill         104
# 1370352   1           Shubman Gill         129
# Name: batsman1_runs, Length: 85, dtype: int64

# %%
a=h.groupby(['match_id','batsman1_name',])['batsman1_runs'].max().sort_values(ascending=False).reset_index()
a
# Out:
#     match_id     batsman1_name  batsman1_runs
# 0     598027       Chris Gayle            174
# 1     335982  Brendon McCullum            158
# 2    1304112   Quinton de Kock            140
# 3     829795    AB de Villiers            133
# 4    1216510          KL Rahul            132
# ..       ...               ...            ...
# 80   1178410       Virat Kohli            100
# 81   1304055       Jos Buttler            100
# 82   1359493       Harry Brook            100
# 83   1359539       Virat Kohli            100
# 84   1359543     Cameron Green            100
#
# [85 rows x 3 columns]

# %%
 # Count the occurrences of each batsman in the DataFrame 'a'
batsman_counts = a['batsman1_name'].value_counts().sort_values(ascending=False).head(10)

# Convert the counts to a DataFrame for easier plotting
batsman_counts_df = batsman_counts.reset_index()
batsman_counts_df.columns = ['batsman', 'count']

# Plot the data
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(batsman_counts_df))

# Create bar plot
bargraph = sns.barplot(x='batsman', y='count', data=batsman_counts_df, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Number of Maximum Scores Achieved by Each Batsman', fontsize=16)
plt.xlabel('Batsman', fontsize=12)
plt.ylabel('Count of Maximum Scores', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'isBoundary',
#        'isWide', 'isNoball', 'batsman1_id', 'batsman1_name', 'batsman1_runs',
#        'batsman1_balls', 'bowler1_id', 'bowler1_name', 'bowler1_overs',
#        'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts', 'batsman2_id',
#        'batsman2_name', 'batsman2_runs', 'batsman2_balls', 'bowler2_id',
#        'bowler2_name', 'bowler2_overs', 'bowler2_maidens', 'bowler2_runs',
#        'bowler2_wkts', 'wicket_id', 'wkt_batsman_name', 'wkt_bowler_name',
#        'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby('bowler1_name')['wicket_id'].count().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Dwayne Bravo           200
# Yuzvendra Chahal       194
# Piyush Chawla          188
# Ravichandran Ashwin    188
# Lasith Malinga         186
# Amit Mishra            182
# Bhuvneshwar Kumar      182
# Sunil Narine           182
# Harbhajan Singh        161
# Ravindra Jadeja        160
# Name: wicket_id, dtype: int64

# %%
top_noball_bowlers = df.groupby('bowler1_name')['isNoball'].sum().sort_values(ascending=False).head(10).reset_index()
top_noball_bowlers.columns = ['bowler', 'total_noballs']


plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(top_noball_bowlers))

# Create bar plot
bargraph = sns.barplot(x='bowler', y='total_noballs', data=top_noball_bowlers, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Top 10 Bowlers by No-Balls Bowled', fontsize=16)
plt.xlabel('Bowler', fontsize=12)
plt.ylabel('Total No-Balls', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
top_wide_bowlers = df.groupby('bowler1_name')['isWide'].sum().sort_values(ascending=False).head(10).reset_index()
top_wide_bowlers.columns = ['bowler', 'total_wides']
plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(top_wide_bowlers))

# Create bar plot
bargraph = sns.barplot(x='bowler', y='total_wides', data=top_wide_bowlers, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Top 10 Bowlers by Wide Balls Bowled', fontsize=16)
plt.xlabel('Bowler', fontsize=12)
plt.ylabel('Total Wides', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Grouping by bowler1_name to sum the number of boundaries conceded
top_boundary_bowlers = df.groupby('bowler1_name')['isBoundary'].sum().sort_values(ascending=False).head(10).reset_index()
top_boundary_bowlers.columns = ['bowler', 'total_boundaries']

plt.figure(figsize=(12, 8))
palette = sns.color_palette('viridis', n_colors=len(top_boundary_bowlers))

# Create bar plot
bargraph = sns.barplot(x='bowler', y='total_boundaries', data=top_boundary_bowlers, palette=palette)

# Add annotations for each bar
for bar in bargraph.patches:
    bargraph.annotate(
        int(bar.get_height()), 
        (bar.get_x() + bar.get_width() / 2, bar.get_height()),  
        ha='center', 
        va='bottom',
        fontsize=9
    )

# Set plot titles and labels
plt.title('Top 10 Bowlers by Boundaries Conceded', fontsize=16)
plt.xlabel('Bowler', fontsize=12)
plt.ylabel('Total Boundaries', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'isBoundary',
#        'isWide', 'isNoball', 'batsman1_id', 'batsman1_name', 'batsman1_runs',
#        'batsman1_balls', 'bowler1_id', 'bowler1_name', 'bowler1_overs',
#        'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts', 'batsman2_id',
#        'batsman2_name', 'batsman2_runs', 'batsman2_balls', 'bowler2_id',
#        'bowler2_name', 'bowler2_overs', 'bowler2_maidens', 'bowler2_runs',
#        'bowler2_wkts', 'wicket_id', 'wkt_batsman_name', 'wkt_bowler_name',
#        'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt'],
#       dtype='object')

# %%
df[['match_id','bowler1_name','bowler1_maidens']].sort_values('bowler1_maidens',ascending=False).head(20)
# Out:
#        match_id    bowler1_name  bowler1_maidens
# 18937   1304052   Harshal Patel                2
# 18938   1304052   Harshal Patel                2
# 18939   1304052   Harshal Patel                2
# 18940   1304052   Harshal Patel                2
# 59030   1216494  Mohammed Siraj                2
# 59119   1216494  Mohammed Siraj                2
# 59120   1216494  Mohammed Siraj                2
# 59115   1216494  Mohammed Siraj                2
# 59116   1216494  Mohammed Siraj                2
# 59040   1216494  Mohammed Siraj                2
# 59041   1216494  Mohammed Siraj                2
# 18925   1304052   Harshal Patel                2
# 18926   1304052   Harshal Patel                2
# 18927   1304052   Harshal Patel                2
# 18928   1304052   Harshal Patel                2
# 18916   1304052   Harshal Patel                2
# 59042   1216494  Mohammed Siraj                2
# 59037   1216494  Mohammed Siraj                2
# ...

# %%
a=df[df['bowler1_maidens'] != 0]
a.head(20)
# Out:
#       season  match_id match_name home_team away_team current_innings  \
# 842   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 849   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 850   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 851   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 852   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 853   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 854   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 861   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 862   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 863   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 864   2023.0   1359478   SRH v RR       SRH        RR             SRH
# 865   2023.0   1359478   SRH v RR       SRH        RR             SRH
# ...

# %%
a.groupby(['match_id','bowler1_name'])['bowler1_maidens'].sum().sort_values(ascending=False).head(10)
# Out:
# match_id  bowler1_name
# 1304052   Harshal Patel          32
# 1216494   Mohammed Siraj         32
# 392237    Ryan Harris            21
# 1304088   Mohsin Khan            21
# 419165    Ravichandran Ashwin    21
# 1216523   Arshdeep Singh         21
# 548336    Kevon Cooper           21
# 1178401   Ishant Sharma          21
# 598065    James Faulkner         21
# 548372    Umesh Yadav            21
# Name: bowler1_maidens, dtype: int64

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'isBoundary',
#        'isWide', 'isNoball', 'batsman1_id', 'batsman1_name', 'batsman1_runs',
#        'batsman1_balls', 'bowler1_id', 'bowler1_name', 'bowler1_overs',
#        'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts', 'batsman2_id',
#        'batsman2_name', 'batsman2_runs', 'batsman2_balls', 'bowler2_id',
#        'bowler2_name', 'bowler2_overs', 'bowler2_maidens', 'bowler2_runs',
#        'bowler2_wkts', 'wicket_id', 'wkt_batsman_name', 'wkt_bowler_name',
#        'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby(['season'])['match_id'].nunique()
# Out:
# season
# 2008.0    58
# 2009.0    57
# 2010.0    60
# 2011.0    73
# 2012.0    74
# 2013.0    76
# 2014.0    60
# 2015.0    59
# 2016.0    60
# 2017.0    59
# 2018.0    60
# 2019.0    60
# 2020.0    60
# 2021.0    60
# 2022.0    74
# 2023.0    73
# Name: match_id, dtype: int64
