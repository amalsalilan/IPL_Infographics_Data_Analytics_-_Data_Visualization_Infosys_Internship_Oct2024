# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('all_season_details.csv')
df
# Out:
# C:\Users\govinda prasad\AppData\Local\Temp\ipykernel_19444\3647924527.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df= pd.read_csv('all_season_details.csv')
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# ...

# %%
pd.set_option('display.max_columns',None)
df
# Out:
#         comment_id  season  match_id match_name home_team away_team  \
# 0              110  2023.0   1359475   GT v CSK        GT       CSK
# 1              120  2023.0   1359475   GT v CSK        GT       CSK
# 2              130  2023.0   1359475   GT v CSK        GT       CSK
# 3              140  2023.0   1359475   GT v CSK        GT       CSK
# 4              150  2023.0   1359475   GT v CSK        GT       CSK
# ...            ...     ...       ...        ...       ...       ...
# 242545      219020  2008.0    336040   CSK v RR       CSK        RR
# 242546      219030  2008.0    336040   CSK v RR       CSK        RR
# 242547      219050  2008.0    336040   CSK v RR       CSK        RR
# 242548      219040  2008.0    336040   CSK v RR       CSK        RR
# 242549      219060  2008.0    336040   CSK v RR       CSK        RR
#
#        current_innings  innings_id  over  ball  runs  \
# 0                  CSK           1     1     1     0
# ...

# %%
df.shape
# Out:
# (242550, 45)

# %%
df.columns
# Out:
# Index(['comment_id', 'season', 'match_id', 'match_name', 'home_team',
#        'away_team', 'current_innings', 'innings_id', 'over', 'ball', 'runs',
#        'shortText', 'isBoundary', 'isWide', 'isNoball', 'batsman1_id',
#        'batsman1_name', 'batsman1_runs', 'batsman1_balls', 'bowler1_id',
#        'bowler1_name', 'bowler1_overs', 'bowler1_maidens', 'bowler1_runs',
#        'bowler1_wkts', 'batsman2_id', 'batsman2_name', 'batsman2_runs',
#        'batsman2_balls', 'bowler2_id', 'bowler2_name', 'bowler2_overs',
#        'bowler2_maidens', 'bowler2_runs', 'bowler2_wkts', 'wicket_id',
#        'wkt_batsman_name', 'wkt_bowler_name', 'wkt_batsman_runs',
#        'wkt_batsman_balls', 'wkt_text', 'isRetiredHurt', 'text', 'preText',
#        'postText'],
#       dtype='object')

# %%
df.drop(['comment_id','text','preText','postText'],axis=1,inplace=True)
df
# Out:
#         season  match_id match_name home_team away_team current_innings  \
# 0       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3       2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4       2023.0   1359475   GT v CSK        GT       CSK             CSK
# ...        ...       ...        ...       ...       ...             ...
# 242545  2008.0    336040   CSK v RR       CSK        RR              RR
# 242546  2008.0    336040   CSK v RR       CSK        RR              RR
# 242547  2008.0    336040   CSK v RR       CSK        RR              RR
# 242548  2008.0    336040   CSK v RR       CSK        RR              RR
# 242549  2008.0    336040   CSK v RR       CSK        RR              RR
#
#         innings_id  over  ball  runs                            shortText  \
# ...

# %%
df.head(50)
# Out:
#     season  match_id match_name home_team away_team current_innings  \
# 0   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 1   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 2   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 3   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 4   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 5   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 6   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 7   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 8   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 9   2023.0   1359475   GT v CSK        GT       CSK             CSK
# 10  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 11  2023.0   1359475   GT v CSK        GT       CSK             CSK
# 12  2023.0   1359475   GT v CSK        GT       CSK             CSK
# ...

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242550 entries, 0 to 242549
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   season             242067 non-null  float64
#  1   match_id           242550 non-null  int64
#  2   match_name         242550 non-null  object
#  3   home_team          242550 non-null  object
#  4   away_team          242550 non-null  object
#  5   current_innings    242550 non-null  object
#  6   innings_id         242550 non-null  int64
#  7   over               242550 non-null  int64
#  8   ball               242550 non-null  int64
#  9   runs               242550 non-null  int64
#  10  shortText          242550 non-null  object
#  11  isBoundary         242550 non-null  bool
#  12  isWide             242550 non-null  bool
#  13  isNoball           242550 non-null  bool
#  14  batsman1_id        242550 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# season                  483
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# shortText                 0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# bowler2_runs          12841
# ...

# %%
df[df['season'].isnull()]
# Out:
#        season  match_id match_name home_team away_team current_innings  \
# 5080      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5081      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5082      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5083      NaN   1359496   MI v KKR       KKR        MI             KKR
# 5084      NaN   1359496   MI v KKR       KKR        MI             KKR
# ...       ...       ...        ...       ...       ...             ...
# 15196     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15197     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15198     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15199     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
# 15200     NaN   1359538  PBKS v DC        DC      PBKS            PBKS
#
#        innings_id  over  ball  runs                                shortText  \
# ...

# %%
    df.loc[(df['match_id'].isin([1359496,1359538])) & (df['season'].isnull()), 'season'] = 2023

# %%
df.isnull().sum()
# Out:
# season                    0
# match_id                  0
# match_name                0
# home_team                 0
# away_team                 0
# current_innings           0
# innings_id                0
# over                      0
# ball                      0
# runs                      0
# shortText                 0
# isBoundary                0
# isWide                    0
# isNoball                  0
# batsman1_id               0
# batsman1_name             0
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id                0
# bowler1_name              0
# bowler1_overs             0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_id               0
# batsman2_name             2
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id            12841
# bowler2_name          12841
# bowler2_overs         12841
# bowler2_maidens       12841
# bowler2_runs          12841
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df[df.duplicated()]
# Out:
#        season  match_id match_name home_team away_team current_innings  \
# 13082  2023.0   1359530   KKR v RR       KKR        RR             KKR
#
#        innings_id  over  ball  runs                shortText  isBoundary  \
# 13082           1     1     1     2  Boult to JJ Roy, 2 runs       False
#
#        isWide  isNoball  batsman1_id batsman1_name  batsman1_runs  \
# 13082   False     False       298438     Jason Roy              2
#
#        batsman1_balls  bowler1_id bowler1_name  bowler1_overs  \
# 13082               1      277912  Trent Boult            0.1
#
#        bowler1_maidens  bowler1_runs  bowler1_wkts batsman2_id  \
# 13082                0             2             0      974087
#
#             batsman2_name  batsman2_runs  batsman2_balls  bowler2_id  \
# 13082  Rahmanullah Gurbaz              0               0         NaN
#
#       bowler2_name  bowler2_overs  bowler2_maidens  bowler2_runs  \
# 13082          NaN            NaN              NaN           NaN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
teams=df['home_team'].unique()
teams
# Out:
# array(['GT', 'PBKS', 'LSG', 'SRH', 'RCB', 'CSK', 'DC', 'RR', 'KKR', 'MI',
#        'KXIP', 'RPS', 'GL', 'PWI', 'Kochi'], dtype=object)

# %%
df.groupby(['season'])['match_id'].nunique()
# Out:
# season
# 2008.0    58
# 2009.0    57
# 2010.0    60
# 2011.0    73
# 2012.0    74
# 2013.0    76
# 2014.0    60
# 2015.0    59
# 2016.0    60
# 2017.0    59
# 2018.0    60
# 2019.0    60
# 2020.0    60
# 2021.0    60
# 2022.0    74
# 2023.0    73
# Name: match_id, dtype: int64

# %%
df.groupby(['season'])['match_id'].nunique().sum()
# Out:
# np.int64(1023)

# %%
df.groupby(['season'])['away_team'].nunique()
# Out:
# season
# 2008.0     8
# 2009.0     8
# 2010.0     8
# 2011.0    10
# 2012.0     9
# 2013.0     9
# 2014.0     8
# 2015.0     8
# 2016.0     8
# 2017.0     8
# 2018.0     8
# 2019.0     8
# 2020.0     8
# 2021.0     8
# 2022.0    10
# 2023.0    10
# Name: away_team, dtype: int64

# %%
df['home_team'][df['season']==2009].unique()
# Out:
# array(['CSK', 'RCB', 'DC', 'SRH', 'KXIP', 'KKR', 'MI'], dtype=object)

# %%
df['away_team'][df['season']==2009].unique()
# Out:
# array(['MI', 'RR', 'KXIP', 'KKR', 'CSK', 'SRH', 'DC', 'RCB'], dtype=object)

# %%
df.groupby('home_team')['runs'].sum().sort_values(ascending=False).head(10)
# Out:
# home_team
# CSK     38452
# RCB     38285
# DC      38057
# MI      37828
# SRH     37371
# KKR     34903
# RR      30118
# KXIP    29635
# PBKS     6577
# PWI      6436
# Name: runs, dtype: int64

# %%
df.groupby('home_team')['wicket_id'].count().sort_values(ascending=False).head(10)
# Out:
# home_team
# SRH     1470
# MI      1425
# CSK     1417
# RCB     1401
# DC      1395
# KKR     1334
# RR      1084
# KXIP    1036
# PWI      270
# PBKS     227
# Name: wicket_id, dtype: int64

# %%
df.groupby('away_team')['runs'].sum().sort_values(ascending=False).head(10)
# Out:
# away_team
# MI      39762
# KKR     38011
# SRH     37428
# RCB     36958
# DC      35545
# RR      33992
# CSK     31843
# KXIP    30517
# PBKS     7279
# PWI      6739
# Name: runs, dtype: int64

# %%
df.groupby('away_team')['wicket_id'].count().sort_values(ascending=False).head(10)
# Out:
# away_team
# MI      1510
# KKR     1395
# DC      1393
# SRH     1375
# RCB     1351
# RR      1285
# KXIP    1161
# CSK     1108
# PBKS     272
# PWI      261
# Name: wicket_id, dtype: int64

# %%
df.groupby('batsman1_name')['runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Virat Kohli       7513
# Shikhar Dhawan    6948
# David Warner      6722
# Rohit Sharma      6414
# Suresh Raina      5762
# AB de Villiers    5312
# Chris Gayle       5296
# MS Dhoni          5245
# Robin Uthappa     5237
# Dinesh Karthik    4692
# Name: runs, dtype: int64

# %%
df.groupby('batsman2_name')['runs'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman2_name
# Virat Kohli       7857
# Shikhar Dhawan    7814
# Rohit Sharma      6425
# David Warner      5829
# Suresh Raina      5764
# Ajinkya Rahane    5061
# Gautam Gambhir    4948
# MS Dhoni          4870
# Robin Uthappa     4805
# Dinesh Karthik    4675
# Name: runs, dtype: int64

# %%
df.groupby('bowler1_name')['wicket_id'].count().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Dwayne Bravo           200
# Yuzvendra Chahal       194
# Piyush Chawla          188
# Ravichandran Ashwin    188
# Lasith Malinga         186
# Amit Mishra            182
# Bhuvneshwar Kumar      182
# Sunil Narine           182
# Harbhajan Singh        161
# Ravindra Jadeja        160
# Name: wicket_id, dtype: int64

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby('bowler1_name')['isNoball'].sum().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Jasprit Bumrah     27
# Umesh Yadav        24
# Sreesanth          23
# Ishant Sharma      22
# Amit Mishra        21
# Lasith Malinga     18
# Prasidh Krishna    17
# Ashok Dinda        14
# Harshal Patel      14
# Brett Lee          13
# Name: isNoball, dtype: int64

# %%
df.groupby('bowler1_name')['isWide'].sum().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Dwayne Bravo           166
# Ravichandran Ashwin    134
# Lasith Malinga         127
# Bhuvneshwar Kumar      123
# Praveen Kumar          111
# Umesh Yadav            106
# Shardul Thakur          98
# Shane Watson            95
# Dale Steyn              93
# Mohammed Siraj          89
# Name: isWide, dtype: int64

# %%
df.groupby('bowler1_name')['isBoundary'].sum().sort_values(ascending=False).head(10)
# Out:
# bowler1_name
# Umesh Yadav            581
# Bhuvneshwar Kumar      570
# Piyush Chawla          562
# Dwayne Bravo           494
# Mohammed Shami         484
# Ravichandran Ashwin    472
# Ravindra Jadeja        461
# Sandeep Sharma         452
# Praveen Kumar          441
# Harbhajan Singh        441
# Name: isBoundary, dtype: int64

# %%
df.groupby('batsman1_name')['isBoundary'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Shikhar Dhawan    896
# Virat Kohli       876
# David Warner      872
# Rohit Sharma      808
# Chris Gayle       760
# Suresh Raina      708
# Robin Uthappa     662
# AB de Villiers    661
# MS Dhoni          575
# Dinesh Karthik    575
# Name: isBoundary, dtype: int64

# %%
df.groupby('batsman1_name')['ball'].count().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Virat Kohli       5726
# Shikhar Dhawan    5353
# Rohit Sharma      4880
# David Warner      4713
# Suresh Raina      4170
# Robin Uthappa     3921
# MS Dhoni          3829
# Ajinkya Rahane    3653
# Gautam Gambhir    3524
# Chris Gayle       3498
# Name: ball, dtype: int64

# %%
df.groupby('batsman1_name')['isRetiredHurt'].sum().sort_values(ascending=False).head(10)
# Out:
# batsman1_name
# Sachin Tendulkar    2
# Shikhar Dhawan      2
# Krunal Pandya       1
# Aaron Finch         1
# Kevin Pietersen     1
# Dominic Thornely    1
# Harbhajan Singh     1
# Liam Livingstone    1
# Jaskaran Singh      1
# Ambati Rayudu       1
# Name: isRetiredHurt, dtype: int64

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team',
#        'current_innings', 'innings_id', 'over', 'ball', 'runs', 'shortText',
#        'isBoundary', 'isWide', 'isNoball', 'batsman1_id', 'batsman1_name',
#        'batsman1_runs', 'batsman1_balls', 'bowler1_id', 'bowler1_name',
#        'bowler1_overs', 'bowler1_maidens', 'bowler1_runs', 'bowler1_wkts',
#        'batsman2_id', 'batsman2_name', 'batsman2_runs', 'batsman2_balls',
#        'bowler2_id', 'bowler2_name', 'bowler2_overs', 'bowler2_maidens',
#        'bowler2_runs', 'bowler2_wkts', 'wicket_id', 'wkt_batsman_name',
#        'wkt_bowler_name', 'wkt_batsman_runs', 'wkt_batsman_balls', 'wkt_text',
#        'isRetiredHurt'],
#       dtype='object')

# %%
df.groupby('wkt_batsman_name')['match_id'].count().sort_values(ascending=False).head(10)
# Out:
# wkt_batsman_name
# Rohit Sharma      218
# Virat Kohli       204
# Shikhar Dhawan    189
# Robin Uthappa     181
# Dinesh Karthik    179
# Suresh Raina      167
# David Warner      154
# Ambati Rayudu     152
# MS Dhoni          143
# Ajinkya Rahane    142
# Name: match_id, dtype: int64

# %%
h=df[['match_id','batsman1_name','batsman1_runs']][df['batsman1_runs']>= 100]
h['batsman1_name'].nunique()
# Out:
# 47

# %%
h=df[['match_id','batsman1_name','batsman1_runs']][df['batsman1_runs']>= 100]
h
# Out:
#         match_id     batsman1_name  batsman1_runs
# 4459     1359493       Harry Brook            100
# 5184     1359496    Venkatesh Iyer            100
# 5187     1359496    Venkatesh Iyer            104
# 5188     1359496    Venkatesh Iyer            104
# 10080    1359516  Yashasvi Jaiswal            100
# ...          ...               ...            ...
# 241732    336019       Shaun Marsh            110
# 241733    336019       Shaun Marsh            111
# 241735    336019       Shaun Marsh            115
# 241736    336019       Shaun Marsh            115
# 241737    336019       Shaun Marsh            115
#
# [479 rows x 3 columns]

# %%
h.groupby(['match_id','batsman1_name'])['batsman1_runs'].max()
# Out:
# match_id  batsman1_name
# 335982    Brendon McCullum     158
# 335983    Michael Hussey       116
# 335990    Andrew Symonds       117
# 335994    Adam Gilchrist       109
# 336018    Sanath Jayasuriya    114
#                               ...
# 1359539   Virat Kohli          100
# 1359543   Cameron Green        100
# 1359544   Shubman Gill         104
#           Virat Kohli          101
# 1370352   Shubman Gill         129
# Name: batsman1_runs, Length: 85, dtype: int64

# %%
a=h.groupby(['match_id','batsman1_name'])['batsman1_runs'].max().sort_values(ascending=False).reset_index()
a
# Out:
#     match_id     batsman1_name  batsman1_runs
# 0     598027       Chris Gayle            174
# 1     335982  Brendon McCullum            158
# 2    1304112   Quinton de Kock            140
# 3     829795    AB de Villiers            133
# 4    1216510          KL Rahul            132
# ..       ...               ...            ...
# 80   1178410       Virat Kohli            100
# 81   1304055       Jos Buttler            100
# 82   1359493       Harry Brook            100
# 83   1359539       Virat Kohli            100
# 84   1359543     Cameron Green            100
#
# [85 rows x 3 columns]

# %%
a['batsman1_name'].value_counts()
# Out:
# batsman1_name
# Virat Kohli           7
# Chris Gayle           6
# Jos Buttler           5
# David Warner          4
# Shane Watson          4
# KL Rahul              4
# Shubman Gill          3
# Sanju Samson          3
# AB de Villiers        3
# Quinton de Kock       2
# Virender Sehwag       2
# Adam Gilchrist        2
# Ajinkya Rahane        2
# Shikhar Dhawan        2
# Murali Vijay          2
# Ben Stokes            2
# Hashim Amla           2
# Brendon McCullum      1
# Rishabh Pant          1
# Andrew Symonds        1
# Paul Valthaty         1
# Wriddhiman Saha       1
# Michael Hussey        1
# Manish Pandey         1
# Sanath Jayasuriya     1
# Jonny Bairstow        1
# Shaun Marsh           1
# Rohit Sharma          1
# Mahela Jayawardene    1
# Rajat Patidar         1
# Yashasvi Jaiswal      1
# Mayank Agarwal        1
# Venkatesh Iyer        1
# Heinrich Klaasen      1
# Kevin Pietersen       1
# Suryakumar Yadav      1
# Prabhsimran Singh     1
# ...
