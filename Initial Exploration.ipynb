# %%
import pandas as pd

# %%
df=pd.read_csv('C:/Users/avhad/Downloads/projectdataset/IPL_Ball_by_Ball_2022.csv')

# %%
df
# Out:
#             ID  innings  overs  ballnumber       batter          bowler  \
# 0      1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1      1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2      1312200        1      0           3   JC Buttler  Mohammed Shami
# 3      1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4      1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...        ...      ...    ...         ...          ...             ...
# 17907  1304047        2     17           5      SS Iyer        DJ Bravo
# 17908  1304047        2     17           6   SP Jackson        DJ Bravo
# 17909  1304047        2     18           1   SP Jackson        AF Milne
# 17910  1304047        2     18           2      SS Iyer        AF Milne
# 17911  1304047        2     18           3      SS Iyer        AF Milne
#
#        non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
data=pd.read_csv('C:/Users/avhad/Downloads/projectdataset/IPL_Matches_2022.csv')

# %%
data
# Out:
#          ID       City        Date  Season  MatchNumber  \
# 0   1312200  Ahmedabad  2022-05-29    2022        Final
# 1   1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2   1312198    Kolkata  2022-05-25    2022   Eliminator
# 3   1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4   1304116     Mumbai  2022-05-22    2022           70
# ..      ...        ...         ...     ...          ...
# 69  1304051       Pune  2022-03-29    2022            5
# 70  1304050     Mumbai  2022-03-28    2022            4
# 71  1304049     Mumbai  2022-03-27    2022            3
# 72  1304048     Mumbai  2022-03-27    2022            2
# 73  1304047     Mumbai  2022-03-26    2022            1
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 1   Royal Challengers Bangalore       Rajasthan Royals
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# 3              Rajasthan Royals         Gujarat Titans
# ...

# %%
df.head(6)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# 5  1312200        1      0           6  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
# ...

# %%
df.tail(5)
# Out:
#             ID  innings  overs  ballnumber      batter    bowler non-striker  \
# 17907  1304047        2     17           5     SS Iyer  DJ Bravo  SP Jackson
# 17908  1304047        2     17           6  SP Jackson  DJ Bravo     SS Iyer
# 17909  1304047        2     18           1  SP Jackson  AF Milne     SS Iyer
# 17910  1304047        2     18           2     SS Iyer  AF Milne  SP Jackson
# 17911  1304047        2     18           3     SS Iyer  AF Milne  SP Jackson
#
#       extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 17907        NaN            1           0          1             0
# 17908        NaN            1           0          1             0
# 17909        NaN            1           0          1             0
# 17910        NaN            2           0          2             0
# 17911        NaN            4           0          4             0
#
#        isWicketDelivery player_out kind fielders_involved  \
# ...

# %%
data.tail(2)
# Out:
#          ID    City        Date  Season MatchNumber                Team1  \
# 72  1304048  Mumbai  2022-03-27    2022           2       Mumbai Indians
# 73  1304047  Mumbai  2022-03-26    2022           1  Chennai Super Kings
#
#                     Team2                      Venue             TossWinner  \
# 72         Delhi Capitals  Brabourne Stadium, Mumbai         Delhi Capitals
# 73  Kolkata Knight Riders   Wankhede Stadium, Mumbai  Kolkata Knight Riders
#
#    TossDecision SuperOver            WinningTeam    WonBy  Margin  method  \
# 72        field         N         Delhi Capitals  Wickets       4     NaN
# 73        field         N  Kolkata Knight Riders  Wickets       6     NaN
#
#    Player_of_Match                                       Team1Players  \
# 72   Kuldeep Yadav  ['RG Sharma', 'Ishan Kishan', 'Anmolpreet Sing...
# 73        UT Yadav  ['RD Gaikwad', 'DP Conway', 'RV Uthappa', 'AT ...
#
#                                          Team2Players       Umpire1  \
# ...

# %%
data.head(3)
# Out:
#         ID       City        Date  Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29    2022        Final
# 1  1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25    2022   Eliminator
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
#
#   SuperOver                  WinningTeam    WonBy  Margin  method  \
# 0         N               Gujarat Titans  Wickets       7     NaN
# 1         N             Rajasthan Royals  Wickets       7     NaN
# ...

# %%
df.shape
# Out:
# (17912, 17)

# %%
df.size
# Out:
# 304504

# %%
df.iloc[0:5,0:5]
# Out:
#         ID  innings  overs  ballnumber       batter
# 0  1312200        1      0           1  YBK Jaiswal
# 1  1312200        1      0           2  YBK Jaiswal
# 2  1312200        1      0           3   JC Buttler
# 3  1312200        1      0           4  YBK Jaiswal
# 4  1312200        1      0           5  YBK Jaiswal

# %%
df.iloc[[0,1]]
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
#
#   non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0  JC Buttler        NaN            0           0          0             0
# 1  JC Buttler    legbyes            0           1          1             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0                 0        NaN  NaN               NaN  Rajasthan Royals
# 1                 0        NaN  NaN               NaN  Rajasthan Royals

# %%
data.City
# Out:
# 0     Ahmedabad
# 1     Ahmedabad
# 2       Kolkata
# 3       Kolkata
# 4        Mumbai
#         ...
# 69         Pune
# 70       Mumbai
# 71       Mumbai
# 72       Mumbai
# 73       Mumbai
# Name: City, Length: 74, dtype: object

# %%
data.loc[data.City == "Mumbai"]
# Out:
#          ID    City        Date  Season MatchNumber  \
# 4   1304116  Mumbai  2022-05-22    2022          70
# 5   1304115  Mumbai  2022-05-21    2022          69
# 6   1304114  Mumbai  2022-05-20    2022          68
# 7   1304113  Mumbai  2022-05-19    2022          67
# 9   1304111  Mumbai  2022-05-17    2022          65
# 11  1304109  Mumbai  2022-05-15    2022          63
# 12  1304108  Mumbai  2022-05-15    2022          62
# 14  1304106  Mumbai  2022-05-13    2022          60
# 15  1304105  Mumbai  2022-05-12    2022          59
# 20  1304100  Mumbai  2022-05-08    2022          54
# 22  1304098  Mumbai  2022-05-07    2022          52
# 23  1304097  Mumbai  2022-05-06    2022          51
# 24  1304096  Mumbai  2022-05-05    2022          50
# 27  1304093  Mumbai  2022-05-02    2022          47
# 29  1304091  Mumbai  2022-05-01    2022          45
# 31  1304089  Mumbai  2022-04-30    2022          43
# 33  1304087  Mumbai  2022-04-28    2022          41
# ...

# %%
data.loc[(data.City == "Mumbai") & (data.TossWinner == "Mumbai Indians")]
# Out:
#          ID    City        Date  Season MatchNumber                 Team1  \
# 5   1304115  Mumbai  2022-05-21    2022          69        Delhi Capitals
# 9   1304111  Mumbai  2022-05-17    2022          65   Sunrisers Hyderabad
# 15  1304105  Mumbai  2022-05-12    2022          59   Chennai Super Kings
# 37  1304083  Mumbai  2022-04-24    2022          37  Lucknow Super Giants
# 48  1304072  Mumbai  2022-04-16    2022          26  Lucknow Super Giants
# 65  1304055  Mumbai  2022-04-02    2022           9      Rajasthan Royals
#
#              Team2                               Venue      TossWinner  \
# 5   Mumbai Indians            Wankhede Stadium, Mumbai  Mumbai Indians
# 9   Mumbai Indians            Wankhede Stadium, Mumbai  Mumbai Indians
# 15  Mumbai Indians            Wankhede Stadium, Mumbai  Mumbai Indians
# 37  Mumbai Indians            Wankhede Stadium, Mumbai  Mumbai Indians
# 48  Mumbai Indians           Brabourne Stadium, Mumbai  Mumbai Indians
# ...

# %%
data.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
data.City.unique
# Out:
# <bound method Series.unique of 0     Ahmedabad
# 1     Ahmedabad
# 2       Kolkata
# 3       Kolkata
# 4        Mumbai
#         ...
# 69         Pune
# 70       Mumbai
# 71       Mumbai
# 72       Mumbai
# 73       Mumbai
# Name: City, Length: 74, dtype: object>

# %%
data.info
# Out:
# <bound method DataFrame.info of          ID       City        Date  Season  MatchNumber  \
# 0   1312200  Ahmedabad  2022-05-29    2022        Final
# 1   1312199  Ahmedabad  2022-05-27    2022  Qualifier 2
# 2   1312198    Kolkata  2022-05-25    2022   Eliminator
# 3   1312197    Kolkata  2022-05-24    2022  Qualifier 1
# 4   1304116     Mumbai  2022-05-22    2022           70
# ..      ...        ...         ...     ...          ...
# 69  1304051       Pune  2022-03-29    2022            5
# 70  1304050     Mumbai  2022-03-28    2022            4
# 71  1304049     Mumbai  2022-03-27    2022            3
# 72  1304048     Mumbai  2022-03-27    2022            2
# 73  1304047     Mumbai  2022-03-26    2022            1
#
#                           Team1                  Team2  \
# 0              Rajasthan Royals         Gujarat Titans
# 1   Royal Challengers Bangalore       Rajasthan Royals
# 2   Royal Challengers Bangalore   Lucknow Super Giants
# ...

# %%
df.sample(5)
# Out:
#             ID  innings  overs  ballnumber       batter          bowler  \
# 2258   1304111        1     13           1     N Pooran      M Markande
# 12280  1304070        2     14           6  JDS Neesham  Mohammed Shami
# 15303  1304057        1      9           7     S Dhawan        DJ Bravo
# 4054   1304104        2      8           3    DA Warner       YS Chahal
# 4355   1304102        1      4           2      VR Iyer     RP Meredith
#
#           non-striker extra_type  batsman_run  extras_run  total_run  \
# 2258      RA Tripathi        NaN            1           0          1
# 12280         R Parag        NaN            2           0          2
# 15303  LS Livingstone        NaN            0           0          0
# 4054         MR Marsh        NaN            2           0          2
# 4355        AM Rahane        NaN            4           0          4
#
#        non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# ...

# %%
printdf.batter.unique)
# Out:
# <bound method Series.unique of 0        YBK Jaiswal
# 1        YBK Jaiswal
# 2         JC Buttler
# 3        YBK Jaiswal
# 4        YBK Jaiswal
#             ...
# 17907        SS Iyer
# 17908     SP Jackson
# 17909     SP Jackson
# 17910        SS Iyer
# 17911        SS Iyer
# Name: batter, Length: 17912, dtype: object>
