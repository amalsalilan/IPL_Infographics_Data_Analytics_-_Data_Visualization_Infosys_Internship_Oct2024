# %%
import pandas as pd
import numpy as np
df=pd.read_csv("/content/all_season_details.csv",low_memory=False)
df
# Out:
#        comment_id  season  match_id match_name home_team away_team  \
# 0             110  2023.0   1359475   GT v CSK        GT       CSK
# 1             120  2023.0   1359475   GT v CSK        GT       CSK
# 2             130  2023.0   1359475   GT v CSK        GT       CSK
# 3             140  2023.0   1359475   GT v CSK        GT       CSK
# 4             150  2023.0   1359475   GT v CSK        GT       CSK
# ...           ...     ...       ...        ...       ...       ...
# 14379       27010  2023.0   1359535  CSK v KKR       CSK       KKR
# 14380       27020  2023.0   1359535  CSK v KKR       CSK       KKR
# 14381       27030  2023.0   1359535  CSK v KKR       CSK       KKR
# 14382       27040  2023.0   1359535  CSK v KKR       CSK       KKR
# 14383       27050  2023.0   1359535  CSK v KKR       CSK       KKR
#
#       current_innings  innings_id  over  ball  ...  wicket_id  \
# 0                 CSK           1     1     1  ...        NaN
# 1                 CSK           1     1     2  ...        NaN
# 2                 CSK           1     1     3  ...        NaN
# 3                 CSK           1     1     4  ...        NaN
# 4                 CSK           1     1     5  ...        NaN
# ...               ...         ...   ...   ...  ...        ...
# 14379             KKR           2     8     1  ...        NaN
# 14380             KKR           2     8     2  ...        NaN
# 14381             KKR           2     8     3  ...        NaN
# 14382             KKR           2     8     4  ...        NaN
# 14383             KKR           2     8     5  ...        NaN
#
#       wkt_batsman_name  wkt_bowler_name wkt_batsman_runs wkt_batsman_balls  \
# 0                  NaN              NaN              NaN               NaN
# 1                  NaN              NaN              NaN               NaN
# 2                  NaN              NaN              NaN               NaN
# 3                  NaN              NaN              NaN               NaN
# 4                  NaN              NaN              NaN               NaN
# ...                ...              ...              ...               ...
# 14379              NaN              NaN              NaN               NaN
# 14380              NaN              NaN              NaN               NaN
# 14381              NaN              NaN              NaN               NaN
# 14382              NaN              NaN              NaN               NaN
# 14383              NaN              NaN              NaN               NaN
#
#        wkt_text isRetiredHurt  \
# 0           NaN         False
# 1           NaN         False
# 2           NaN         False
# 3           NaN         False
# 4           NaN         False
# ...         ...           ...
# 14379       NaN         False
# 14380       NaN         False
# 14381       NaN         False
# 14382       NaN         False
# 14383       NaN           NaN
#
#                                                     text  \
# 0      nice and full, angling and perhaps swinging in...
# 1      Conway shuffles across off, and shimmies out a...
# 2      good length, angling in at off and then straig...
# 3      shorter and slanting into middle and leg, Gaik...
# 4      Shami hits a heavy length and brings this back...
# ...                                                  ...
# 14379      full, outside off, driven to long-off for one
# 14380          full, around off, driven down to long-off
# 14381  big back lift, length ball , middle and leg. C...
# 14382  looks to go over extra cover but gets a thick ...
# 14383                                                NaN
#
#                                                  preText  postText
# 0      <p><strong>7.30pm</strong> Gaikwad and Conway ...       NaN
# 1                                                    NaN       NaN
# 2                                                    NaN       NaN
# 3      <p>Rummy: "Fast bowling options for CSK defini...       NaN
# 4      <p>LG: "Watching out for Hangargekar. He was i...       NaN
# ...                                                  ...       ...
# 14379  <p>Maheesh Theekshana to bowl now. One slip in...       NaN
# 14380                                                NaN       NaN
# 14381                                                NaN       NaN
# 14382                                                NaN       NaN
# 14383                                                NaN       NaN
#
# [14384 rows x 45 columns]

# %%
df.head()
# Out:
#    comment_id  season  match_id match_name home_team away_team  \
# 0         110  2023.0   1359475   GT v CSK        GT       CSK
# 1         120  2023.0   1359475   GT v CSK        GT       CSK
# 2         130  2023.0   1359475   GT v CSK        GT       CSK
# 3         140  2023.0   1359475   GT v CSK        GT       CSK
# 4         150  2023.0   1359475   GT v CSK        GT       CSK
#
#   current_innings  innings_id  over  ball  ...  wicket_id wkt_batsman_name  \
# 0             CSK           1     1     1  ...        NaN              NaN
# 1             CSK           1     1     2  ...        NaN              NaN
# 2             CSK           1     1     3  ...        NaN              NaN
# 3             CSK           1     1     4  ...        NaN              NaN
# 4             CSK           1     1     5  ...        NaN              NaN
#
#    wkt_bowler_name wkt_batsman_runs wkt_batsman_balls  wkt_text isRetiredHurt  \
# 0              NaN              NaN               NaN       NaN         False
# 1              NaN              NaN               NaN       NaN         False
# 2              NaN              NaN               NaN       NaN         False
# 3              NaN              NaN               NaN       NaN         False
# 4              NaN              NaN               NaN       NaN         False
#
#                                                 text  \
# 0  nice and full, angling and perhaps swinging in...
# 1  Conway shuffles across off, and shimmies out a...
# 2  good length, angling in at off and then straig...
# 3  shorter and slanting into middle and leg, Gaik...
# 4  Shami hits a heavy length and brings this back...
#
#                                              preText  postText
# 0  <p><strong>7.30pm</strong> Gaikwad and Conway ...       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  <p>Rummy: "Fast bowling options for CSK defini...       NaN
# 4  <p>LG: "Watching out for Hangargekar. He was i...       NaN
#
# [5 rows x 45 columns]

# %%
df.tail()
# Out:
#        comment_id  season  match_id match_name home_team away_team  \
# 14379       27010  2023.0   1359535  CSK v KKR       CSK       KKR
# 14380       27020  2023.0   1359535  CSK v KKR       CSK       KKR
# 14381       27030  2023.0   1359535  CSK v KKR       CSK       KKR
# 14382       27040  2023.0   1359535  CSK v KKR       CSK       KKR
# 14383       27050  2023.0   1359535  CSK v KKR       CSK       KKR
#
#       current_innings  innings_id  over  ball  ...  wicket_id  \
# 14379             KKR           2     8     1  ...        NaN
# 14380             KKR           2     8     2  ...        NaN
# 14381             KKR           2     8     3  ...        NaN
# 14382             KKR           2     8     4  ...        NaN
# 14383             KKR           2     8     5  ...        NaN
#
#       wkt_batsman_name  wkt_bowler_name wkt_batsman_runs wkt_batsman_balls  \
# 14379              NaN              NaN              NaN               NaN
# 14380              NaN              NaN              NaN               NaN
# 14381              NaN              NaN              NaN               NaN
# 14382              NaN              NaN              NaN               NaN
# 14383              NaN              NaN              NaN               NaN
#
#        wkt_text isRetiredHurt  \
# 14379       NaN         False
# 14380       NaN         False
# 14381       NaN         False
# 14382       NaN         False
# 14383       NaN           NaN
#
#                                                     text  \
# 14379      full, outside off, driven to long-off for one
# 14380          full, around off, driven down to long-off
# 14381  big back lift, length ball , middle and leg. C...
# 14382  looks to go over extra cover but gets a thick ...
# 14383                                                NaN
#
#                                                  preText  postText
# 14379  <p>Maheesh Theekshana to bowl now. One slip in...       NaN
# 14380                                                NaN       NaN
# 14381                                                NaN       NaN
# 14382                                                NaN       NaN
# 14383                                                NaN       NaN
#
# [5 rows x 45 columns]

# %%
df.shape
# Out:
# (14384, 45)

# %%
df.columns.tolist()
# Out:
# ['comment_id',
#  'season',
#  'match_id',
#  'match_name',
#  'home_team',
#  'away_team',
#  'current_innings',
#  'innings_id',
#  'over',
#  'ball',
#  'runs',
#  'shortText',
#  'isBoundary',
#  'isWide',
#  'isNoball',
#  'batsman1_id',
#  'batsman1_name',
#  'batsman1_runs',
#  'batsman1_balls',
#  'bowler1_id',
#  'bowler1_name',
#  'bowler1_overs',
#  'bowler1_maidens',
#  'bowler1_runs',
#  'bowler1_wkts',
#  'batsman2_id',
#  'batsman2_name',
#  'batsman2_runs',
#  'batsman2_balls',
#  'bowler2_id',
#  'bowler2_name',
#  'bowler2_overs',
#  'bowler2_maidens',
#  'bowler2_runs',
#  'bowler2_wkts',
#  'wicket_id',
#  'wkt_batsman_name',
#  'wkt_bowler_name',
#  'wkt_batsman_runs',
#  'wkt_batsman_balls',
#  'wkt_text',
#  'isRetiredHurt',
#  'text',
#  'preText',
#  'postText']

# %%
df.dtypes
# Out:
# comment_id             int64
# season               float64
# match_id               int64
# match_name            object
# home_team             object
# away_team             object
# current_innings       object
# innings_id             int64
# over                   int64
# ball                   int64
# runs                   int64
# shortText             object
# isBoundary              bool
# isWide                object
# isNoball              object
# batsman1_id          float64
# batsman1_name         object
# batsman1_runs        float64
# batsman1_balls       float64
# bowler1_id           float64
# bowler1_name          object
# bowler1_overs        float64
# bowler1_maidens      float64
# bowler1_runs         float64
# bowler1_wkts         float64
# batsman2_id          float64
# batsman2_name         object
# batsman2_runs        float64
# batsman2_balls       float64
# bowler2_id           float64
# bowler2_name          object
# bowler2_overs        float64
# bowler2_maidens      float64
# bowler2_runs         float64
# bowler2_wkts         float64
# wicket_id            float64
# wkt_batsman_name      object
# wkt_bowler_name       object
# wkt_batsman_runs     float64
# wkt_batsman_balls    float64
# wkt_text              object
# isRetiredHurt         object
# text                  object
# preText               object
# postText              object
# dtype: object

# %%
df.isnull().sum()
# Out:
# comment_id               0
# season                 234
# match_id                 0
# match_name               0
# home_team                0
# away_team                0
# current_innings          0
# innings_id               0
# over                     0
# ball                     0
# runs                     0
# shortText                0
# isBoundary               0
# isWide                   0
# isNoball                 1
# batsman1_id              1
# batsman1_name            1
# batsman1_runs            1
# batsman1_balls           1
# bowler1_id               1
# bowler1_name             1
# bowler1_overs            1
# bowler1_maidens          1
# bowler1_runs             1
# bowler1_wkts             1
# batsman2_id              1
# batsman2_name            1
# batsman2_runs            1
# batsman2_balls           1
# bowler2_id             759
# bowler2_name           759
# bowler2_overs          759
# bowler2_maidens        759
# bowler2_runs           759
# bowler2_wkts           759
# wicket_id            13647
# wkt_batsman_name     13647
# wkt_bowler_name      13647
# wkt_batsman_runs     13647
# wkt_batsman_balls    13647
# wkt_text             13647
# isRetiredHurt            1
# text                    22
# preText              11270
# postText             12686
# dtype: int64

# %%
df.describe()
# Out:
#           comment_id   season      match_id    innings_id          over  \
# count   14384.000000  14150.0  1.438400e+04  14384.000000  14384.000000
# mean    87175.739016   2023.0  1.359504e+06      1.483732     10.216560
# std     79774.646740      0.0  1.744939e+01      0.499753      5.677247
# min       110.000000   2023.0  1.359475e+06      1.000000      1.000000
# 25%     18040.000000   2023.0  1.359490e+06      1.000000      5.000000
# 50%     29020.000000   2023.0  1.359504e+06      1.000000     10.000000
# 75%    118070.000000   2023.0  1.359520e+06      2.000000     15.000000
# max    219080.000000   2023.0  1.359535e+06      2.000000     20.000000
#
#                ball          runs   batsman1_id  batsman1_runs  \
# count  14384.000000  14384.000000  1.438300e+04   14383.000000
# mean       3.481646      1.426029  6.023402e+05      19.313634
# std        1.707148      1.711137  3.590519e+05      18.925871
# min        1.000000      0.000000  8.917000e+03       0.000000
# 25%        2.000000      0.000000  3.188450e+05       4.000000
# 50%        3.000000      1.000000  5.546910e+05      13.000000
# 75%        5.000000      2.000000  9.117070e+05      29.000000
# max        6.000000      7.000000  1.349361e+06     116.000000
#
#        batsman1_balls  ...  batsman2_runs  batsman2_balls    bowler2_id  \
# count    14383.000000  ...   14383.000000    14383.000000  1.362500e+04
# mean        13.580338  ...      18.029062       12.943266  6.766141e+05
# std         11.454416  ...      18.412232       11.373874  3.730622e+05
# min          0.000000  ...       0.000000        0.000000  8.917000e+03
# 25%          5.000000  ...       3.000000        4.000000  3.761160e+05
# 50%         10.000000  ...      12.000000       10.000000  6.629730e+05
# 75%         20.000000  ...      27.000000       19.000000  1.070183e+06
# max         66.000000  ...     104.000000       60.000000  1.350792e+06
#
#        bowler2_overs  bowler2_maidens  bowler2_runs  bowler2_wkts  \
# count   13625.000000     13625.000000  13625.000000  13625.000000
# mean        2.176998         0.018128     17.671339      0.605211
# std         1.041590         0.133421     10.667746      0.813830
# min         0.100000         0.000000      0.000000      0.000000
# 25%         1.000000         0.000000      9.000000      0.000000
# 50%         2.000000         0.000000     16.000000      0.000000
# 75%         3.000000         0.000000     24.000000      1.000000
# max         4.000000         1.000000     62.000000      4.000000
#
#           wicket_id  wkt_batsman_runs  wkt_batsman_balls
# count  7.370000e+02        737.000000         737.000000
# mean   6.116798e+05         20.489824          15.207598
# std    3.643572e+05         20.926962          12.716347
# min    8.917000e+03          0.000000           1.000000
# 25%    3.188450e+05          4.000000           5.000000
# 50%    5.592350e+05         13.000000          12.000000
# 75%    9.301890e+05         30.000000          22.000000
# max    1.312645e+06        104.000000          65.000000
#
# [8 rows x 26 columns]

# %%
df['match_name'].value_counts()
# Out:
# match_name
# KKR v SRH     250
# CSK v PBKS    250
# SRH v KKR     250
# CSK v RR      250
# RCB v CSK     250
# RR v SRH      250
# MI v RR       250
# GT v LSG      250
# CSK v DC      250
# RR v PBKS     250
# RCB v RR      250
# LSG v DC      250
# PBKS v LSG    250
# RR v DC       249
# CSK v LSG     249
# RCB v LSG     249
# GT v DC       248
# KKR v CSK     248
# DC v SRH      248
# MI v PBKS     248
# KKR v PBKS    248
# GT v KKR      248
# DC v PBKS     248
# LSG v PBKS    247
# RCB v KKR     247
# SRH v MI      247
# SRH v RR      247
# RCB v DC      247
# GT v MI       246
# LSG v RCB     246
# DC v KKR      246
# DC v MI       246
# RR v LSG      245
# RR v CSK      245
# SRH v LSG     244
# PBKS v GT     244
# MI v GT       243
# GT v CSK      243
# SRH v DC      242
# GT v RR       242
# LSG v GT      241
# PBKS v MI     241
# DC v GT       240
# MI v CSK      239
# PBKS v RCB    236
# MI v KKR      234
# CSK v SRH     234
# KKR v GT      233
# KKR v RCB     232
# CSK v MI      231
# MI v RCB      229
# DC v RCB      228
# SRH v PBKS    228
# RCB v MI      227
# LSG v SRH     223
# PBKS v KKR    222
# KKR v RR      204
# RR v GT       198
# RR v RCB      189
# CSK v KKR     175
# Name: count, dtype: int64

# %%
df['home_team'].nunique()
# Out:
# 10

# %%
df['away_team'].value_counts()
# Out:
# away_team
# PBKS    1719
# MI      1672
# LSG     1487
# DC      1486
# RR      1443
# GT      1399
# KKR     1388
# RCB     1360
# CSK     1225
# SRH     1205
# Name: count, dtype: int64

# %%
all_teams = pd.concat([df['home_team'], df['away_team']]).unique()
num_teams = len(all_teams)
print(f"Number of different teams: {num_teams}")
# Out:
# Number of different teams: 10

# %%
team_matches = pd.concat([df['home_team'], df['away_team']]).value_counts()
team_matches
# Out:
# RR      3069
# KKR     3037
# DC      2942
# PBKS    2912
# MI      2881
# GT      2876
# CSK     2864
# RCB     2830
# LSG     2694
# SRH     2663
# Name: count, dtype: int64

# %% [markdown]
# # **to analyze runs scored , wickets taken**

# %%
batsmen_data = df[['batsman1_name', 'batsman1_runs', 'batsman1_balls']]
batsmen_data.columns = ['batsman', 'runs', 'balls']


batsmen_data2 = df[['batsman2_name', 'batsman2_runs', 'batsman2_balls']]
batsmen_data2.columns = ['batsman', 'runs', 'balls']
batsmen_data = pd.concat([batsmen_data, batsmen_data2])


batsmen_data = batsmen_data.groupby('batsman').agg({'runs': 'sum', 'balls': 'sum'})
print(batsmen_data)
# Out:
#                      runs    balls
# batsman
# Abdul Basith          1.0      1.0
# Abdul Samad        2682.0   2700.0
# Abhinav Manohar    1962.0   1826.0
# Abhishek Sharma    6141.0   3923.0
# Abishek Porel       294.0    283.0
# ...                   ...      ...
# Wayne Parnell         9.0     25.0
# Wriddhiman Saha    8656.0   5543.0
# Yash Dhull           14.0     28.0
# Yashasvi Jaiswal  24505.0  13480.0
# Yudhvir Singh         1.0      2.0
#
# [162 rows x 2 columns]

# %%
max_runs_batsman = batsmen_data['runs'].idxmax()
max_runs = batsmen_data['runs'].max()

print(f"The player who scored the maximum runs is {max_runs_batsman} with {max_runs} runs.")
# Out:
# The player who scored the maximum runs is Faf du Plessis with 26821.342696238615 runs.

# %%
bowler_wickets = df.groupby('bowler1_name')['bowler1_wkts'].sum()
max_wickets_bowler = bowler_wickets.idxmax()
max_wickets = bowler_wickets.max()
print(f"The bowler who took the maximum wickets is {max_wickets_bowler} with {max_wickets} wickets.")



bowler_runs = df.groupby('bowler1_name')['bowler1_runs'].sum()
max_runs_bowler = bowler_runs.idxmax()
max_runs_conceded = bowler_runs.max()
print(f"The bowler who conceded the maximum runs is {max_runs_bowler} with {max_runs_conceded} runs.")



bowler_overs = df.groupby('bowler1_name')['bowler1_overs'].sum()
max_overs_bowler = bowler_overs.idxmax()
max_overs = bowler_overs.max()
print(f"The bowler who bowled the maximum overs is {max_overs_bowler} with {max_overs} overs.")
# Out:
# The bowler who took the maximum wickets is Rashid Khan with 271.0 wickets.
# The bowler who conceded the maximum runs is Arshdeep Singh with 5270.0 runs.
# The bowler who bowled the maximum overs is Ravichandran Ashwin with 581.6543141208371 overs.

# %%
df[['current_innings','runs']].head(15)
# Out:
#    current_innings  runs
# 0              CSK     0
# 1              CSK     1
# 2              CSK     0
# 3              CSK     1
# 4              CSK     0
# 5              CSK     0
# 6              CSK     4
# 7              CSK     0
# 8              CSK     4
# 9              CSK     1
# 10             CSK     1
# 11             CSK     1
# 12             CSK     1
# 13             CSK     0
# 14             CSK     0

# %%
import matplotlib.pyplot as plt
import seaborn as sns


team_matches_played = pd.concat([df['home_team'], df['away_team']]).value_counts()


plt.figure(figsize=(15, 6))
sns.lineplot(x=team_matches_played.index, y=team_matches_played.values)
plt.xlabel('Teams')
plt.ylabel('Number of Matches Played')
plt.title('Number of Matches Played by Each Team')
plt.xticks(rotation=90)
plt.show()

# %%
df['runs_per_over'] = df['runs'] / df['bowler1_overs']


runs_per_over_by_match = df.groupby('match_name')['runs_per_over'].mean()

runs_per_over_by_match
# Out:
# match_name
# CSK v DC           inf
# CSK v KKR          inf
# CSK v LSG          inf
# CSK v MI           inf
# CSK v PBKS         inf
# CSK v RR           inf
# CSK v SRH          inf
# DC v GT            inf
# DC v KKR           inf
# DC v MI            inf
# DC v PBKS     2.462010
# DC v RCB      2.780951
# DC v SRH           inf
# GT v CSK      2.449018
# GT v DC       1.003931
# GT v KKR      1.974201
# GT v LSG           inf
# GT v MI            inf
# GT v RR            inf
# KKR v CSK     2.230550
# KKR v GT           inf
# KKR v PBKS    2.067834
# KKR v RCB     2.167906
# KKR v RR           inf
# KKR v SRH     2.694743
# LSG v DC           inf
# LSG v GT      2.041158
# LSG v PBKS         inf
# LSG v RCB          inf
# LSG v SRH     2.182318
# MI v CSK           inf
# MI v GT       1.665191
# MI v KKR      2.876853
# MI v PBKS          inf
# MI v RCB      2.985795
# MI v RR            inf
# PBKS v GT     1.658343
# PBKS v KKR    2.306432
# PBKS v LSG    3.222556
# PBKS v MI          inf
# PBKS v RCB    1.850275
# RCB v CSK     2.364279
# RCB v DC           inf
# RCB v KKR     2.414929
# RCB v LSG     2.494684
# RCB v MI           inf
# RCB v RR      2.166447
# RR v CSK      2.437118
# RR v DC            inf
# RR v GT       1.792559
# RR v LSG      1.668419
# RR v PBKS     2.363460
# RR v RCB      1.711527
# RR v SRH      2.033448
# SRH v DC      1.819657
# SRH v KKR          inf
# SRH v LSG     2.177169
# SRH v MI      1.971576
# SRH v PBKS         inf
# SRH v RR      2.490794
# Name: runs_per_over, dtype: float64

# %%
team_runs = df.groupby('home_team')['runs'].sum() + df.groupby('away_team')['runs'].sum()
team_matches_played = pd.concat([df['home_team'], df['away_team']]).value_counts()

average_runs = team_runs / team_matches_played

average_runs
# Out:
# CSK     1.429120
# DC      1.289939
# GT      1.400904
# KKR     1.457359
# LSG     1.383445
# MI      1.529330
# PBKS    1.469780
# RCB     1.462191
# RR      1.437276
# SRH     1.396545
# dtype: float64

# %%
team_runs = df.groupby('home_team')['runs'].sum() + df.groupby('away_team')['runs'].sum()

team_matches_played = pd.concat([df['home_team'], df['away_team']]).value_counts()

average_runs = team_runs / team_matches_played


best_performing_team = average_runs.idxmax()
highest_average_runs = average_runs.max()

print(f"The best performing team is {best_performing_team} with an average of {highest_average_runs} runs per match.")
# Out:
# The best performing team is MI with an average of 1.5293300937174592 runs per match.

# %%
top_batsmen = df.groupby('batsman1_name')['batsman1_runs'].sum().sort_values(ascending=False).head(5)
print(top_batsmen)
# Out:
# batsman1_name
# Faf du Plessis      12871.313634
# Yashasvi Jaiswal    12708.000000
# Devon Conway        10735.000000
# Shubman Gill         9483.000000
# Virat Kohli          9177.000000
# Name: batsman1_runs, dtype: float64

# %%
top_bowlers = df.groupby('bowler1_name')['bowler1_wkts'].sum().sort_values(ascending=False).head(5)
print(top_bowlers)
# Out:
# bowler1_name
# Rashid Khan           271.0
# Piyush Chawla         237.0
# Varun Chakravarthy    234.0
# Mohammed Shami        207.0
# Mohammed Siraj        204.0
# Name: bowler1_wkts, dtype: float64

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(x='home_team', y='runs', data=df)
plt.xlabel('Team')
plt.ylabel('Runs')
plt.title('Distribution of Runs Scored by Each Team')
plt.xticks(rotation=90)
plt.show()

# %%
best_team_avg_runs = average_runs_per_match.idxmax()
highest_avg_runs = average_runs_per_match.max()
print(f"The team with the highest average runs per match is {best_team_avg_runs} with {highest_avg_runs:.2f} runs.")
# Out:
# The team with the highest average runs per match is MI with 1.53 runs.

# %%
team_runs = df.groupby('home_team')['runs'].sum() + df.groupby('away_team')['runs'].sum()
team_matches_played = pd.concat([df['home_team'], df['away_team']]).value_counts()
average_runs_per_match = team_runs / team_matches_played

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='runs', y='bowler1_wkts', data=df)
plt.xlabel('Runs Scored')
plt.ylabel('Wickets Taken')
plt.title('Relationship between Runs Scored and Wickets Taken')
plt.show()

# %%
df.columns.tolist()
# Out:
# ['comment_id',
#  'season',
#  'match_id',
#  'match_name',
#  'home_team',
#  'away_team',
#  'current_innings',
#  'innings_id',
#  'over',
#  'ball',
#  'runs',
#  'shortText',
#  'isBoundary',
#  'isWide',
#  'isNoball',
#  'batsman1_id',
#  'batsman1_name',
#  'batsman1_runs',
#  'batsman1_balls',
#  'bowler1_id',
#  'bowler1_name',
#  'bowler1_overs',
#  'bowler1_maidens',
#  'bowler1_runs',
#  'bowler1_wkts',
#  'batsman2_id',
#  'batsman2_name',
#  'batsman2_runs',
#  'batsman2_balls',
#  'bowler2_id',
#  'bowler2_name',
#  'bowler2_overs',
#  'bowler2_maidens',
#  'bowler2_runs',
#  'bowler2_wkts',
#  'wicket_id',
#  'wkt_batsman_name',
#  'wkt_bowler_name',
#  'wkt_batsman_runs',
#  'wkt_batsman_balls',
#  'wkt_text',
#  'isRetiredHurt',
#  'text',
#  'preText',
#  'postText',
#  'runs_per_over']

# %%
team_wickets = df.groupby('home_team')['bowler1_wkts'].sum() + df.groupby('away_team')['bowler1_wkts'].sum()
average_wickets_per_match = team_wickets / team_matches_played
