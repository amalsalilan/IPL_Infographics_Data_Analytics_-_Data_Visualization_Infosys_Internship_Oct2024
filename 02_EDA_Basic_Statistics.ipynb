# %% [markdown]
# <a href="https://colab.research.google.com/github/amalsalilan/IPL_Infographics_Data_Analytics_-_Data_Visualization_Infosys_Internship_Oct2024/blob/K_Akshya/02_EDA_Basic_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/all_season_details_data.csv')
# df
# Out:
# <ipython-input-17-9c444859df4c>:1: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('/content/all_season_details_data.csv')

# %%
mean_df=df.mean(numeric_only=True)
mean_df
# Out:
# season                 2015.602777
# match_id             870174.882737
# innings_id                1.483247
# over                     10.161716
# ball                      3.483886
# runs                      1.317899
# isBoundary                0.161559
# isWide                    0.031338
# isNoball                  0.004127
# batsman1_id          250305.529975
# batsman1_runs            18.047698
# batsman1_balls           14.119873
# bowler1_id           315859.817934
# bowler1_overs             1.682535
# bowler1_maidens           0.017411
# bowler1_runs             13.656152
# bowler1_wkts              0.468264
# batsman2_runs            16.551686
# batsman2_balls           13.219288
# bowler2_id           315165.013247
# bowler2_overs             2.198914
# bowler2_maidens           0.024483
# bowler2_runs             16.235019
# bowler2_wkts              0.551868
# wicket_id            263527.278283
# wkt_batsman_runs         18.815404
# wkt_batsman_balls        15.311869
# ...

# %%
median_df=df.median(numeric_only=True)
median_df
# Out:
# season                 2015.0
# match_id             829819.0
# innings_id                1.0
# over                     10.0
# ball                      3.0
# runs                      1.0
# isBoundary                0.0
# isWide                    0.0
# isNoball                  0.0
# batsman1_id           52912.0
# batsman1_runs            12.0
# batsman1_balls           11.0
# bowler1_id           269170.0
# bowler1_overs             1.5
# bowler1_maidens           0.0
# bowler1_runs             12.0
# bowler1_wkts              0.0
# batsman2_runs            11.0
# batsman2_balls           10.0
# bowler2_id           265564.0
# bowler2_overs             2.0
# bowler2_maidens           0.0
# bowler2_runs             14.0
# bowler2_wkts              0.0
# wicket_id            211854.0
# wkt_batsman_runs         12.0
# wkt_batsman_balls        12.0
# isRetiredHurt             0.0
# dtype: float64

# %%
mode_df=df.mode(numeric_only=True)
mode_df
# Out:
#      season  match_id  innings_id  over  ball  runs isBoundary isWide  \
# 0    2013.0    335989         1.0   2.0   1.0   1.0      False  False
# 1       NaN    336009         NaN   NaN   NaN   NaN        NaN    NaN
# 2       NaN    336023         NaN   NaN   NaN   NaN        NaN    NaN
# 3       NaN    336036         NaN   NaN   NaN   NaN        NaN    NaN
# 4       NaN    392190         NaN   NaN   NaN   NaN        NaN    NaN
# ..      ...       ...         ...   ...   ...   ...        ...    ...
# 97      NaN   1359536         NaN   NaN   NaN   NaN        NaN    NaN
# 98      NaN   1359537         NaN   NaN   NaN   NaN        NaN    NaN
# 99      NaN   1359540         NaN   NaN   NaN   NaN        NaN    NaN
# 100     NaN   1359541         NaN   NaN   NaN   NaN        NaN    NaN
# 101     NaN   1359542         NaN   NaN   NaN   NaN        NaN    NaN
#
#     isNoball  batsman1_id  ...  batsman2_balls  bowler2_id  bowler2_overs  \
# ...

# %%
std_values = df.std(numeric_only=True)                      # Measures the spread of data from the mean
std_values
# Out:
# season                    4.646633
# match_id             353066.379847
# innings_id                0.499720
# over                      5.658034
# ball                      1.707447
# runs                      1.612824
# isBoundary                0.368047
# isWide                    0.174230
# isNoball                  0.064109
# batsman1_id          296881.184241
# batsman1_runs            18.341554
# batsman1_balls           11.905876
# bowler1_id           321749.411684
# bowler1_overs             1.115569
# bowler1_maidens           0.131614
# bowler1_runs             10.238288
# bowler1_wkts              0.728663
# batsman2_runs            17.771904
# batsman2_balls           11.892062
# bowler2_id           322205.626237
# bowler2_overs             1.046243
# bowler2_maidens           0.155527
# bowler2_runs             10.171336
# bowler2_wkts              0.773715
# wicket_id            303991.460628
# wkt_batsman_runs         19.542348
# wkt_batsman_balls        12.695239
# ...

# %%
variance_values = df.var(numeric_only=True)                # understanding the spread of the data
variance_values
# Out:
# season               2.159120e+01
# match_id             1.246559e+11
# innings_id           2.497204e-01
# over                 3.201335e+01
# ball                 2.915375e+00
# runs                 2.601201e+00
# isBoundary           1.354583e-01
# isWide               3.035605e-02
# isNoball             4.109986e-03
# batsman1_id          8.813844e+10
# batsman1_runs        3.364126e+02
# batsman1_balls       1.417499e+02
# bowler1_id           1.035227e+11
# bowler1_overs        1.244495e+00
# bowler1_maidens      1.732224e-02
# bowler1_runs         1.048225e+02
# bowler1_wkts         5.309504e-01
# batsman2_runs        3.158406e+02
# batsman2_balls       1.414211e+02
# bowler2_id           1.038165e+11
# bowler2_overs        1.094624e+00
# bowler2_maidens      2.418856e-02
# bowler2_runs         1.034561e+02
# bowler2_wkts         5.986351e-01
# wicket_id            9.241081e+10
# wkt_batsman_runs     3.819034e+02
# wkt_batsman_balls    1.611691e+02
# ...

# %%
min_values = df.min(numeric_only=True)
min_values
# Out:
# season               2008.0
# match_id             335982
# innings_id                1
# over                      1
# ball                      1
# runs                      0
# isBoundary            False
# isWide                False
# isNoball              False
# batsman1_id            4292
# batsman1_runs             0
# batsman1_balls            0
# bowler1_id             4508
# bowler1_overs           0.0
# bowler1_maidens           0
# bowler1_runs              0
# bowler1_wkts              0
# batsman2_runs             0
# batsman2_balls            0
# bowler2_id           4508.0
# bowler2_overs           0.1
# bowler2_maidens         0.0
# bowler2_runs            0.0
# bowler2_wkts            0.0
# wicket_id            4292.0
# wkt_batsman_runs        0.0
# wkt_batsman_balls       0.0
# isRetiredHurt         False
# dtype: object

# %%
df.season.min()
# Out:
# 2008.0

# %%
max_values = df.max(numeric_only=True)
max_values
# Out:
# season                  2023.0
# match_id               1370353
# innings_id                   2
# over                        20
# ball                         7
# runs                         7
# isBoundary                True
# isWide                    True
# isNoball                  True
# batsman1_id            1349361
# batsman1_runs              174
# batsman1_balls              73
# bowler1_id             1350792
# bowler1_overs              4.0
# bowler1_maidens              2
# bowler1_runs                70
# bowler1_wkts                 6
# batsman2_runs              174
# batsman2_balls              73
# bowler2_id           1350792.0
# bowler2_overs              4.0
# bowler2_maidens            2.0
# bowler2_runs              70.0
# bowler2_wkts               5.0
# wicket_id            1312645.0
# wkt_batsman_runs         129.0
# wkt_batsman_balls         69.0
# isRetiredHurt             True
# dtype: object

# %%
df.dtypes
# Out:
# season               float64
# match_id               int64
# match_name            object
# home_team             object
# away_team             object
# current_innings       object
# innings_id             int64
# over                   int64
# ball                   int64
# runs                   int64
# shortText             object
# isBoundary              bool
# isWide                  bool
# isNoball                bool
# batsman1_id            int64
# batsman1_name         object
# batsman1_runs          int64
# batsman1_balls         int64
# bowler1_id             int64
# bowler1_name          object
# bowler1_overs        float64
# bowler1_maidens        int64
# bowler1_runs           int64
# bowler1_wkts           int64
# batsman2_id           object
# batsman2_name         object
# batsman2_runs          int64
# batsman2_balls         int64
# bowler2_id           float64
# bowler2_name          object
# bowler2_overs        float64
# bowler2_maidens      float64
# ...

# %%
for col in df.select_dtypes(include=['bool']).columns:
    df[col] = df[col].astype(int)
quantiles = df.quantile([0.25, 0.5, 0.75], numeric_only=True)
quantiles
# Out:
#       season   match_id  innings_id  over  ball  runs  isBoundary  isWide  \
# 0.25  2012.0   548315.0         1.0   5.0   2.0   0.0         0.0     0.0
# 0.50  2015.0   829819.0         1.0  10.0   3.0   1.0         0.0     0.0
# 0.75  2020.0  1216506.0         2.0  15.0   5.0   1.0         0.0     0.0
#
#       isNoball  batsman1_id  ...  batsman2_balls  bowler2_id  bowler2_overs  \
# 0.25       0.0      32966.0  ...             4.0     33335.0            1.0
# 0.50       0.0      52912.0  ...            10.0    265564.0            2.0
# 0.75       0.0     379143.0  ...            20.0    475281.0            3.0
#
#       bowler2_maidens  bowler2_runs  bowler2_wkts  wicket_id  \
# 0.25              0.0           8.0           0.0    33141.0
# 0.50              0.0          14.0           0.0   211854.0
# 0.75              0.0          23.0           1.0   398439.0
#
#       wkt_batsman_runs  wkt_batsman_balls  isRetiredHurt
# ...

# %%
skewness = df.skew(numeric_only=True)                         # to understand the asymmetric distribution of data
skewness
# Out:
# season                 0.035182
# match_id              -0.085453
# innings_id             0.067051
# over                   0.042967
# ball                   0.011533
# runs                   1.550749
# isBoundary             1.839135
# isWide                 5.379856
# isNoball              15.469770
# batsman1_id            1.498729
# batsman1_runs          1.558417
# batsman1_balls         1.173468
# bowler1_id             1.120880
# bowler1_overs          0.251518
# bowler1_maidens        7.519902
# bowler1_runs           0.809832
# bowler1_wkts           1.661945
# batsman2_runs          1.579042
# batsman2_balls         1.141412
# bowler2_id             1.122851
# bowler2_overs          0.333778
# bowler2_maidens        6.275001
# bowler2_runs           0.788353
# bowler2_wkts           1.466445
# wicket_id              1.409583
# wkt_batsman_runs       1.491740
# wkt_batsman_balls      1.134973
# isRetiredHurt        119.435191
# dtype: float64

# %%
correlation = df.corr(numeric_only=True)                # relationship between different variables
correlation
# Out:
#                      season  match_id  innings_id      over      ball  \
# season             1.000000  0.987936    0.002102  0.010503  0.000842
# match_id           0.987936  1.000000    0.001337  0.009632  0.000815
# innings_id         0.002102  0.001337    1.000000 -0.043354 -0.003990
# over               0.010503  0.009632   -0.043354  1.000000 -0.012488
# ball               0.000842  0.000815   -0.003990 -0.012488  1.000000
# runs               0.026341  0.027530   -0.006319  0.083484  0.000417
# isBoundary         0.020556  0.021333   -0.001894  0.012057 -0.001552
# isWide             0.006260  0.005833    0.003118  0.005198 -0.006112
# isNoball          -0.001888 -0.002540   -0.004856  0.018460 -0.002311
# batsman1_id        0.605883  0.588707    0.008641  0.033369  0.001762
# batsman1_runs      0.052083  0.054303   -0.015820  0.333015  0.012274
# batsman1_balls     0.010620  0.011512   -0.021637  0.343544  0.005332
# ...

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns,annot=True,cmap='Blues', square=True, linewidths=1.0)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#               season      match_id     innings_id           over  \
# count  242549.000000  2.425490e+05  242549.000000  242549.000000
# mean     2015.602777  8.701749e+05       1.483247      10.161716
# std         4.646633  3.530664e+05       0.499720       5.658034
# min      2008.000000  3.359820e+05       1.000000       1.000000
# 25%      2012.000000  5.483150e+05       1.000000       5.000000
# 50%      2015.000000  8.298190e+05       1.000000      10.000000
# 75%      2020.000000  1.216506e+06       2.000000      15.000000
# max      2023.000000  1.370353e+06       2.000000      20.000000
#
#                 ball           runs     isBoundary         isWide  \
# count  242549.000000  242549.000000  242549.000000  242549.000000
# mean        3.483886       1.317899       0.161559       0.031338
# std         1.707447       1.612824       0.368047       0.174230
# min         1.000000       0.000000       0.000000       0.000000
# ...
