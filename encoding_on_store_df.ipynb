# %%
import pandas as pd
df = pd.read_csv('/content/store_df.csv')
df.head()
# Out:
#   Product_Category Store_Type Product_Quality Shelf_Placement Discount_Level  \
# 0         Beverage      Urban            High             Top         Medium
# 1            Snack   Suburban          Medium          Middle            Low
# 2            Fruit      Rural            High          Bottom            NaN
# 3            Dairy      Urban             Low          Middle           High
# 4           Bakery   Suburban          Medium             Top            Low
#
#    Sales_Amount
# 0           500
# 1           300
# 2           150
# 3           450
# 4           350

# %%
data_encoded = pd.get_dummies(df, columns=['Store_Type'])
data_encoded.head()
# Out:
#   Product_Category Product_Quality Shelf_Placement Discount_Level  \
# 0         Beverage            High             Top         Medium
# 1            Snack          Medium          Middle            Low
# 2            Fruit            High          Bottom            NaN
# 3            Dairy             Low          Middle           High
# 4           Bakery          Medium             Top            Low
#
#    Sales_Amount  Store_Type_Rural  Store_Type_Suburban  Store_Type_Urban
# 0           500             False                False              True
# 1           300             False                 True             False
# 2           150              True                False             False
# 3           450             False                False              True
# 4           350             False                 True             False

# %%
quality_mapping = {'High': 2, 'Medium': 1, 'Low': 0}
df['Product_Quality_Encoded'] = df['Product_Quality'].map(quality_mapping)

# %%
df.head()
# Out:
#   Product_Category Store_Type Product_Quality Shelf_Placement Discount_Level  \
# 0         Beverage      Urban            High             Top         Medium
# 1            Snack   Suburban          Medium          Middle            Low
# 2            Fruit      Rural            High          Bottom            NaN
# 3            Dairy      Urban             Low          Middle           High
# 4           Bakery   Suburban          Medium             Top            Low
#
#    Sales_Amount  Product_Quality_Encoded
# 0           500                        2
# 1           300                        1
# 2           150                        2
# 3           450                        0
# 4           350                        1
